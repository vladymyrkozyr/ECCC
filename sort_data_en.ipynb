# %%
import glob
import os
import pandas as pd

from langdetect import detect
import nltk
#nltk.download()   # comment after first download
from nltk.tokenize import wordpunct_tokenize, MWETokenizer
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
import gensim
from gensim import corpora
import string
from numbers import Number
from pprint import pprint
import logging
import operator

pd.options.display.max_rows = 30

# %%
keywords_chosen = './EnglishData/Keywords_ECCC_EN.csv'

# list = [social_media_csv_filepath, cleaned_text_column_name, raw_text_column_name]
data_folder = './EnglishData/Accounts/*.csv'

CSV_COLUMNS = ['caption_cleaned', 'hashtags']

# %%
stopWords = set(stopwords.words('english'))
exclude = set(string.punctuation)
exclude.remove('_')
exclude.remove('-')
lemma = WordNetLemmatizer()


def detect_lang(text):
    try:
        lang = detect(text)
    except:
        return 'error'
    return lang


def lemmatize_keywords(col):
    return '_'.join(lemma.lemmatize(word).lower() for word in col.split()) 


def lemmatize_text(row):    
    text_cols = str(row['caption_cleaned']).lower(), str(row['hashtags']).lower()
    normalized_text = []
    if text_cols[0] == 'nan':
        return '', ''
    for text in text_cols:
        if isinstance(text, str):
            tokens = tokenizer.tokenize(text.split())
            
            stop_free = ' '.join(w for w in tokens if w not in stopWords and len(w) > 1)
            punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
            normalized = ' '.join(lemma.lemmatize(word).lower() for word in punc_free.split() if len(lemma.lemmatize(word)) > 2)
            #print(normalized)
            normalized_text.append(normalized.split())
        else:
            normalized_text = ['', '']
    return normalized_text[0], normalized_text[1]


def find_category(row):
    text_cols = row['lemmatized_caption_cleaned'], row['lemmatized_hashtags']
    keywords_found = []
    counter = {'Social': 0, 'Economical': 0, 'Environmental': 0}
    category = 'unknown'
    for text in text_cols:
        for word in text:
            if word in soc_list:
                counter['Social'] += 1
                keywords_found.append(word)
            if word in econ_list:
                counter['Economical'] += 1
                keywords_found.append(word)
            if word in env_list:
                counter['Environmental'] += 1
                keywords_found.append(word)
    if len(keywords_found) > 0:
        category = max(counter.items(), key=operator.itemgetter(1))[0]    
    return keywords_found, category

# %%
# load keywords list
pd.options.display.max_rows = 10
KEYWORD_COL = ['Social', 'Economical', 'Environmental']
keywords_df = pd.read_csv(keywords_chosen, encoding = "ISO-8859-1")
lemma_keywords_df = pd.DataFrame(columns=KEYWORD_COL)
for col in KEYWORD_COL:
    lemma_keywords_df[col] = keywords_df[col].astype(str).apply(lemmatize_keywords)
display(lemma_keywords_df)
soc_list = set(lemma_keywords_df['Social'].tolist())
soc_list.remove('nan')
econ_list = set(lemma_keywords_df['Economical'].tolist())
econ_list.remove('nan')
env_list = set(lemma_keywords_df['Environmental'].tolist())
env_list.remove('nan')
multi_word = [w.split('_') for w in soc_list.union(econ_list).union(env_list) ]   #if '_' in w 
print(multi_word)
tokenizer = MWETokenizer(multi_word)
# Out:
#             Social        Economical   Environmental
# 0           family      eating_local          biking
# 1           friend            energy      composting
# 2   public_concern            growth       recycling
# 3           spouse    infrastructure  climate_change
# 4              kid  circular_economy      low_carbon
# ..             ...               ...             ...
# 83             nan               nan          summit
# 84             nan               nan       agri-food
# 85             nan               nan           guard
# 86             nan               nan         biology
# 87             nan               nan             nan
#
# [88 rows x 3 columns]
# [['civil'], ['green', 'economy'], ['culture'], ['air', 'quality'], ['sustainable', 'food'], ['green'], ['wildlife'], ['biology'], ['human', 'right'], ['tourism'], ['safe'], ['spouse'], ['discrimination'], ['gender'], ['carbon'], ['conserve'], ['integrated'], ['commission'], ['public', 'concern'], ['health'], ['gold'], ['alternative'], ['carbon', 'offset'], ['conservation'], ['household'], ['interdisciplinary'], ['agri-food'], ['kid'], ['deforestation'], ['resource'], ['biodiversity'], ['wetland'], ['hi-velocity', 'system'], ['park'], ['fishery'], ['emission'], ['economy', 'fund'], ['cost', 'benefit'], ['bioenergy'], ['child'], ['guard'], ['sea', 'level'], ['healthy'], ['geothermal'], ['justice'], ['equity'], ['minority'], ['eating', 'local'], ['green', 'tourism'], ['stakeholder'], ['provincal'], ['energy'], ['aboriginal', 'tourism'], ['ocean'], ['minister'], ['life', 'expectancy'], ['entrepreneurship'], ['gas'], ['arctic'], ['forest', 'practice'], ['water', 'use'], ['material'], ['specie'], ['policy'], ['money'], ['solar'], ['engineering'], ['land'], ['pollutant'], ['population'], ['inuit'], ['clean', 'water'], ['pristine'], ['reusable', 'material'], ['tree'], ['river'], ['gdp'], ['tradeoff'], ['crown'], ['behaviour', 'change'], ['local'], ['tax'], ['dioxide'], ['innovative'], ['infrastructure'], ['natural', 'system'], ['federal'], ['balance'], ['ice'], ['invest'], ['finance'], ['polar', 'knowledge'], ['water'], ['climate'], ['low', 'carbon'], ['right'], ['equality'], ['funding'], ['mitigation'], ['sustainably'], ['change'], ['urban', 'health'], ['global'], ['friend'], ['student'], ['movement'], ['sustainable'], ['community'], ['climate', 'change'], ['hydrogenics'], ['building'], ['farming'], ['future'], ['transport'], ['woman'], ['biomimicry'], ['lake'], ['food', 'system'], ['landscape'], ['first', 'nation'], ['plant'], ['food', 'chain'], ['resilience'], ['nature'], ['technology'], ['wildlife', 'federation'], ['substance'], ['recycling'], ['awareness', 'raising'], ['income'], ['footprint'], ['circular', 'economy'], ['clean'], ['greenhouse', 'gas'], ['agriculture'], ['library'], ['innovation'], ['research', 'station'], ['bird'], ['coastal'], ['summit'], ['ecosystem'], ['oil'], ['governance'], ['poverty'], ['multicultural'], ['armed', 'force'], ['indigenous'], ['growth'], ['government'], ['biking'], ['planet'], ['collaboration'], ['marine'], ['job'], ['harmful'], ['globalization'], ['family'], ['diversity'], ['wind', 'energy'], ['composting'], ['woodland', 'biofuels'], ['museum', 'of', 'nature'], ['air'], ['biomass'], ['pipe'], ['natural'], ['archive'], ['race'], ['interconnection'], ['contaminated'], ['adaptation'], ['engagement'], ['northern'], ['coast'], ['partnership'], ['cop23'], ['unemployment']]

# %%
pd.options.display.max_rows = 1000
# read csv files and save targt columns to dataframe
filePaths = glob.glob(data_folder)  
for filename in filePaths:
    display(filename)
    #print(os.path.basename(filename))
    data_df = pd.read_csv(filename)
    data_df['lang'] = data_df['caption_cleaned'].astype(str).apply(detect_lang)
    wrong_lang = data_df[data_df['lang'] != 'en'].shape[0]    
    print(wrong_lang/len(data_df))
    data_df['lemmatized_caption_cleaned'], data_df['lemmatized_hashtags']  = zip(*data_df.apply(lemmatize_text, axis=1))
    data_df['keywords_found'], data_df['category'] = zip(*data_df.apply(find_category, axis=1))
    #data_df.to_csv(filename, index=None)
    display(data_df[['words_matched_list', 'lang', 'keywords_found', 'category']])
# Out:
# './EnglishData/Accounts/CanadianAgriculture_facebook_statuses.csv'
# 0.0544280442804428
#                                      words_matched_list lang  \
# 0               ['gas', 'emissions ', 'greenhouse gas']   en
# 1                                                   NaN   en
# 2                                                ['or']   en
# 3                                                   NaN   en
# 4                                                   NaN   en
# 5                                   ['future', 'futur']   en
# 6                                                   NaN   en
# 7                                            ['policy']   en
# 8                                                ['or']   en
# 9                                        ['innovation']   en
# 10                                               ['or']   en
# 11                                           ['policy']   en
# 12                                                  NaN   tl
# 13                                               ['or']   en
# 14                                               ['or']   en
# 15                                               ['or']   en
# 16                                           ['nature']   en
# 17                               ['partnership', 'oil']   en
# 18                                ['agriculture', 'or']   en
# 19                                           ['policy']   en
# 20               ['climate', 'species', 'climat', 'or']   en
# 21                                                  NaN   en
# 22                                    ['natural', 'or']   en
# 23                                               ['or']   en
# 24                                        ['or', 'mer']   en
# 25                                                  NaN   en
# 26                                           ['import']   en
# 27                                              ['oil']   en
# 28                                ['agriculture', 'or']   en
# 29                                             ['safe']   en
# 30            ['invest', 'technologies', 'technologie']   en
# 31                                        ['or', 'ice']   en
# 32             ['gas', 'agriculture', 'greenhouse gas']   en
# 33                                ['agriculture', 'or']   en
# 34                                ['agriculture', 'or']   en
# 35                                              ['air']   en
# 36                                        ['or', 'mer']   en
# 37                                               ['or']   en
# 38                                        ['or', 'ice']   en
# 39                                        ['or', 'mer']   en
# 40                      ['technologies', 'technologie']   en
# 41                                                  NaN   tl
# 42                                ['agriculture', 'or']   en
# 43                                      ['agriculture']   en
# 44                         ['agri-food', 'agriculture']   en
# 45                                        ['or', 'mer']   en
# 46                                               ['or']   en
# 47                                                  NaN   en
# 48                                ['agriculture', 'or']   en
# 49            ['agri-food', 'agriculture', 'or', 'air']   en
# 50                                      ['water', 'or']   en
# 51                                ['agriculture', 'or']   en
# 52                         ['agri-food', 'agriculture']   en
# 53                                               ['or']   en
# 54                  ['gas', 'agriculture', 'or', 'mer']   en
# 55                             ['farming', 'or', 'mer']   en
# 56                                    ['import', 'oil']   en
# 57                               ['conservation', 'or']   en
# 58                                                  NaN   tl
# 59                                               ['or']   en
# 60                                      ['agriculture']   en
# 61                                   ['safe', 'health']   en
# 62                                           ['invest']   en
# 63                                               ['or']   en
# 64                                               ['or']   en
# 65                                           ['health']   en
# 66                     ['global', 'partnership', 'oil']   en
# 67                                    ['natural', 'or']   en
# 68                                           ['import']   en
# 69                                             ['vote']   en
# 70                                               ['or']   en
# 71     ['eau', 'agri-food', 'agriculture', 'or', 'mer']   en
# 72                   ['agri-food', 'agriculture', 'or']   en
# 73                                           ['health']   en
# 74                                              ['air']   en
# 75                                ['agriculture', 'or']   en
# 76                                            ['green']   en
# 77                                        ['eau', 'or']   en
# 78                                                  NaN   en
# 79                 ['sustainable', 'agriculture', 'or']   en
# 80                                                  NaN   en
# 81                                        ['or', 'ice']   en
# 82                                                  NaN   en
# 83                                               ['or']   en
# 84                                        ['or', 'mer']   en
# 85            ['planet', 'conservation', 'agriculture']   en
# 86                                        ['household']   en
# 87                                               ['or']   en
# 88                                           ['health']   en
# 89                                           ['health']   en
# 90                                               ['or']   en
# 91                                        ['or', 'mer']   en
# 92    ['agriculture', 'growth', 'partnership', 'mini...   en
# 93            ['ami', 'culture', 'community', 'family']   en
# 94                                        ['or', 'mer']   en
# 95                                               ['or']   en
# 96                                ['agriculture', 'or']   en
# 97                         ['agriculture', 'or', 'mer']   en
# 98                                ['agriculture', 'or']   en
# 99                               ['health', 'healthy ']   en
# 100                                              ['or']   en
# 101                                                 NaN   tl
# 102                                       ['or', 'mer']   en
# 103                                ['or', 'ice', 'mer']   en
# 104                                          ['friend']   en
# 105                                       ['or', 'mer']   en
# 106                                              ['or']   en
# 107                               ['agriculture', 'or']   en
# 108                                      ['eau', 'mer']   en
# 109                        ['agriculture', 'or', 'mer']   en
# 110                               ['agriculture', 'or']   en
# 111                                      ['tree', 'or']   en
# 112                                                 NaN   tl
# 113                                       ['or', 'mer']   en
# 114                                              ['or']   en
# 115       ['gas', 'emissions ', 'greenhouse gas', 'or']   en
# 116                                              ['or']   en
# 117                                          ['nature']   en
# 118                                                 NaN   en
# 119                               ['agriculture', 'or']   en
# 120                                ['mer', 'or', 'air']   en
# 121                                              ['or']   en
# 122                                                 NaN   en
# 123                                                 NaN   en
# 124                                              ['or']   en
# 125                                                 NaN   en
# 126                                           ['women']   en
# 127                               ['agriculture', 'or']   en
# 128                                                 NaN   en
# 129                               ['agriculture', 'or']   en
# 130                                              ['or']   en
# 131                                              ['or']   en
# 132                               ['agriculture', 'or']   en
# 133                                ['funding', 'green']   en
# 134                                              ['or']   en
# 135                                                 NaN   en
# 136                         ['climate', 'or', 'climat']   en
# 137                                                 NaN   en
# 138                                              ['or']   en
# 139                                           ['local']   en
# 140                                          ['health']   en
# 141                                      ['park', 'or']   en
# 142                                              ['or']   en
# 143                                              ['or']   en
# 144                                            ['safe']   en
# 145                                           ['money']   en
# 146                                           ['water']   en
# 147                        ['agriculture', 'or', 'mer']   en
# 148                                       ['or', 'mer']   en
# 149                                              ['or']   en
# 150                               ['agriculture', 'or']   en
# 151                               ['agriculture', 'or']   en
# 152                               ['agriculture', 'or']   en
# 153                                              ['or']   en
# 154                        ['agriculture', 'or', 'mer']   en
# 155                                             ['oil']   en
# 156                                                 NaN   en
# 157                                                 NaN   tl
# 158                        ['agriculture', 'or', 'mer']   en
# 159                ['sustainable', 'agriculture', 'or']   en
# 160                                                 NaN   en
# 161                                       ['or', 'ice']   en
# 162                                                 NaN   tl
# 163                                       ['footprint']   en
# 164                                     ['agriculture']   en
# 165                                       ['or', 'mer']   en
# 166                                                 NaN   tl
# 167                               ['agriculture', 'or']   en
# 168                                   ['import', 'oil']   en
# 169                                                 NaN   en
# 170                                          ['health']   en
# 171                                 ['future', 'futur']   en
# 172                                       ['or', 'mer']   en
# 173                                              ['or']   en
# 174                                              ['or']   en
# 175                                              ['or']   en
# 176                              ['health', 'healthy ']   en
# 177                                              ['or']   en
# 178                                          ['health']   en
# 179                                              ['or']   en
# 180                        ['agriculture', 'or', 'mer']   en
# 181                                                 NaN   en
# 182                                              ['or']   en
# 183                                             ['mer']   en
# 184                            ['farming', 'or', 'mer']   en
# 185                                              ['or']   en
# 186                                                 NaN   en
# 187                                ['funding', 'green']   en
# 188                                              ['or']   en
# 189                                ['or', 'ice', 'air']   en
# 190                                          ['policy']   en
# 191                                              ['or']   en
# 192                               ['agriculture', 'or']   en
# 193                                              ['or']   en
# 194                               ['agriculture', 'or']   en
# 195                                             ['oil']   en
# 196                                              ['or']   en
# 197                                              ['or']   en
# 198                                           ['local']   en
# 199                                   ['farming', 'or']   en
# 200                                             ['air']   en
# 201                                          ['import']   en
# 202                                          ['policy']   en
# 203                               ['agriculture', 'or']   en
# 204                                       ['or', 'mer']   en
# 205                ['sustainable', 'agriculture', 'or']   en
# 206                                   ['green', 'jobs']   en
# 207                                              ['or']   en
# 208                                       ['or', 'mer']   en
# 209                  ['agri-food', 'agriculture', 'or']   en
# 210                                              ['or']   en
# 211                                                 NaN   tl
# 212                                       ['or', 'mer']   en
# 213                                     ['water', 'or']   en
# 214                                             ['air']   en
# 215                                                 NaN   en
# 216                                              ['or']   en
# 217                         ['climate', 'or', 'climat']   en
# 218                                              ['or']   en
# 219           ['agri-food', 'agriculture', 'or', 'mer']   en
# 220                                             ['oil']   en
# 221                                          ['friend']   en
# 222                                                 NaN   tl
# 223                                              ['or']   en
# 224                                                 NaN   en
# 225                                                 NaN   en
# 226                                ['mer', 'or', 'air']   en
# 227                            ['diversity', 'library']   en
# 228                                          ['health']   en
# 229                                       ['or', 'ice']   en
# 230                                              ['or']   en
# 231                                          ['policy']   en
# 232                                              ['or']   en
# 233                                          ['health']   en
# 234                                                 NaN   tl
# 235          ['policy', 'import', 'summit', 'minister']   en
# 236                                              ['or']   en
# 237                                              ['or']   en
# 238                                       ['or', 'mer']   en
# 239                                              ['or']   en
# 240                              ['conservation', 'or']   en
# 241                                             ['mer']   en
# 242                                          ['policy']   en
# 243                ['sustainable', 'agriculture', 'or']   en
# 244                                       ['or', 'mer']   en
# 245                                       ['or', 'mer']   en
# 246                                              ['or']   en
# 247                                                 NaN   en
# 248                                              ['or']   en
# 249                    ['federal', 'culture', 'health']   en
# 250                         ['climate', 'or', 'climat']   en
# 251                                             ['mer']   en
# 252                                            ['safe']   en
# 253                                                 NaN   en
# 254                                          ['health']   en
# 255                        ['agriculture', 'or', 'ice']   en
# 256                                          ['health']   en
# 257                               ['agriculture', 'or']   en
# 258                                   ['ami', 'family']   en
# 259                                       ['or', 'mer']   en
# 260              ['gas', 'or', 'greenhouse gas', 'air']   en
# 261                                                 NaN   en
# 262                              ['health', 'healthy ']   en
# 263                                                 NaN   en
# 264                                             ['oil']   en
# 265                                                 NaN   en
# 266       ['conservation', 'agriculture', 'or', 'gold']   en
# 267                               ['agriculture', 'or']   en
# 268                                                 NaN   tl
# 269                                                 NaN   en
# 270                                                 NaN   tl
# 271                 ['diversity', 'health', 'healthy ']   en
# 272                               ['agriculture', 'or']   en
# 273                               ['agriculture', 'or']   en
# 274                        ['invest', 'infrastructure']   en
# 275                                                 NaN   tl
# 276                                                 NaN   en
# 277                                              ['or']   en
# 278                                              ['or']   en
# 279                                              ['or']   en
# 280                     ['gas', 'or', 'greenhouse gas']   en
# 281                                              ['or']   en
# 282                                             ['mer']   en
# 283                                                 NaN   tl
# 284                                      ['innovation']   en
# 285                                                 NaN   en
# 286                                 ['future', 'futur']   en
# 287                                                 NaN   en
# 288                                              ['or']   en
# 289                         ['mer', 'or', 'ice', 'air']   en
# 290                                          ['policy']   en
# 291                                                 NaN   en
# 292                              ['agriculture', 'ice']   en
# 293                                          ['health']   en
# 294                                             ['mer']   en
# 295                                            ['safe']   en
# 296                                              ['or']   en
# 297                               ['agriculture', 'or']   en
# 298                                            ['safe']   en
# 299                                      ['tree', 'or']   en
# 300                                                 NaN   en
# 301                                              ['or']   en
# 302                               ['agriculture', 'or']   en
# 303                                              ['or']   en
# 304                                                 NaN   en
# 305                                       ['or', 'air']   en
# 306                                              ['or']   en
# 307                                                 NaN   en
# 308                                       ['or', 'air']   en
# 309                               ['agriculture', 'or']   en
# 310                                              ['or']   en
# 311                    ['future', 'diversity', 'futur']   en
# 312                                              ['or']   en
# 313                               ['agriculture', 'or']   en
# 314                                              ['or']   en
# 315                                       ['or', 'mer']   en
# 316                              ['health', 'healthy ']   en
# 317                                          ['friend']   en
# 318                                     ['water', 'or']   en
# 319                                       ['or', 'ice']   en
# 320                                              ['or']   en
# 321                                     ['tree', 'mer']   en
# 322                                              ['or']   en
# 323                     ['gas', 'or', 'greenhouse gas']   en
# 324                                             ['oil']   en
# 325                            ['global', 'innovation']   en
# 326                           ['farming', 'ice', 'mer']   en
# 327                                     ['agriculture']   en
# 328                                       ['diversity']   en
# 329                                          ['health']   en
# 330                               ['agriculture', 'or']   en
# 331                  ['agri-food', 'agriculture', 'or']   en
# 332                                ['mer', 'or', 'air']   en
# 333                                       ['or', 'mer']   en
# 334                               ['agriculture', 'or']   en
# 335                                     ['agriculture']   en
# 336             ['gas', 'emissions ', 'greenhouse gas']   en
# 337                                                 NaN   en
# 338                               ['agriculture', 'or']   en
# 339                                              ['or']   en
# 340                                   ['species', 'or']   en
# 341                                       ['or', 'air']   en
# 342                         ['climate', 'or', 'climat']   en
# 343                               ['agriculture', 'or']   en
# 344                                          ['health']   en
# 345                                ['policy', 'import']   en
# 346                                          ['friend']   en
# 347                               ['agriculture', 'or']   en
# 348                                       ['or', 'mer']   en
# 349                                                 NaN   en
# 350                                     ['agriculture']   en
# 351                                     ['agriculture']   en
# 352                                       ['or', 'mer']   en
# 353                               ['agriculture', 'or']   en
# 354                               ['agriculture', 'or']   en
# 355                                       ['or', 'mer']   en
# 356                        ['agriculture', 'or', 'air']   en
# 357                                            ['safe']   en
# 358                               ['agriculture', 'or']   en
# 359                                              ['or']   en
# 360                                              ['or']   en
# 361                                              ['or']   en
# 362                  ['agri-food', 'agriculture', 'or']   en
# 363                        ['agriculture', 'or', 'mer']   en
# 364                        ['agri-food', 'agriculture']   en
# 365                                          ['health']   en
# 366                              ['policy', 'minister']   en
# 367                                              ['or']   en
# 368                                              ['or']   en
# 369                               ['agriculture', 'or']   en
# 370                               ['agriculture', 'or']   en
# 371                        ['gas', 'agriculture', 'or']   en
# 372                                     ['agriculture']   en
# 373                                                 NaN   en
# 374                                             ['ami']   en
# 375             ['growth', 'partnership', 'innovation']   en
# 376                               ['agriculture', 'or']   en
# 377                                   ['ami', 'family']   en
# 378                                              ['or']   en
# 379                                              ['or']   en
# 380                                                 NaN   en
# 381                                    ['plants', 'or']   en
# 382                                              ['or']   en
# 383                                                 NaN   tl
# 384                               ['tree', 'or', 'mer']   en
# 385                               ['agriculture', 'or']   en
# 386                                              ['or']   en
# 387                            ['natural', 'or', 'mer']   en
# 388                                 ['future', 'futur']   en
# 389                                             ['air']   en
# 390                                          ['import']   en
# 391                                          ['plants']   en
# 392                            ['farming', 'or', 'mer']   en
# 393                                   ['ami', 'family']   en
# 394                                       ['or', 'mer']   en
# 395                                           ['green']   en
# 396                                              ['or']   en
# 397                                      ['population']   en
# 398                                              ['or']   en
# 399                                       ['or', 'mer']   en
# 400                                              ['or']   en
# 401                                       ['eau', 'or']   en
# 402              ['climate', 'species', 'climat', 'or']   en
# 403                       ['ami', 'health', 'healthy ']   en
# 404                               ['agriculture', 'or']   en
# 405                                              ['or']   en
# 406                ['sustainable', 'agriculture', 'or']   en
# 407                                      ['innovation']   en
# 408                        ['agriculture', 'or', 'mer']   en
# 409                                      ['innovation']   en
# 410                                       ['or', 'air']   en
# 411                                              ['or']   en
# 412                                       ['or', 'mer']   en
# 413                               ['agriculture', 'or']   en
# 414                                              ['or']   en
# 415                                              ['or']   en
# 416                                   ['green', 'jobs']   en
# 417                                              ['or']   en
# 418                                       ['or', 'ice']   en
# 419                                                 NaN   en
# 420                ['sustainable', 'agriculture', 'or']   en
# 421                                              ['or']   en
# 422                                                 NaN   en
# 423                                              ['or']   en
# 424                              ['health', 'healthy ']   en
# 425                                       ['or', 'mer']   en
# 426                         ['climate', 'or', 'climat']   en
# 427                                              ['or']   en
# 428                                   ['ami', 'family']   en
# 429                                              ['or']   en
# 430                                       ['or', 'mer']   en
# 431                                                 NaN   en
# 432                                          ['plants']   en
# 433                                              ['or']   en
# 434                                              ['or']   en
# 435                                       ['or', 'air']   en
# 436                                                 NaN   tl
# 437                        ['agriculture', 'or', 'air']   en
# 438                                ['mer', 'or', 'air']   en
# 439                                     ['agriculture']   en
# 440                                 ['future', 'futur']   en
# 441                                                 NaN   tl
# 442                                      ['ice', 'mer']   en
# 443                                                 NaN   en
# 444                                                 NaN   en
# 445                                              ['or']   en
# 446                                           ['local']   en
# 447                                       ['or', 'ice']   en
# 448                                                 NaN   en
# 449                        ['agriculture', 'or', 'mer']   en
# 450                                              ['or']   en
# 451                               ['agriculture', 'or']   en
# 452                  ['agri-food', 'agriculture', 'or']   en
# 453                ['coast', 'mer', 'or', 'ice', 'air']   en
# 454                 ['climate', 'park', 'or', 'climat']   en
# 455                                             ['oil']   en
# 456                               ['policy', 'funding']   en
# 457                         ['plants', 'natural', 'or']   en
# 458                                       ['or', 'mer']   en
# 459                                             ['air']   en
# 460                               ['agriculture', 'or']   en
# 461                ['sustainable', 'agriculture', 'or']   en
# 462                                ['invest', 'income']   en
# 463                                              ['or']   en
# 464                     ['technologies', 'technologie']   en
# 465                                       ['or', 'air']   en
# 466                                                 NaN   en
# 467                               ['agriculture', 'or']   en
# 468                                    ['water', 'mer']   en
# 469                                              ['or']   en
# 470                                                 NaN   en
# 471                                              ['or']   en
# 472                         ['climate', 'or', 'climat']   en
# 473                                              ['or']   en
# 474                       ['culture', 'safe', 'health']   en
# 475                                             ['oil']   en
# 476                                                 NaN   en
# 477                                              ['or']   en
# 478                                              ['or']   en
# 479                                                 NaN   en
# 480                                     ['agriculture']   en
# 481                                              ['or']   en
# 482                                                 NaN   en
# 483                        ['agriculture', 'or', 'mer']   en
# 484                         ['climate', 'or', 'climat']   en
# 485                               ['agriculture', 'or']   en
# 486                                             ['oil']   en
# 487                                      ['mer', 'air']   en
# 488                                                 NaN   en
# 489                                       ['or', 'mer']   en
# 490                                              ['or']   en
# 491                                                 NaN   tl
# 492                                          ['friend']   en
# 493                               ['agriculture', 'or']   en
# 494                              ['agriculture', 'ice']   en
# 495                                              ['or']   en
# 496                                                 NaN   tl
# 497                                           ['women']   en
# 498                                            ['gold']   en
# 499                  ['agri-food', 'agriculture', 'or']   en
# ...                                                 ...  ...
# 584                                              ['or']   en
# 585                               ['import', 'imports']   en
# 586                                          ['health']   en
# 587                               ['agriculture', 'or']   en
# 588                                              ['or']   en
# 589                  ['climate', 'or', 'climat', 'air']   en
# 590                                          ['friend']   en
# 591           ['agri-food', 'agriculture', 'or', 'mer']   en
# 592                                          ['invest']   en
# 593                                          ['policy']   en
# 594                                             ['mer']   en
# 595                                          ['policy']   en
# 596                         ['climate', 'or', 'climat']   en
# 597                                              ['or']   en
# 598                                              ['or']   en
# 599                                                 NaN   en
# 600                                     ['or', 'clean']   en
# 601                                           ['green']   en
# 602                                                 NaN   en
# 603                                                 NaN   en
# 604                                             ['oil']   en
# 605                                              ['or']   en
# 606                                             ['air']   en
# 607                       ['natural', 'conserve', 'or']   en
# 608                              ['import', 'minister']   en
# 609                                      ['commission']   en
# 610                               ['agriculture', 'or']   en
# 611                                              ['or']   en
# 612                                              ['or']   en
# 613                                       ['or', 'air']   en
# 614                                                 NaN   en
# 615                                          ['friend']   en
# 616                               ['agriculture', 'or']   en
# 617                  ['agri-food', 'agriculture', 'or']   en
# 618                                      ['ice', 'mer']   en
# 619                                          ['policy']   en
# 620                           ['culture', 'indigenous']   en
# 621                         ['plants', 'natural', 'or']   en
# 622                                       ['or', 'air']   en
# 623                                       ['or', 'air']   en
# 624                                ['or', 'ice', 'mer']   en
# 625                                       ['or', 'mer']   en
# 626           ['agri-food', 'agriculture', 'or', 'mer']   en
# 627                                                 NaN   tl
# 628                                                 NaN   en
# 629                                          ['planet']   en
# 630                                                 NaN   en
# 631                               ['agriculture', 'or']   en
# 632                                              ['or']   en
# 633                                              ['or']   en
# 634                                              ['or']   en
# 635                                                 NaN   en
# 636                        ['agri-food', 'agriculture']   en
# 637                                ['or', 'government']   en
# 638                                                 NaN   en
# 639                                                 NaN   tl
# 640                                     ['agriculture']   en
# 641                            ['import', 'government']   en
# 642                                       ['or', 'mer']   en
# 643                                             ['ami']   en
# 644                    ['farming', 'agriculture', 'or']   en
# 645                                          ['policy']   en
# 646                                                 NaN   en
# 647                                          ['planet']   en
# 648                                                 NaN   en
# 649                                             ['mer']   en
# 650                                 ['agri-food', 'or']   en
# 651                                                 NaN   en
# 652                                       ['or', 'ice']   en
# 653                                              ['or']   en
# 654                                                 NaN   en
# 655                               ['agriculture', 'or']   en
# 656                ['coast', 'mer', 'or', 'ice', 'air']   en
# 657                                              ['or']   en
# 658                                       ['or', 'mer']   en
# 659                                       ['footprint']   en
# 660                      ['culture', 'future', 'futur']   en
# 661                                       ['or', 'mer']   en
# 662                                                 NaN   en
# 663                                          ['import']   en
# 664                                              ['or']   en
# 665                                              ['or']   en
# 666                              ['health', 'healthy ']   en
# 667                                          ['policy']   en
# 668                      ['culture', 'future', 'futur']   en
# 669                                       ['or', 'mer']   en
# 670                                                 NaN   en
# 671                                                 NaN   en
# 672                                                 NaN   en
# 673           ['ami', 'culture', 'community', 'family']   en
# 674                                       ['or', 'ice']   en
# 675                               ['agriculture', 'or']   en
# 676                                       ['agri-food']   en
# 677                                              ['or']   en
# 678                                                 NaN   en
# 679                               ['import', 'imports']   en
# 680                                              ['or']   en
# 681                                          ['invest']   en
# 682                                                 NaN   en
# 683                                              ['or']   en
# 684                                          ['policy']   en
# 685                                                 NaN   en
# 686                                 ['agri-food', 'or']   en
# 687                            ['farming', 'or', 'ice']   en
# 688                                 ['or', 'resources']   en
# 689                                                 NaN   en
# 690                                       ['or', 'mer']   en
# 691   ['climate', 'climat', 'climate change', 'gas',...   en
# 692                                             ['mer']   en
# 693                 ['students', 'local', 'indigenous']   en
# 694                        ['agriculture', 'or', 'mer']   en
# 695                                                 NaN   tl
# 696                                                 NaN   tl
# 697                                              ['or']   en
# 698                              ['conservation', 'or']   en
# 699                                       ['or', 'mer']   en
# 700                                                 NaN   tl
# 701                                       ['or', 'mer']   en
# 702                                          ['planet']   en
# 703                                     ['agriculture']   en
# 704                                              ['or']   en
# 705                     ['technologies', 'technologie']   en
# 706                               ['agriculture', 'or']   en
# 707                                              ['or']   en
# 708                                       ['or', 'air']   en
# 709                                       ['or', 'mer']   en
# 710                                ['mer', 'or', 'air']   en
# 711                                              ['or']   en
# 712                               ['agriculture', 'or']   en
# 713                                             ['air']   en
# 714                                                 NaN   en
# 715                  ['agriculture', 'or', 'resources']   en
# 716                        ['gas', 'agriculture', 'or']   en
# 717                                             ['mer']   en
# 718                                              ['or']   en
# 719                                ['or', 'ice', 'air']   en
# 720                                              ['or']   en
# 721                  ['agri-food', 'agriculture', 'or']   en
# 722                                             ['ice']   en
# 723                                              ['or']   en
# 724                                          ['planet']   en
# 725                         ['climate', 'or', 'climat']   en
# 726                  ['agri-food', 'agriculture', 'or']   en
# 727                                      ['ice', 'mer']   en
# 728                                                 NaN   en
# 729                                      ['tree', 'or']   en
# 730                                ['or', 'ice', 'air']   en
# 731            ['technologie', 'technologies', 'green']   en
# 732                         ['climate', 'or', 'climat']   en
# 733                                              ['or']   en
# 734                                          ['import']   en
# 735                                              ['or']   en
# 736                                     ['agriculture']   en
# 737                                                 NaN   en
# 738                                          ['health']   en
# 739                                              ['or']   en
# 740                                              ['or']   en
# 741                                              ['or']   en
# 742                                         ['farming']   en
# 743                                 ['agri-food', 'or']   en
# 744                                                 NaN   en
# 745                                       ['or', 'mer']   en
# 746                                              ['or']   en
# 747       ['gas', 'emissions ', 'greenhouse gas', 'or']   en
# 748                                              ['or']   en
# 749                                      ['commission']   en
# 750                                       ['or', 'mer']   en
# 751                                 ['future', 'futur']   en
# 752                                                 NaN   en
# 753                                                 NaN   tl
# 754                               ['agriculture', 'or']   en
# 755                                     ['or', 'coast']   en
# 756       ['gas', 'emissions ', 'greenhouse gas', 'or']   en
# 757                         ['climate', 'or', 'climat']   en
# 758                                                 NaN   tl
# 759                                                 NaN   tl
# 760                                          ['health']   en
# 761                                                 NaN   en
# 762                                              ['or']   en
# 763                                           ['women']   en
# 764                      ['culture', 'future', 'futur']   en
# 765                                              ['or']   en
# 766                                       ['or', 'ice']   en
# 767                                              ['or']   en
# 768                                              ['or']   en
# 769                                      ['innovation']   en
# 770           ['agri-food', 'agriculture', 'or', 'air']   en
# 771                                           ['women']   en
# 772                                              ['or']   en
# 773                                                 NaN   tl
# 774                                         ['farming']   en
# 775                                                 NaN   en
# 776                                      ['innovation']   en
# 777                                                 NaN   tl
# 778                                       ['footprint']   en
# 779                                          ['health']   en
# 780                                              ['or']   en
# 781                                          ['summit']   en
# 782                                                 NaN   en
# 783                                      ['innovative']   en
# 784                                                 NaN   en
# 785                                       ['or', 'air']   en
# 786                                         ['federal']   en
# 787                                                 NaN   tl
# 788                                 ['or', 'resources']   en
# 789                                          ['invest']   en
# 790                                       ['or', 'air']   en
# 791                                      ['innovation']   en
# 792                                                 NaN   en
# 793                                          ['policy']   en
# 794                                          ['policy']   en
# 795                                              ['or']   en
# 796                               ['agriculture', 'or']   en
# 797                         ['mer', 'or', 'government']   en
# 798                                                 NaN   en
# 799                                 ['agri-food', 'or']   en
# 800                                              ['or']   en
# 801                        ['gas', 'agriculture', 'or']   en
# 802                                              ['or']   en
# 803                                      ['innovation']   en
# 804                                              ['or']   en
# 805                        ['agriculture', 'or', 'mer']   en
# 806                                              ['or']   en
# 807                                     ['agriculture']   en
# 808                                       ['or', 'mer']   en
# 809                                     ['partnership']   en
# 810                                                 NaN   en
# 811                                                 NaN   en
# 812                                              ['or']   en
# 813                                   ['farming', 'or']   en
# 814   ['climate', 'climat', 'government', 'mer', 'ag...   en
# 815                                      ['commission']   en
# 816                                                 NaN   tl
# 817                                       ['or', 'ice']   en
# 818           ['ami', 'culture', 'community', 'family']   en
# 819                                              ['or']   en
# 820                               ['agriculture', 'or']   en
# 821                                                 NaN   en
# 822                                                 NaN   tl
# 823                                       ['or', 'air']   en
# 824                                 ['agri-food', 'or']   en
# 825                                              ['or']   en
# 826                                   ['species', 'or']   en
# 827                                                 NaN   en
# 828                                              ['or']   en
# 829                                ['gas', 'or', 'ice']   en
# ...
# 2887                                                 []        unknown
# 2888                                                 []        unknown
# 2889                                                 []        unknown
# 2890                                                 []        unknown
# 2891                                                 []        unknown
# 2892                                                 []        unknown
# 2893                                                 []        unknown
# 2894                                                 []        unknown
# 2895                                                 []        unknown
# 2896                                                 []        unknown
# 2897                           [energy, energy, energy]     Economical
# 2898                                                 []        unknown
# 2899                                          [archive]         Social
# 2900                                                 []        unknown
# 2901                                                 []        unknown
# 2902                                                 []        unknown
# 2903                                                 []        unknown
# 2904                                           [policy]     Economical
# 2905                                                 []        unknown
# 2906                                           [income]     Economical
# 2907                                                 []        unknown
# 2908                                                 []        unknown
# 2909                                                 []        unknown
# 2910                                                 []        unknown
# 2911                                                 []        unknown
# 2912                                                 []        unknown
# 2913                                           [health]         Social
# 2914                                                 []        unknown
# 2915                                                 []        unknown
# 2916                                                 []        unknown
# 2917                                                 []        unknown
# 2918                                                 []        unknown
# 2919                                           [policy]     Economical
# 2920                                                 []        unknown
# 2921                                                 []        unknown
# 2922                                                 []        unknown
# 2923                                                 []        unknown
# 2924                                                 []        unknown
# 2925                                                 []        unknown
# 2926                                                 []        unknown
# 2927                                                 []        unknown
# 2928                                                 []        unknown
# 2929                                         [resource]  Environmental
# 2930                                                 []        unknown
# 2931                                                 []        unknown
# 2932                                                 []        unknown
# 2933                                                 []        unknown
# 2934                                                 []        unknown
# 2935                                                 []        unknown
# 2936                                                 []        unknown
# 2937                                                 []        unknown
# 2938                                                 []        unknown
# 2939                                           [family]         Social
# 2940                                                 []        unknown
# 2941                                                 []        unknown
# 2942                                                 []        unknown
# 2943                                                 []        unknown
# 2944                         [greenhouse_gas, emission]  Environmental
# 2945                                           [specie]  Environmental
# 2946                                                 []        unknown
# 2947                                                 []        unknown
# 2948                        [funding, carbon, emission]  Environmental
# 2949                                                 []        unknown
# 2950                                                 []        unknown
# 2951                                                 []        unknown
# 2952                                                 []        unknown
# 2953                                       [commission]     Economical
# 2954                                           [income]     Economical
# 2955                                                 []        unknown
# 2956                                                 []        unknown
# 2957                                                 []        unknown
# 2958                                                 []        unknown
# 2959                                                 []        unknown
# 2960                                                 []        unknown
# 2961                                                 []        unknown
# 2962                                                 []        unknown
# 2963                                                 []        unknown
# 2964                                                 []        unknown
# 2965                                                 []        unknown
# 2966                                                 []        unknown
# 2967                                                 []        unknown
# 2968                                                 []        unknown
# 2969                                              [job]     Economical
# 2970                                                 []        unknown
# 2971                                                 []        unknown
# 2972                                                 []        unknown
# 2973                                                 []        unknown
# 2974                                                 []        unknown
# 2975                                                 []        unknown
# 2976                                                 []        unknown
# 2977                                                 []        unknown
# 2978                                                 []        unknown
# 2979                                                 []        unknown
# 2980                                                 []        unknown
# 2981                                                 []        unknown
# 2982                                                 []        unknown
# 2983                                         [resource]  Environmental
# 2984                                                 []        unknown
# 2985                                           [growth]     Economical
# 2986                                                 []        unknown
# 2987                                             [safe]         Social
# 2988                                                 []        unknown
# 2989                                                 []        unknown
# 2990                                                 []        unknown
# 2991                                           [health]         Social
# 2992                                                 []        unknown
# 2993                                                 []        unknown
# 2994                                                 []        unknown
# 2995                                                 []        unknown
# 2996                                         [resource]  Environmental
# 2997                                                 []        unknown
# 2998                                                 []        unknown
# 2999                                                 []        unknown
# 3000                                           [invest]     Economical
# 3001                                                 []        unknown
# 3002                                 [funding, student]         Social
# 3003                                      [sustainable]  Environmental
# 3004                                                 []        unknown
# 3005                                                 []        unknown
# 3006                                                 []        unknown
# 3007                                           [health]         Social
# 3008                                                 []        unknown
# 3009                                                 []        unknown
# 3010                                                 []        unknown
# 3011                                                 []        unknown
# 3012                                       [commission]     Economical
# 3013                                                 []        unknown
# 3014                                                 []        unknown
# 3015                                                 []        unknown
# 3016                                                 []        unknown
# 3017                                                 []        unknown
# 3018                                                 []        unknown
# 3019                                       [commission]     Economical
# 3020                                                 []        unknown
# 3021                                                 []        unknown
# 3022                                                 []        unknown
# 3023                                                 []        unknown
# 3024                                                 []        unknown
# 3025                                                 []        unknown
# 3026                                                 []        unknown
# 3027                                [library, resource]         Social
# 3028                                                 []        unknown
# 3029                                                 []        unknown
# 3030                                                 []        unknown
# 3031                                                 []        unknown
# 3032                                                 []        unknown
# 3033                                                 []        unknown
# 3034                                                 []        unknown
# 3035                                           [health]         Social
# 3036                                                 []        unknown
# 3037                                                 []        unknown
# 3038                                                 []        unknown
# 3039                                                 []        unknown
# 3040                                                 []        unknown
# 3041                                                 []        unknown
# 3042                                                 []        unknown
# 3043                                                 []        unknown
# 3044                                          [farming]  Environmental
# 3045                                         [minister]     Economical
# 3046                                           [growth]     Economical
# 3047                                                 []        unknown
# 3048                                                 []        unknown
# 3049                                                 []        unknown
# 3050                                                 []        unknown
# 3051                                                 []        unknown
# 3052                                                 []        unknown
# 3053                                            [right]     Economical
# 3054                                                 []        unknown
# 3055                                                 []        unknown
# 3056                                                 []        unknown
# 3057                                                 []        unknown
# 3058                                                 []        unknown
# 3059                                                 []        unknown
# 3060                                    [plant, health]         Social
# 3061                                                 []        unknown
# 3062                                                 []        unknown
# 3063                                                 []        unknown
# 3064                                                 []        unknown
# 3065                                                 []        unknown
# 3066                                                 []        unknown
# 3067                                                 []        unknown
# 3068                                                 []        unknown
# 3069                                                 []        unknown
# 3070                                                 []        unknown
# 3071                                                 []        unknown
# 3072                                           [global]     Economical
# 3073                                                 []        unknown
# 3074                                                 []        unknown
# 3075                                                 []        unknown
# 3076                                                 []        unknown
# 3077                                                 []        unknown
# 3078                                           [global]     Economical
# 3079                                                 []        unknown
# 3080                                                 []        unknown
# 3081                                                 []        unknown
# 3082                                           [health]         Social
# 3083                                                 []        unknown
# 3084                                                 []        unknown
# 3085                                                 []        unknown
# 3086                                                 []        unknown
# 3087                                                 []        unknown
# 3088                           [material, biodiversity]     Economical
# 3089                                            [right]     Economical
# 3090                                                 []        unknown
# 3091                                                 []        unknown
# 3092                                          [funding]     Economical
# 3093                                         [resource]  Environmental
# 3094                                                 []        unknown
# 3095                                                 []        unknown
# 3096                                                 []        unknown
# 3097                                                 []        unknown
# 3098                                                 []        unknown
# 3099                                                 []        unknown
# 3100                                                 []        unknown
# 3101                                                 []        unknown
# 3102                                                 []        unknown
# 3103                                                 []        unknown
# 3104                                                 []        unknown
#
# [3105 rows x 4 columns]
