# %%
import glob
import os
import sys
import pandas as pd
import nltk
#nltk.download()   # comment after first download
from nltk.tokenize import MWETokenizer
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
import string
from numbers import Number
from pprint import pprint
import logging
import operator

pd.options.display.max_rows = 10

# %%
en_file = './Accounts/q3q4_output/*.csv'

keywords_chosen = '13_FSDS_Goals_Keywords_EN.csv'

OUTPUT_COLS = ['id', 'num_comments', 'num_shares',
               'num_angrys', 'num_hahas', 'num_likes', 'num_loves', 'num_sads',
                'num_special', 'num_wows', 'Reactions_SUM', 
               'FSDS_matched_keywords', 'FSDS_category']

# %%
# read all accounts csv files and save chosen columns to dataframe
filePaths = glob.glob(en_file)
data_df = pd.DataFrame(columns=OUTPUT_COLS)
for filename in filePaths:
    #print(filename)    
    df_i = pd.read_csv(filename, encoding = 'utf-8')
    data_df = data_df.append(df_i, ignore_index=True)

data_df = data_df[OUTPUT_COLS]
data_df
# Out:
#                                    id num_comments num_shares num_angrys  \
# 0      318424514044_10154848488474045           49        353          0
# 1      318424514044_10155396901694045          695        129         25
# 2      318424514044_10154830856069045           20         81          0
# 3      318424514044_10154700497599045           47        142          1
# 4      318424514044_10154771845659045           28        151          0
# ...                               ...          ...        ...        ...
# 46814             2017-10-04_08-22-12            0        NaN        NaN
# 46815             2016-12-08_08-45-08            0        NaN        NaN
# 46816             2016-12-08_08-20-07            0        NaN        NaN
# 46817             2016-12-08_08-17-30            0        NaN        NaN
# 46818             2016-12-08_08-15-13            0        NaN        NaN
#
#       num_hahas num_likes num_loves num_sads num_special num_wows  \
# 0             1      3005        67        0           0        6
# 1             7       214        48       11           0       10
# 2             0       929        63        0           0        4
# 3             1       612        14        0           0        3
# 4            14       603        16        0           0        1
# ...         ...       ...       ...      ...         ...      ...
# 46814       NaN         3       NaN      NaN         NaN      NaN
# 46815       NaN         3       NaN      NaN         NaN      NaN
# 46816       NaN         2       NaN      NaN         NaN      NaN
# 46817       NaN         1       NaN      NaN         NaN      NaN
# 46818       NaN         1       NaN      NaN         NaN      NaN
#
#       Reactions_SUM                              FSDS_matched_keywords  \
# 0              3481                                                 []
# 1              1139                                                 []
# 2              1097                                                 []
# 3               820                     ['development', 'development']
# 4               813                     ['development', 'development']
# ...             ...                                                ...
# 46814             3                                                 []
# 46815             3  ['infrastructure', 'gas', 'vehicle', 'electric...
# 46816             2                                        ['economy']
# 46817             1                            ['mountain', 'economy']
# 46818             1                            ['mountain', 'economy']
#
#                FSDS_category
# 0                    unknown
# 1                    unknown
# 2                    unknown
# 3               Clean growth
# 4               Clean growth
# ...                      ...
# 46814                unknown
# 46815  Low-carbon government
# 46816           Clean growth
# 46817           Clean growth
# 46818           Clean growth
#
# [46819 rows x 13 columns]

# %%
# set of punctuations to remove from text
exclude = set(string.punctuation)

stopWords = set(stopwords.words('english'))

lemma = WordNetLemmatizer()    # NLTK English lemmatizer

# detect_lang function can be use to check the percentage of non English posts
# note that missing value NaN can be detected as many different languages such english, spanish or italian
def detect_lang(text):
    try:
        lang = detect(text)
    except:
        return 'error'
    return lang

# lemmatize_keywords also clears 'nan' from input keyword list file
# lemmatization is conducted based on context, some words may not get lemmatized, 
# e.g. "local eating" does not get lemmatized to "local eat"
def lemmatize_keywords(col):
    if str(col).lower() == 'nan':
        return ''
    return '_'.join(lemma.lemmatize(word).lower() for word in col.replace('’', '\'').replace('.', '').split()) #

# %%
# load keywords list

keywords_df = pd.read_csv(keywords_chosen, encoding='latin-1')   # "ISO-8859-1"
KEYWORDS_COLS = keywords_df.columns
lemma_keywords_df = pd.DataFrame(columns=KEYWORDS_COLS)
category_dict = {}
keywords_list = set()
for col in KEYWORDS_COLS:
    lemma_keywords_df[col] = keywords_df[col].astype(str).apply(lemmatize_keywords)
    category_dict[col.lower()] = set(lemma_keywords_df[col].tolist())
    category_dict[col.lower()].remove('')
    keywords_list = keywords_list.union(category_dict[col.lower()])

# the following is meant to clean a column name
try:
    category_dict['connecting canadians with nature'] = category_dict['connecting canadians with nature ']
    del category_dict['connecting canadians with nature ']
except:
    pass

# %%
category_dict
# Out:
# {'clean drinking water': {'accessible',
#   'affordable',
#   'aquifer',
#   'boil_water',
#   'clean',
#   'drinking',
#   'dumping',
#   'first_nation',
#   'flow',
#   'forum_for_leadership_on_water',
#   'fresh_water',
#   'freshwater',
#   'health',
#   'hygiene',
#   'indigenous_land',
#   'lake',
#   'municipality',
#   'on-reserve',
#   'phoshporus',
#   'public_health',
#   'river',
#   'sanitation',
#   'untreated_wastewater',
#   'wastewater',
#   'wastewater_treatment',
#   'water',
#   'water-related',
#   'water-use',
#   'water_advisory',
#   'water_contamination',
#   'water_harvesting',
#   'water_infrastructure',
#   'water_pollution',
#   'water_resource_management',
#   'water_scarcity',
#   'water_supply',
#   'water_system',
#   'wetland'},
#  'clean energy': {'clean_energy',
#   'clean_power_generation',
#   'clean_technology',
#   'cleaner_fossil-fuel',
#   'cleanest_electricity_system',
#   'coalfired_electricity',
#   'diesel',
#   'electricity',
#   'electricity_generation',
#   'energy',
#   'energy_efficiency',
#   'energy_solution',
#   'gas',
#   'global_energy_mix',
#   'heat',
#   'investment_in_energy',
#   'oil',
#   'renewable_elctricity_capacity',
#   'renewable_energy',
#   'solar_panel'},
#  'clean growth': {'clean_job',
#   'clean_technology',
#   'clean_technology_sector',
#   'development',
#   'economy',
#   'greenhouse_gas',
#   'growth',
#   'habibtat',
#   'marine',
#   'reduce_ghg'},
#  'connecting canadians with nature': {'biosphere',
#   'camping',
#   'community',
#   'connecting',
#   'conservation',
#   'engagement',
#   'experience_nature',
#   'federal_protected_area',
#   'get_involved',
#   'green_space',
#   'hiking',
#   'municipal_park',
#   'national_marine',
#   'national_park',
#   'national_wildlife',
#   'nature',
#   'nature-based_activity',
#   'park',
#   'physical',
#   'protect_the_enivronment',
#   'stewardship',
#   'tourism',
#   'urban_canadian'},
#  'effective action on climate change': {'building_retrofit',
#   "canada's_action_plan",
#   'carbon_pricing_leadership_coalition',
#   'carbon_sink',
#   'change-related_planning',
#   'clean_technology',
#   'cleaner_energy_system',
#   'climate-related_hazard',
#   'climate_change',
#   'climate_change_mitigation',
#   'climate_change_strategy',
#   'climate_consideration',
#   'commitment',
#   'critical_global_problem',
#   'ecosystem',
#   'effective_adaption',
#   'electricity_emission',
#   'ghg',
#   'global_temperature_rise',
#   'global_warming',
#   'green_climate',
#   'human_and_institutional_capacity_on_climate',
#   'increase_carbon_sequestration_in_soil',
#   'increase_fuel_efficieny',
#   'mitigate_climate_change',
#   'mitigation_action',
#   'reduce_ghg_emission',
#   'reducing_greenhouse_gas',
#   'space_consolidation',
#   'transitioning_to_low-carbon'},
#  'healthy coasts and oceans': {'aboriginal_right',
#   'cautious_zone',
#   'coast',
#   'coastal_ecosystem',
#   'conserving_coastal',
#   'critical_zone',
#   'ecosystem',
#   'eelgrass',
#   'envirnomental_change',
#   'environmental_challenge',
#   'fish',
#   'fish_stock',
#   'fishery',
#   'flood',
#   'harvesting',
#   'healthy_zone',
#   'marine_protected_area',
#   'marine_territory',
#   'ocean',
#   'ocean_area',
#   'ocean_disposal',
#   'ocean_resource',
#   'oil_spill',
#   'plant',
#   'polluter_pay',
#   'pollution',
#   'protected_area',
#   'protection_mechanism',
#   'recreational_fishery',
#   'sea',
#   'sea_level',
#   'shellfish',
#   'shipping',
#   'special_place',
#   'specie',
#   'water'},
#  'healthy wildlife populations': {'alien_specie',
#   'animal',
#   'biodiversity',
#   'biodiversity_loss',
#   'conservation',
#   'deterioration',
#   'disease',
#   'ecological',
#   'ecosystem',
#   'extinct',
#   'habitat',
#   'human_activity',
#   'invasive_specie',
#   'loss',
#   'migration',
#   'nature-based',
#   'plant',
#   'poaching',
#   'pollution',
#   'population',
#   'preserve',
#   'protection',
#   'reserve',
#   'specie',
#   'specie_at_risk',
#   'threatened',
#   'threatened_specie',
#   'urban_development',
#   'variety_of_gene',
#   'wilderness',
#   'wildlife'},
#  'low-carbon government': {'carbon',
#   'carbon-neutral',
#   'clean_tech',
#   'electricity',
#   'emission',
#   'energy',
#   'energy_efficiency',
#   'equipment',
#   'ghg_consumption',
#   'innovative_technology',
#   'leed',
#   'low-carbon',
#   'operable_window',
#   'operation',
#   'outside-air_supply',
#   'real_property',
#   'triple-pane_curtain_wall',
#   'vehicle'},
#  'modern and resilient infrastructure': {'clean_economic_growth',
#   'development',
#   'economic_development',
#   'economic_growth',
#   'facility',
#   'flood_mitigation',
#   'green_infrastructure',
#   'industry',
#   'information_access',
#   'infrastructure',
#   'infrastructure_investment',
#   'innovation',
#   'modern_and_resilient_infrastructure',
#   'national_circumstance',
#   'research',
#   'resilient_infrastructure',
#   'small-scale_industrial',
#   'wastewater_system'},
#  'pristine lakes and rivers': {'agriculture',
#   'algal_bloom',
#   'alien_specie',
#   'aquatic_life',
#   'atmosphere',
#   'boat_shipping',
#   'boating',
#   'churchill',
#   'clean_lake',
#   'commercial_fishery',
#   'experimental_lakes_area',
#   'fishery_commission',
#   'fraser',
#   'great_lakes',
#   'harmful_algal_bloom',
#   'health_of_lake',
#   'international_joint_commission',
#   'interprovincial',
#   'invasive',
#   'lake',
#   'lake_erie',
#   'lake_simcoe',
#   'lake_winnipeg',
#   'mackenzie',
#   'mercury_deposition',
#   'nutrient_level',
#   'pollution',
#   'recreational_fishing',
#   'restore_water-related_ecosystem',
#   'river',
#   'st_lawrence',
#   'swimming',
#   'tourism',
#   'transboundary_water_issue',
#   'undertreated_waste_water',
#   'untreated_run-off',
#   'water',
#   'water_contamination',
#   'water_flow',
#   'water_resource',
#   'water_unsafe',
#   'watershed'},
#  'safe and healthy communities': {'aging',
#   'air_quality',
#   'ambulance',
#   'cancer',
#   'care',
#   'city',
#   'clinic',
#   'community',
#   'contaminated_site',
#   'cost',
#   'diessel',
#   'disaster',
#   'doctor',
#   'electricity',
#   'enivronmental_emergency',
#   'everyday_life',
#   'flu',
#   'hazardous_chemical',
#   'health_financing',
#   'health_problem',
#   'health_risk',
#   'health_workforce',
#   'hospital',
#   'human_settlement',
#   'ice',
#   'inaccessibility',
#   'inefficient_infrastructure',
#   'municipal',
#   'nurse',
#   'pollution',
#   'public_health',
#   'remoteness',
#   'reserve',
#   'resilience',
#   'settlement',
#   'space_heating',
#   'substance',
#   'urban',
#   'urbanization',
#   'waste_management'},
#  'sustainable food': {'agri-based',
#   'agri-food',
#   'agricultural_land',
#   'agricultural_practice',
#   'agricultural_productivity',
#   'aquaculture',
#   'country_food',
#   'cultivated_plant',
#   'disaster',
#   'domesticated',
#   'drought',
#   'ecosystem',
#   'end_hunger',
#   'family_farmer',
#   'farmed',
#   'feed',
#   'fishery',
#   'flooding',
#   'food',
#   'food_commodity_market',
#   'food_decomposes',
#   'food_price',
#   'food_producer',
#   'food_reserve',
#   'food_system',
#   'food_waste',
#   'freshwater',
#   'genetic_diversity_of_seed',
#   'healthy_food',
#   'malnutrition',
#   'methane',
#   'non-farm_employment',
#   'nutritious',
#   'pastoralists_and_fisher',
#   'plant_bank',
#   'secure_food',
#   'soil_quality',
#   'stunting',
#   'sufficient'},
#  'sustainably managed lands and forests': {'afforestation',
#   'agricultural_land',
#   'alien_specie',
#   'biodiversity_loss',
#   'canadian_boreal',
#   'combat_desertification',
#   'conservation',
#   'degradation',
#   'desertification',
#   'drought',
#   'drylands',
#   'fauna',
#   'flood',
#   'flora',
#   'forest',
#   'forest_management',
#   'genetic_resource',
#   'habitat',
#   'invasive',
#   'land',
#   'land_degradation-neutral_world',
#   'mountain',
#   'mountain_ecosystem',
#   'national_park',
#   'peatlands',
#   'poaching',
#   'population',
#   'prairie',
#   'priority_specie',
#   'protected_specie',
#   'rainforest',
#   'reforestation',
#   'soil',
#   'storing_carbon_dioxide',
#   'sustainably_manage_forest',
#   'terrestrial',
#   'terrestrial_ecosystem',
#   'threatened_specie',
#   'tract_of_forest',
#   'tundra',
#   'wetland',
#   'wilderness',
#   'wildlife',
#   'wildlife_product'}}

# %%
data_df['FSDS_category'] = data_df['FSDS_category'].str.lower()

# %%
data_df['FSDS_category'] = data_df['FSDS_category'].str.replace('unknown', 'other')
data_df['FSDS_category'] = data_df['FSDS_category'].str.replace('connecting canadians with nature ', 'connecting canadians with nature')

# %%
def find_goal_words_only(row):
    matched_words = row['FSDS_matched_keywords'].replace('\', \'', ',').replace('[\'', '').replace('\']', '').replace('[]', '')
    if matched_words == '':
        return ''
    #print('Processing FSDS Goal: ' + row['FSDS_category'])
    matched_word_list = matched_words.split(',')
    matched_word_set = set(matched_word_list)   #### this lines removes duplicated matched words
    remove_words = []
    for word in matched_word_set:
        if word not in category_dict[row['FSDS_category']]:            
            remove_words.append(word)
            #print('This word does not belong to this category: ' + word)
    for word in remove_words:
        matched_word_set.remove(word)
    return str(', '.join(sorted(list(matched_word_set), key=str.lower)))

# %%
data_df['matched_goal_words_only'] = data_df.apply(find_goal_words_only, axis=1)
data_df
# Out:
#                                    id num_comments num_shares num_angrys  \
# 0      318424514044_10154848488474045           49        353          0
# 1      318424514044_10155396901694045          695        129         25
# 2      318424514044_10154830856069045           20         81          0
# 3      318424514044_10154700497599045           47        142          1
# 4      318424514044_10154771845659045           28        151          0
# 5      318424514044_10154849106479045           25         62          0
# 6      318424514044_10154702444009045          305         86          1
# 7      318424514044_10154732005664045           17         66          0
# 8      318424514044_10154491555714045            2         93          0
# 9      318424514044_10156589291004045           13        280          1
# 10     318424514044_10155978270779045           21        246          0
# 11     318424514044_10154658885269045            8         28          0
# 12     318424514044_10154664864874045            3         48          0
# 13     318424514044_10154511949484045            6         25          0
# 14     318424514044_10154816339454045            5         36          0
# 15     318424514044_10154643488034045           12        119          0
# 16     318424514044_10155215390119045           11        115          0
# 17     318424514044_10154644216389045            7         32          0
# 18     318424514044_10154807727819045           26         25          1
# 19     318424514044_10154514822519045            1         36          0
# 20     318424514044_10155988996264045            3         96          1
# 21     318424514044_10154797582689045            0         21          0
# 22     318424514044_10154968295914045            6         22          0
# 23     318424514044_10156039240784045            6         47          0
# 24     318424514044_10154961664129045            5         18          0
# 25     318424514044_10154450533139045            7         17          0
# 26     318424514044_10154585272574045            3         21          0
# 27     318424514044_10156356522849045            4         96          0
# 28     318424514044_10156523732504045           41         54          3
# 29     318424514044_10155904022604045           40         40          0
# 30     318424514044_10156226685774045            2         49          0
# 31     318424514044_10154680941374045            1         12          0
# 32     318424514044_10154903977954045            3         23          0
# 33     318424514044_10156231289779045            2         52          0
# 34     318424514044_10154797021289045            1         17          0
# 35     318424514044_10154496296719045            1         10          0
# 36     318424514044_10154484082274045            6         19          0
# 37     318424514044_10155865671829045            2        101          0
# 38     318424514044_10156170249859045           40         39          2
# 39     318424514044_10155721278569045            5         77          0
# 40     318424514044_10155883220354045            2         33          0
# 41     318424514044_10154446469909045            6         19          0
# 42     318424514044_10156740188799045            2         80          0
# 43     318424514044_10155291131919045            1         62          1
# 44     318424514044_10154738149479045            1          3          0
# 45     318424514044_10154585889914045            6         74          0
# 46     318424514044_10155377927159045            8         22          0
# 47     318424514044_10154546378374045            2         18          0
# 48     318424514044_10154585353219045            6         11          0
# 49     318424514044_10155481124659045            1         43          0
# ...                               ...          ...        ...        ...
# 46769             2017-11-29_12-53-13            0        NaN        NaN
# 46770             2017-05-13_09-18-03            0        NaN        NaN
# 46771             2017-11-28_07-53-31            0        NaN        NaN
# 46772             2017-02-09_10-07-46            0        NaN        NaN
# 46773             2017-11-23_11-48-38            0        NaN        NaN
# 46774             2017-10-03_16-03-11            0        NaN        NaN
# 46775             2017-11-17_06-55-01            0        NaN        NaN
# 46776             2017-10-05_07-33-34            1        NaN        NaN
# 46777             2017-02-23_06-11-49            0        NaN        NaN
# 46778             2017-02-16_11-05-26            1        NaN        NaN
# 46779             2017-11-08_11-26-12            0        NaN        NaN
# 46780             2017-09-28_09-17-59            0        NaN        NaN
# 46781             2017-02-02_11-30-28            0        NaN        NaN
# 46782             2017-02-02_11-20-52            0        NaN        NaN
# 46783             2017-09-29_11-14-47            0        NaN        NaN
# 46784             2017-03-03_05-48-17            0        NaN        NaN
# 46785             2017-12-05_11-31-43            0        NaN        NaN
# 46786             2017-10-12_14-06-28            0        NaN        NaN
# 46787             2017-03-08_09-49-02            0        NaN        NaN
# 46788             2017-03-03_05-51-28            1        NaN        NaN
# 46789             2017-10-24_08-03-04            0        NaN        NaN
# 46790             2016-12-12_13-12-14            0        NaN        NaN
# 46791             2017-02-03_13-26-06            0        NaN        NaN
# 46792             2017-07-13_07-58-04            0        NaN        NaN
# 46793             2017-06-09_06-44-20            0        NaN        NaN
# 46794             2016-12-28_07-53-40            0        NaN        NaN
# 46795             2017-02-23_09-49-16            0        NaN        NaN
# 46796             2017-03-08_09-45-00            0        NaN        NaN
# 46797             2017-10-02_14-39-52            0        NaN        NaN
# 46798             2017-12-01_08-52-07            0        NaN        NaN
# 46799             2017-10-03_09-09-52            0        NaN        NaN
# 46800             2017-05-13_09-39-22            0        NaN        NaN
# 46801             2017-02-08_05-57-42            0        NaN        NaN
# 46802             2016-12-08_08-58-20            1        NaN        NaN
# 46803             2017-10-05_14-03-23            0        NaN        NaN
# 46804             2017-12-06_08-09-12            0        NaN        NaN
# 46805             2017-10-05_14-58-52            0        NaN        NaN
# 46806             2017-08-14_11-16-26            0        NaN        NaN
# 46807             2017-11-03_07-24-17            0        NaN        NaN
# 46808             2017-09-28_14-09-28            0        NaN        NaN
# 46809             2017-09-29_14-32-24            0        NaN        NaN
# 46810             2017-10-03_13-59-23            0        NaN        NaN
# 46811             2017-10-04_13-30-59            0        NaN        NaN
# 46812             2017-10-05_12-41-44            0        NaN        NaN
# 46813             2017-10-05_15-22-28            0        NaN        NaN
# 46814             2017-10-04_08-22-12            0        NaN        NaN
# 46815             2016-12-08_08-45-08            0        NaN        NaN
# 46816             2016-12-08_08-20-07            0        NaN        NaN
# 46817             2016-12-08_08-17-30            0        NaN        NaN
# 46818             2016-12-08_08-15-13            0        NaN        NaN
#
#       num_hahas num_likes num_loves num_sads num_special num_wows  \
# 0             1      3005        67        0           0        6
# 1             7       214        48       11           0       10
# 2             0       929        63        0           0        4
# 3             1       612        14        0           0        3
# 4            14       603        16        0           0        1
# 5             0       508        23        0           0        0
# 6             0       187         6        0           0        4
# 7             3       463         9        0           0        0
# 8             0       399         4        0           0        0
# 9             0       152        18        1           0        5
# 10            0        81        16        0           1        2
# 11            0       265        13        1           0        5
# 12            0       240         3        0           0        1
# 13            0       261         1        0           0        0
# 14            0       222        24        1           0        1
# 15           18       130         4        0           0        0
# 16            0       142         7        0           0        0
# 17            0       194         9        0           0        2
# 18            2       174         1        0           0        0
# 19            0       177         9        0           0        3
# 20            0       104         2       15           0        4
# 21            0       184         2        0           0        1
# 22           10       161         3        0           0        2
# 23            0       124        15        0           0       10
# 24            0       163         9        0           0        4
# 25            0       169         0        0           0        0
# 26            0       151         7        0           0        0
# 27            0        64         1       15           0        0
# 28            0        73         9        0           0        0
# 29            0        85        11        0           0        0
# 30            0       109        14        0           0        0
# 31            0       155         0        0           0        0
# 32            0       133         8        0           0        0
# 33            0       109         3        0           0        1
# 34            0       140         8        0           0        0
# 35            0       153         0        0           0        0
# 36            0       137         0        0           0        0
# 37            0        52         6        0           0        0
# 38            0        62        10        1           1        0
# 39            0        69         1        0           0        2
# 40            0       106         9        0           0        3
# 41            0       125         0        0           0        0
# 42            0        62         6        0           0        0
# 43            0        75        10        0           0        0
# 44            0       140         3        0           0        0
# 45            0        63         4        0           0        0
# 46            0       102        14        0           0        0
# 47            0       122         1        0           0        2
# 48            0       116         8        1           0        0
# 49            0        91         4        0           0        0
# ...         ...       ...       ...      ...         ...      ...
# 46769       NaN         9       NaN      NaN         NaN      NaN
# 46770       NaN         9       NaN      NaN         NaN      NaN
# 46771       NaN         9       NaN      NaN         NaN      NaN
# 46772       NaN         9       NaN      NaN         NaN      NaN
# 46773       NaN         9       NaN      NaN         NaN      NaN
# 46774       NaN         9       NaN      NaN         NaN      NaN
# 46775       NaN         9       NaN      NaN         NaN      NaN
# 46776       NaN         8       NaN      NaN         NaN      NaN
# 46777       NaN         9       NaN      NaN         NaN      NaN
# 46778       NaN         8       NaN      NaN         NaN      NaN
# 46779       NaN         9       NaN      NaN         NaN      NaN
# 46780       NaN         9       NaN      NaN         NaN      NaN
# 46781       NaN         9       NaN      NaN         NaN      NaN
# 46782       NaN         9       NaN      NaN         NaN      NaN
# 46783       NaN         8       NaN      NaN         NaN      NaN
# 46784       NaN         8       NaN      NaN         NaN      NaN
# 46785       NaN         8       NaN      NaN         NaN      NaN
# 46786       NaN         8       NaN      NaN         NaN      NaN
# 46787       NaN         8       NaN      NaN         NaN      NaN
# 46788       NaN         7       NaN      NaN         NaN      NaN
# 46789       NaN         8       NaN      NaN         NaN      NaN
# 46790       NaN         7       NaN      NaN         NaN      NaN
# 46791       NaN         7       NaN      NaN         NaN      NaN
# 46792       NaN         7       NaN      NaN         NaN      NaN
# 46793       NaN         7       NaN      NaN         NaN      NaN
# 46794       NaN         7       NaN      NaN         NaN      NaN
# 46795       NaN         7       NaN      NaN         NaN      NaN
# 46796       NaN         7       NaN      NaN         NaN      NaN
# 46797       NaN         6       NaN      NaN         NaN      NaN
# 46798       NaN         6       NaN      NaN         NaN      NaN
# 46799       NaN         6       NaN      NaN         NaN      NaN
# 46800       NaN         6       NaN      NaN         NaN      NaN
# 46801       NaN         6       NaN      NaN         NaN      NaN
# 46802       NaN         4       NaN      NaN         NaN      NaN
# 46803       NaN         5       NaN      NaN         NaN      NaN
# 46804       NaN         5       NaN      NaN         NaN      NaN
# 46805       NaN         5       NaN      NaN         NaN      NaN
# 46806       NaN         5       NaN      NaN         NaN      NaN
# 46807       NaN         5       NaN      NaN         NaN      NaN
# 46808       NaN         5       NaN      NaN         NaN      NaN
# 46809       NaN         5       NaN      NaN         NaN      NaN
# 46810       NaN         4       NaN      NaN         NaN      NaN
# 46811       NaN         4       NaN      NaN         NaN      NaN
# 46812       NaN         4       NaN      NaN         NaN      NaN
# 46813       NaN         4       NaN      NaN         NaN      NaN
# 46814       NaN         3       NaN      NaN         NaN      NaN
# 46815       NaN         3       NaN      NaN         NaN      NaN
# 46816       NaN         2       NaN      NaN         NaN      NaN
# 46817       NaN         1       NaN      NaN         NaN      NaN
# 46818       NaN         1       NaN      NaN         NaN      NaN
#
#       Reactions_SUM                              FSDS_matched_keywords  \
# 0              3481                                                 []
# 1              1139                                                 []
# 2              1097                                                 []
# 3               820                     ['development', 'development']
# 4               813                     ['development', 'development']
# 5               618                     ['development', 'development']
# 6               589                                                 []
# 7               558                     ['development', 'development']
# 8               498                               ['specie', 'specie']
# 9               470                                                 []
# 10              367                                         ['nature']
# 11              320  ['wildlife', 'wildlife', 'nature', 'specie', '...
# 12              295                                                 []
# 13              293                        ['water', 'water', 'water']
# 14              289   ['wildlife', 'wildlife', 'wildlife', 'wildlife']
# 15              283  ['wildlife', 'wildlife', 'migration', 'migrati...
# 16              275  ['land', 'stewardship', 'fish', 'conservation'...
# 17              244                                                 []
# 18              229                     ['development', 'development']
# 19              226                               ['energy', 'energy']
# 20              225  ['specie', 'specie', 'ecosystem', 'ecosystem',...
# 21              208                                                 []
# 22              204                   ['park', 'wildlife', 'wildlife']
# 23              202                                                 []
# 24              199  ['forest', 'freshwater', 'freshwater', 'biosph...
# 25              193                                                 []
# 26              182                                      ['equipment']
# 27              180     ['food', 'habitat', 'habitat', 'food', 'feed']
# 28              180                                                 []
# 29              176                                                 []
# 30              174                                         ['nature']
# 31              168  ['wildlife', 'wildlife', 'commitment', 'wildli...
# 32              167                                                 []
# 33              167                                                 []
# 34              166  ['terrestrial', 'marine', 'land', 'specie', 's...
# 35              164          ['ice', 'ice', 'water', 'water', 'water']
# 36              162                                            ['ice']
# 37              161                                                 []
# 38              155  ['carbon', 'economy', 'greenhouse_gas', 'emiss...
# 39              154  ['conservation', 'conservation', 'conservation...
# 40              153  ['water', 'water', 'water', 'wildlife', 'wildl...
# 41              150                                                 []
# 42              150  ['wildlife', 'wildlife', 'national_wildlife', ...
# 43              149  ['health', 'economy', 'plant', 'plant', 'wildl...
# 44              147                                           ['park']
# 45              147                                                 []
# 46              146                                                 []
# 47              145          ['ice', 'water', 'water', 'water', 'ice']
# 48              142  ['climate_change', 'water', 'water', 'water', ...
# 49              139                           ['wildlife', 'wildlife']
# ...             ...                                                ...
# 46769             9                                                 []
# 46770             9                                       ['research']
# 46771             9                                                 []
# 46772             9                                                 []
# 46773             9                                                 []
# 46774             9                                                 []
# 46775             9                                           ['park']
# 46776             9                                                 []
# 46777             9                                                 []
# 46778             9  ['forest', 'industry', 'industry', 'forest', '...
# 46779             9                                                 []
# 46780             9                                                 []
# 46781             9                         ['community', 'community']
# 46782             9                                                 []
# 46783             8                               ['energy', 'energy']
# 46784             8                                       ['research']
# 46785             8                                                 []
# 46786             8  ['pollution', 'pollution', 'pollution', 'pollu...
# 46787             8                                                 []
# 46788             8  ['research', 'population', 'population', 'inva...
# 46789             8                               ['energy', 'energy']
# 46790             7                                                 []
# 46791             7                                           ['city']
# 46792             7                               ['energy', 'energy']
# 46793             7                                                 []
# 46794             7                            ['lake', 'lake', 'ice']
# 46795             7  ['energy', 'energy', 'carbon', 'economy', 'eco...
# 46796             7                     ['forest', 'health', 'forest']
# 46797             6                                   ['clean_energy']
# 46798             6  ['municipal', 'municipality', 'water', 'water'...
# 46799             6                               ['energy', 'energy']
# 46800             6                                                 []
# 46801             6                               ['energy', 'energy']
# 46802             5               ['infrastructure', 'infrastructure']
# 46803             5                               ['energy', 'energy']
# 46804             5                                                 []
# 46805             5                     ['carbon', 'energy', 'energy']
# 46806             5                               ['energy', 'energy']
# 46807             5                               ['energy', 'energy']
# 46808             5                               ['energy', 'energy']
# 46809             5                               ['energy', 'energy']
# 46810             4                                                 []
# 46811             4                                                 []
# 46812             4                               ['energy', 'energy']
# 46813             4                               ['energy', 'energy']
# 46814             3                                                 []
# 46815             3  ['infrastructure', 'gas', 'vehicle', 'electric...
# 46816             2                                        ['economy']
# 46817             1                            ['mountain', 'economy']
# 46818             1                            ['mountain', 'economy']
#
#                                FSDS_category  \
# 0                                      other
# 1                                      other
# 2                                      other
# 3                               clean growth
# 4                               clean growth
# 5                               clean growth
# 6                                      other
# 7                               clean growth
# 8               healthy wildlife populations
# 9                                      other
# 10          connecting canadians with nature
# 11              healthy wildlife populations
# 12                                     other
# 13                      clean drinking water
# 14              healthy wildlife populations
# 15              healthy wildlife populations
# 16              healthy wildlife populations
# 17                                     other
# 18                              clean growth
# 19                     low-carbon government
# 20              healthy wildlife populations
# 21                                     other
# 22              healthy wildlife populations
# 23                                     other
# 24     sustainably managed lands and forests
# 25                                     other
# 26                     low-carbon government
# 27                          sustainable food
# 28                                     other
# 29                                     other
# 30          connecting canadians with nature
# 31              healthy wildlife populations
# 32                                     other
# 33                                     other
# 34     sustainably managed lands and forests
# 35              safe and healthy communities
# 36              safe and healthy communities
# 37                                     other
# 38                              clean growth
# 39          connecting canadians with nature
# 40              healthy wildlife populations
# 41                                     other
# 42              healthy wildlife populations
# 43              healthy wildlife populations
# 44          connecting canadians with nature
# 45                                     other
# 46                                     other
# 47              safe and healthy communities
# 48        effective action on climate change
# 49              healthy wildlife populations
# ...                                      ...
# 46769                                  other
# 46770    modern and resilient infrastructure
# 46771                                  other
# 46772                                  other
# 46773                                  other
# 46774                                  other
# 46775       connecting canadians with nature
# 46776                                  other
# 46777                                  other
# 46778    modern and resilient infrastructure
# 46779                                  other
# 46780                                  other
# 46781           safe and healthy communities
# 46782                                  other
# 46783                  low-carbon government
# 46784    modern and resilient infrastructure
# 46785                                  other
# 46786              healthy coasts and oceans
# 46787                                  other
# 46788  sustainably managed lands and forests
# 46789                  low-carbon government
# 46790                                  other
# 46791           safe and healthy communities
# 46792                  low-carbon government
# 46793                                  other
# 46794           safe and healthy communities
# 46795                  low-carbon government
# 46796  sustainably managed lands and forests
# 46797                           clean energy
# 46798                   clean drinking water
# 46799                  low-carbon government
# 46800                                  other
# 46801                  low-carbon government
# 46802    modern and resilient infrastructure
# 46803                  low-carbon government
# 46804                                  other
# 46805                  low-carbon government
# 46806                  low-carbon government
# 46807                  low-carbon government
# 46808                  low-carbon government
# 46809                  low-carbon government
# 46810                                  other
# 46811                                  other
# 46812                  low-carbon government
# 46813                  low-carbon government
# 46814                                  other
# 46815                  low-carbon government
# 46816                           clean growth
# 46817                           clean growth
# 46818                           clean growth
#
#                           matched_goal_words_only
# 0
# 1
# 2
# 3                                     development
# 4                                     development
# 5                                     development
# 6
# 7                                     development
# 8                                          specie
# 9
# 10                                         nature
# 11                               specie, wildlife
# 12
# 13                                          water
# 14                                       wildlife
# 15              conservation, migration, wildlife
# 16                           conservation, specie
# 17
# 18                                    development
# 19                                         energy
# 20     ecosystem, habitat, loss, specie, wildlife
# 21
# 22                                       wildlife
# 23
# 24                                         forest
# 25
# 26                                      equipment
# 27                                     feed, food
# 28
# 29
# 30                                         nature
# 31                      habitat, specie, wildlife
# 32
# 33
# 34                     habitat, land, terrestrial
# 35                                            ice
# 36                                            ice
# 37
# 38                        economy, greenhouse_gas
# 39                     conservation, nature, park
# 40                              habitat, wildlife
# 41
# 42          habitat, protection, specie, wildlife
# 43                       habitat, plant, wildlife
# 44                                           park
# 45
# 46
# 47                                            ice
# 48      climate_change, ecosystem, global_warming
# 49                                       wildlife
# ...                                           ...
# 46769
# 46770                                    research
# 46771
# 46772
# 46773
# 46774
# 46775                                        park
# 46776
# 46777
# 46778                        industry, innovation
# 46779
# 46780
# 46781                                   community
# 46782
# 46783                                      energy
# 46784                                    research
# 46785
# 46786                            pollution, water
# 46787
# 46788                forest, invasive, population
# 46789                                      energy
# 46790
# 46791                                        city
# 46792                                      energy
# 46793
# 46794                                         ice
# 46795                              carbon, energy
# 46796                                      forest
# 46797                                clean_energy
# 46798                         municipality, water
# 46799                                      energy
# 46800
# 46801                                      energy
# 46802                              infrastructure
# 46803                                      energy
# 46804
# 46805                              carbon, energy
# 46806                                      energy
# 46807                                      energy
# 46808                                      energy
# 46809                                      energy
# 46810
# 46811
# 46812                                      energy
# 46813                                      energy
# 46814
# 46815                        electricity, vehicle
# 46816                                     economy
# 46817                                     economy
# 46818                                     economy
#
# [46819 rows x 14 columns]

# %%
f = {'id': ['count'], 'num_comments': ['sum'], 'num_shares': ['sum'], 'num_angrys': ['sum'], 'num_hahas': ['sum'], 
     'num_likes': ['sum'], 'num_loves': ['sum'], 'num_sads': ['sum'], 'num_special': ['sum'], 'num_wows': ['sum'], 
     'Reactions_SUM': ['sum'], 'FSDS_matched_keywords':[lambda col: ', '.join(col)], 
     'matched_goal_words_only':[lambda col: ', '.join(col)],}
output_df = data_df.groupby(['FSDS_category']).agg(f).reset_index()
output_df.columns = ['FSDS_category', 'id_count', 'num_comments', 'num_shares', 'num_angrys', 'num_hahas', 'num_likes', 'num_loves', 'num_sads', 'num_special', 'num_wows', 'Reactions_SUM', 'FSDS_matched_keywords', 'matched_goal_words_only', ]
output_df
# Out:
#                             FSDS_category  id_count  num_comments  num_shares  \
# 0                    clean drinking water      1857          1375       25952
# 1                            clean energy       414           314        6986
# 2                            clean growth      1416           605       16071
# 3        connecting canadians with nature      1303         22525       52085
# 4      effective action on climate change       526           391        9701
# 5               healthy coasts and oceans      3041          1531       44599
# 6            healthy wildlife populations      2623          4741       48591
# 7                   low-carbon government      2782          2889       24743
# 8     modern and resilient infrastructure      1386           431       10756
# 9                                   other     28152         16387      522513
# 10              pristine lakes and rivers       386           228        3749
# 11           safe and healthy communities      1626           839       21404
# 12                       sustainable food       517           201       16827
# 13  sustainably managed lands and forests       790          2927       11316
#
#     num_angrys  num_hahas  num_likes  num_loves  num_sads  num_special  \
# 0            6         12      72465       1654        22            3
# 1           10          5       3336         56         1            1
# 2           13         45      18836        449         7            5
# 3           23        266     917235      16596       151           36
# 4            9          7       6858         88         8           -5
# 5           18         23      76409       1234        23            1
# 6           42        152     209295       5699       266           18
# 7          632        882      24520        304        56            2
# 8           10         35      11409        226        20           -3
# 9          662        912     423362      13061       604          279
# 10          12          5       8257        117         4            0
# 11          29         15      45997        780        92          -12
# 12           1          6       6929        148        18            0
# 13           3         39     216601       2663        10            4
#
#     num_wows  Reactions_SUM  \
# 0        502         101991
# 1         20          10729
# 2        111          36142
# 3       3802        1012719
# 4         11          17068
# 5        374         124212
# 6       1402         270206
# 7        135          54163
# 8         54          22938
# 9       3232         981012
# 10        27          12399
# 11       498          69642
# 12        34          24164
# 13       624         234187
#
#                                 FSDS_matched_keywords  \
# 0   ['water', 'water', 'water'], ['drinking'], ['f...
# 1   ['gas', 'park'], ['energy', 'energy', 'oil', '...
# 2   ['development', 'development'], ['development'...
# 3   ['nature'], ['nature'], ['conservation', 'cons...
# 4   ['climate_change', 'water', 'water', 'water', ...
# 5   ['sea', 'ecosystem', 'ecosystem', 'ecosystem',...
# 6   ['specie', 'specie'], ['wildlife', 'wildlife',...
# 7   ['energy', 'energy'], ['equipment'], ['energy'...
# 8   ['research', 'lake', 'lake'], ['research', 're...
# 9   [], [], [], [], [], [], [], [], [], [], [], []...
# 10  ['watershed', 'water', 'water', 'water', 'aqua...
# 11  ['ice', 'ice', 'water', 'water', 'water'], ['i...
# 12  ['food', 'habitat', 'habitat', 'food', 'feed']...
# 13  ['forest', 'freshwater', 'freshwater', 'biosph...
#
#                               matched_goal_words_only
# 0   water, drinking, freshwater, water, clean, hea...
# 1   gas, energy, oil, diesel, electricity, heat, r...
# 2   development, development, development, develop...
# 3   nature, nature, conservation, nature, park, pa...
# 4   climate_change, ecosystem, global_warming, cli...
# 5   ecosystem, sea, fish, shellfish, plant, water,...
# 6   specie, specie, wildlife, wildlife, conservati...
# 7   energy, equipment, energy, energy, emission, e...
# 8   research, facility, research, facility, innova...
# 9   , , , , , , , , , , , , , , , , , , , , , , , ...
# 10  aquatic_life, river, water, watershed, river, ...
# 11  ice, ice, ice, community, community, urban, su...
# 12  feed, food, feed, feed, feed, flooding, food, ...
# 13  forest, habitat, land, terrestrial, habitat, l...

# %%
def check_flag(col, word):
    word_set = set(col.split(', '))
    if word in word_set:
        return 'Y'
    else:
        return 'N'   
    
def find_top_topics(row):
    print('\n' + 'Processing FSDS Goal: ' + row['FSDS_category'])
    matched_words_list = row['matched_goal_words_only'].split(', ')
    #print(matched_words_list)
    counter = {}
    for word in set(matched_words_list):
        counter[word] = 0
    for word in matched_words_list:
        counter[word] += 1
    top_topics = sorted(counter, key=counter.get, reverse=True)  
    #print(counter)
    result = ''
    temp_df = data_df[data_df['FSDS_category']==row['FSDS_category']]
    for i in range(0, 15):
        try:
            top_topics[i]
        except:
            return result
        temp_df['flag'] = 'N'
        temp_df['flag'] = temp_df['matched_goal_words_only'].apply(check_flag, word=top_topics[i])
        react_sum = temp_df[temp_df['flag'] == 'Y']['Reactions_SUM'].sum()
        result += top_topics[i].replace('specie', 'species').replace('_', ' ') + ': ' + str(react_sum) + '\n'  
    return result

output_df['Topics/Issues'] = output_df.apply(find_top_topics, axis=1)
output_df
# Out:
# Processing FSDS Goal: clean drinking water
# /Users/chao/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/chao/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Processing FSDS Goal: clean energy
#
# Processing FSDS Goal: clean growth
#
# Processing FSDS Goal: connecting canadians with nature
#
# Processing FSDS Goal: effective action on climate change
#
# Processing FSDS Goal: healthy coasts and oceans
#
# Processing FSDS Goal: healthy wildlife populations
#
# Processing FSDS Goal: low-carbon government
#
# Processing FSDS Goal: modern and resilient infrastructure
#
# Processing FSDS Goal: other
#
# Processing FSDS Goal: pristine lakes and rivers
#
# Processing FSDS Goal: safe and healthy communities
#
# Processing FSDS Goal: sustainable food
#
# Processing FSDS Goal: sustainably managed lands and forests
#                             FSDS_category  id_count  num_comments  num_shares  \
# 0                    clean drinking water      1857          1375       25952
# 1                            clean energy       414           314        6986
# 2                            clean growth      1416           605       16071
# 3        connecting canadians with nature      1303         22525       52085
# 4      effective action on climate change       526           391        9701
# 5               healthy coasts and oceans      3041          1531       44599
# 6            healthy wildlife populations      2623          4741       48591
# 7                   low-carbon government      2782          2889       24743
# 8     modern and resilient infrastructure      1386           431       10756
# 9                                   other     28152         16387      522513
# 10              pristine lakes and rivers       386           228        3749
# 11           safe and healthy communities      1626           839       21404
# 12                       sustainable food       517           201       16827
# 13  sustainably managed lands and forests       790          2927       11316
#
#     num_angrys  num_hahas  num_likes  num_loves  num_sads  num_special  \
# 0            6         12      72465       1654        22            3
# 1           10          5       3336         56         1            1
# 2           13         45      18836        449         7            5
# 3           23        266     917235      16596       151           36
# 4            9          7       6858         88         8           -5
# 5           18         23      76409       1234        23            1
# 6           42        152     209295       5699       266           18
# 7          632        882      24520        304        56            2
# 8           10         35      11409        226        20           -3
# 9          662        912     423362      13061       604          279
# 10          12          5       8257        117         4            0
# 11          29         15      45997        780        92          -12
# 12           1          6       6929        148        18            0
# 13           3         39     216601       2663        10            4
#
#     num_wows  Reactions_SUM  \
# 0        502         101991
# 1         20          10729
# 2        111          36142
# 3       3802        1012719
# 4         11          17068
# 5        374         124212
# 6       1402         270206
# 7        135          54163
# 8         54          22938
# 9       3232         981012
# 10        27          12399
# 11       498          69642
# 12        34          24164
# 13       624         234187
#
#                                 FSDS_matched_keywords  \
# 0   ['water', 'water', 'water'], ['drinking'], ['f...
# 1   ['gas', 'park'], ['energy', 'energy', 'oil', '...
# 2   ['development', 'development'], ['development'...
# 3   ['nature'], ['nature'], ['conservation', 'cons...
# 4   ['climate_change', 'water', 'water', 'water', ...
# 5   ['sea', 'ecosystem', 'ecosystem', 'ecosystem',...
# 6   ['specie', 'specie'], ['wildlife', 'wildlife',...
# 7   ['energy', 'energy'], ['equipment'], ['energy'...
# 8   ['research', 'lake', 'lake'], ['research', 're...
# 9   [], [], [], [], [], [], [], [], [], [], [], []...
# 10  ['watershed', 'water', 'water', 'water', 'aqua...
# 11  ['ice', 'ice', 'water', 'water', 'water'], ['i...
# 12  ['food', 'habitat', 'habitat', 'food', 'feed']...
# 13  ['forest', 'freshwater', 'freshwater', 'biosph...
#
#                               matched_goal_words_only  \
# 0   water, drinking, freshwater, water, clean, hea...
# 1   gas, energy, oil, diesel, electricity, heat, r...
# 2   development, development, development, develop...
# 3   nature, nature, conservation, nature, park, pa...
# 4   climate_change, ecosystem, global_warming, cli...
# 5   ecosystem, sea, fish, shellfish, plant, water,...
# 6   specie, specie, wildlife, wildlife, conservati...
# 7   energy, equipment, energy, energy, emission, e...
# 8   research, facility, research, facility, innova...
# 9   , , , , , , , , , , , , , , , , , , , , , , , ...
# 10  aquatic_life, river, water, watershed, river, ...
# 11  ice, ice, ice, community, community, urban, su...
# 12  feed, food, feed, feed, feed, flooding, food, ...
# 13  forest, habitat, land, terrestrial, habitat, l...
#
#                                         Topics/Issues
# 0   water: 48601\nriver: 20780\nlake: 39172\nhealt...
# 1   oil: 4448\nheat: 1704\ngas: 2977\nenergy: 690\...
# 2   marine: 22032\neconomy: 6223\ngrowth: 2821\nde...
# 3   park: 910948\nnature: 282407\nengagement: 4181...
# 4   climate change: 5332\ncommitment: 7069\necosys...
# 5   coast: 53396\nocean: 35616\nfishery: 7951\nsea...
# 6   species: 41215\nwildlife: 75679\nconservation:...
# 7   energy: 17720\noperation: 5006\nvehicle: 9475\...
# 8   research: 13022\nindustry: 3489\ninnovation: 3...
# 9                                          : 981012\n
# 10  agriculture: 2469\nboating: 2589\nriver: 5026\...
# 11  community: 18158\nice: 28660\ncost: 3924\ncity...
# 12  food: 5762\nfeed: 16288\naquaculture: 790\nflo...
# 13  forest: 47655\nland: 28601\nmountain: 156261\n...

# %%
output_df = output_df[['FSDS_category', 'Reactions_SUM', 'Topics/Issues']]
output_df.columns = ['FSDS Goal', 'Reaction_Sum', 'Topics/Issues']
output_df['FSDS Goal'] = output_df['FSDS Goal'].str.title()
output_df = output_df.sort_values('Reaction_Sum', ascending=False)
output_df.to_csv('./section3-3_table_en.csv', index=None)
output_df
# Out:
# /Users/chao/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                 FSDS Goal  Reaction_Sum  \
# 3        Connecting Canadians With Nature       1012719
# 9                                   Other        981012
# 6            Healthy Wildlife Populations        270206
# 13  Sustainably Managed Lands And Forests        234187
# 5               Healthy Coasts And Oceans        124212
# 0                    Clean Drinking Water        101991
# 11           Safe And Healthy Communities         69642
# 7                   Low-Carbon Government         54163
# 2                            Clean Growth         36142
# 12                       Sustainable Food         24164
# 8     Modern And Resilient Infrastructure         22938
# 4      Effective Action On Climate Change         17068
# 10              Pristine Lakes And Rivers         12399
# 1                            Clean Energy         10729
#
#                                         Topics/Issues
# 3   park: 910948\nnature: 282407\nengagement: 4181...
# 9                                          : 981012\n
# 6   species: 41215\nwildlife: 75679\nconservation:...
# 13  forest: 47655\nland: 28601\nmountain: 156261\n...
# 5   coast: 53396\nocean: 35616\nfishery: 7951\nsea...
# 0   water: 48601\nriver: 20780\nlake: 39172\nhealt...
# 11  community: 18158\nice: 28660\ncost: 3924\ncity...
# 7   energy: 17720\noperation: 5006\nvehicle: 9475\...
# 2   marine: 22032\neconomy: 6223\ngrowth: 2821\nde...
# 12  food: 5762\nfeed: 16288\naquaculture: 790\nflo...
# 8   research: 13022\nindustry: 3489\ninnovation: 3...
# 4   climate change: 5332\ncommitment: 7069\necosys...
# 10  agriculture: 2469\nboating: 2589\nriver: 5026\...
# 1   oil: 4448\nheat: 1704\ngas: 2977\nenergy: 690\...
