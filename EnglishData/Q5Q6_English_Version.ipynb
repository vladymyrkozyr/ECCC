# %%
import glob
import os
import pandas as pd
import nltk
#nltk.download()   # comment after first download
from nltk.tokenize import MWETokenizer
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
import gensim
from gensim import corpora
from gensim.models import Word2Vec
import string
from numbers import Number
from pprint import pprint
import logging
import operator
from pprint import pprint
pd.options.display.max_rows = 30

# %%
keywords_chosen = 'Que5_Que6 KeywordLists.csv'

data_folder = './Accounts/*.csv'
OUTPUT_COLS = ['id','date_published','link','caption_original','caption_cleaned','hashtags','num_comments',
               'num_shares','num_likes','Reactions_SUM','category','matched_keywords','language',
               'average_sentiment_score','sentiment', 'Action_matched_keywords']

# %%
# create output directory
outputDir = os.path.dirname(data_folder) + '/q5q6_output/'
if not os.path.exists(outputDir):
    os.makedirs(outputDir)

# %%
# set of punctuations to remove from text
exclude = set(string.punctuation)

# %%
stopWords = set(stopwords.words('english'))
stopWords.add('theyre')
stopWords.add("we're")
stopWords.add("we've") 

lemma = WordNetLemmatizer()    # NLTK English lemmatizer

# detect_lang function can be use to check the percentage of non English posts
# note that missing value NaN can be detected as many different languages such english, spanish or italian
def detect_lang(text):
    try:
        lang = detect(text)
    except:
        return 'error'
    return lang

# lemmatize_keywords also clears 'nan' from input keyword list file
# lemmatization is conducted based on context, some words may not get lemmatized, 
# e.g. "local eating" does not get lemmatized to "local eat"
def lemmatize_keywords(col):
    if col.lower() == 'nan':
        return ''
    # if a stopword appreas in given keyword list, this stopword will be removed from stopword list
    for keyword in col.split():
        if keyword in stopWords:
            print(keyword)
            stopWords.remove(keyword)
    return '_'.join(lemma.lemmatize(word).lower() for word in col.replace('’', '\'').replace('.', '').split()) #lemma.lemmatize(word)

# %%
#print(stopWords)

# %%
# load keywords list
pd.options.display.max_rows = 100
keywords_df = pd.read_csv(keywords_chosen, encoding='utf-8')   # "ISO-8859-1"

keywords_df['lemmatized_keywords'] = keywords_df['Actions to advance sustainablity'].astype(str).apply(lemmatize_keywords)
keywords_list = set(keywords_df['lemmatized_keywords'].tolist())
display(keywords_df)

# if there are punctuations in the keywords list, these punctuation will be kept regardless of puncturation removal step
for word in keywords_list:
    for char in word:
        if char in exclude:
            exclude.remove(char)
            
# Add all words in the given keyword list to pre-defined token dictionary
multi_word = [w.split('_') for w in keywords_list ] 
tokenizer = MWETokenizer(multi_word)
# Out:
# down
# the
# own
# off
#     Actions to advance sustainablity lemmatized_keywords
# 0                       eating_local        eating_local
# 1                             biking              biking
# 2                         composting          composting
# 3                          recycling           recycling
# 4                             saving              saving
# 5                             hiking              hiking
# 6                            fishing             fishing
# 7                            camping             camping
# 8                            growing             growing
# 9                         preserving          preserving
# 10                        protecting          protecting
# 11                        conserving          conserving
# 12                          planting            planting
# 13                          fighting            fighting
# 14                          building            building
# 15                           working             working
# 16                   decision-making     decision-making
# 17                           cooling             cooling
# 18                           warming             warming
# 19                           hunting             hunting
# 20                        re-tooling          re-tooling
# 21                      implementing        implementing
# 22                          adapting            adapting
# 23                          changing            changing
# 24                           leading             leading
# 25                         investing           investing
# 26                            living              living
# 27                           raising             raising
# 28                         providing           providing
# 29                           slowing             slowing
# 30                        increasing          increasing
# 31                          planning            planning
# 32                           talking             talking
# 33                           pricing             pricing
# 34                           helping             helping
# 35                          ensuring            ensuring
# 36                          reducing            reducing
# 37                        low carbon          low_carbon
# 38                          damaging            damaging
# 39                         procuring           procuring
# 40                            curing              curing
# 41                           solving             solving
# 42                         educating           educating
# 43                          drinking            drinking
# 44                        supporting          supporting
# 45                        addressing          addressing
# 46                          tracking            tracking
# 47                         achieving           achieving
# 48                            paying              paying
# 49                        developing          developing
# ..                               ...                 ...
# 353                        expanding           expanding
# 354                             bulb                bulb
# 355                         approach            approach
# 356                          cleaner             cleaner
# 357                           farmer              farmer
# 358                            fight               fight
# 359                         increase            increase
# 360                         paddling            paddling
# 361                           paddle              paddle
# 362                          enhance             enhance
# 363                         progress            progress
# 364                      investigate         investigate
# 365                           remove              remove
# 366                           create              create
# 367                             boat                boat
# 368                          boating             boating
# 369                    climateaction       climateaction
# 370                      maintaining         maintaining
# 371                       processing          processing
# 372                          causing             causing
# 373                          farming             farming
# 374                        greenjobs           greenjobs
# 375                             care                care
# 376                      modernizing         modernizing
# 377                         choosing            choosing
# 378                       low_carbon          low_carbon
# 379                         engaging            engaging
# 380                        appliance           appliance
# 381                          grocery             grocery
# 382                            habit               habit
# 383                         shopping            shopping
# 384                            store               store
# 385                         generate            generate
# 386                           manage              manage
# 387                 energyefficiency    energyefficiency
# 388                  energyefficient     energyefficient
# 389                 energystarcanada    energystarcanada
# 390                       saveenergy          saveenergy
# 391                             turn                turn
# 392                         breaking            breaking
# 393                       conducting          conducting
# 394                           diving              diving
# 395                             dive                dive
# 396                          feeding             feeding
# 397                             feed                feed
# 398                         lighting            lighting
# 399                          running             running
# 400                              run                 run
# 401                           ending              ending
# 402                           ending              ending
#
# [403 rows x 2 columns]

# %%
def lemmatize_text(col): 
    text = col.replace('’', '\'')
    tokens = tokenizer.tokenize(text.split())   
    # remove stop words
    stop_free = ' '.join(w for w in tokens if w.lower() not in stopWords and len(w) > 1)
    # remove punctuation
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    # lemmatize
    lemmas = ' '.join(lemma.lemmatize(word).lower() for word in punc_free.split() if len(lemma.lemmatize(word)) > 1)
    return lemmas.split()

# assign a category based the max number of keywords found in each category
def find_matched_keywords(col):
    keywords_found = []
    for word in col:
        if word in keywords_list:
            keywords_found.append(word) 
    return keywords_found

# %% [markdown]
# ## Read and merge input csv files

# %%
pd.options.display.max_rows = 10
# read csv files and save targt columns to dataframe
filePaths = glob.glob(data_folder)  
data_df = pd.DataFrame(columns=OUTPUT_COLS)
for filename in filePaths:
    print(filename)    
    df_i = pd.read_csv(filename, encoding = 'utf-8')
    df_x = df_i.dropna(subset=['caption_original']) 
    data_df = data_df.append(df_x, ignore_index=True)

display(data_df)
# Out:
# ./Accounts/ParksCanada_tweets.csv
# ./Accounts/CanadianAgriculture_facebook_statuses.csv
# ./Accounts/CCG_GCC_tweets.csv
# ./Accounts/FisheriesOceansCanada_facebook_statuses.csv
# ./Accounts/CanadianCoastGuard_facebook_statuses.csv
# ./Accounts/YourMoneyMattersCanada_facebook_statuses.csv
# ./Accounts/EnvironmentandClimateChange_facebook_statuses.csv
# ./Accounts/parks.canada_posts.csv
# ./Accounts/TransportandInfrastructureinCanada_facebook_statuses.csv
# ./Accounts/environmentca_tweets.csv
# ./Accounts/NRCan_tweets.csv
# ./Accounts/ENERGYSTAR_CAN_tweets.csv
# ./Accounts/DFO_Gulf_tweets.csv
# ./Accounts/ec_minister_tweets.csv
# ./Accounts/DFO_Central_tweets.csv
# ./Accounts/DFO_Pacific_tweets.csv
# ./Accounts/DFO_NL_tweets.csv
# ./Accounts/DFO_CCG_Quebec_tweets.csv
# ./Accounts/DFO_Science_tweets.csv
# ./Accounts/Transport_gc_tweets.csv
# ./Accounts/GiantMine_tweets.csv
# ./Accounts/TSBCanada_tweets.csv
# ./Accounts/CTA_gc_tweets.csv
# ./Accounts/AskISED_tweets.csv
# ./Accounts/DFO_MPO_tweets.csv
# ./Accounts/GovCanNorth_facebook_statuses.csv
# ./Accounts/DFO_MAR_tweets.csv
# ./Accounts/GCIndigenous_tweets.csv
# ./Accounts/canenvironment_posts.csv
# ./Accounts/CanadianTransportationAgency_facebook_statuses.csv
# ./Accounts/AAFC_Canada_tweets.csv
# ./Accounts/ParksCanada_facebook_statuses.csv
# ./Accounts/naturalresourcescanada_posts.csv
#       Action_matched_keywords Reactions_SUM  Unnamed: 0  \
# 0                         NaN          2372         0.0
# 1                         NaN          1970         1.0
# 2                         NaN           595         2.0
# 3                         NaN           510         3.0
# 4                         NaN           439         4.0
# ...                       ...           ...         ...
# 44998                     NaN             3       232.0
# 44999                     NaN             3       233.0
# 45000                     NaN             2       234.0
# 45001                     NaN             1       235.0
# 45002                     NaN             1       236.0
#
#                            account_name  average_sentiment_score  \
# 0                   ParksCanada_tweeter                -0.155556
# 1                   ParksCanada_tweeter                 0.300000
# 2                   ParksCanada_tweeter                 0.220000
# 3                   ParksCanada_tweeter                 0.214583
# 4                   ParksCanada_tweeter                 0.000000
# ...                                 ...                      ...
# 44998  naturalresourcescanada_instagram                 0.000000
# 44999  naturalresourcescanada_instagram                 0.000000
# 45000  naturalresourcescanada_instagram                 0.000000
# 45001  naturalresourcescanada_instagram                 0.000000
# 45002  naturalresourcescanada_instagram                 0.000000
#
#                                          caption_cleaned  \
# 0      RT CanadianPM 117 000 poppies one Fallen casca...
# 1      big thank incredible Canada150 year behalf ent...
# 2      Qausuittuq National Park officially open Learn...
# 3      first day PolarBearWeek cool photos fun facts ...
# 4      RemembranceDay Honour served country share pho...
# ...                                                  ...
# 44998  part conversation generation Min Sohi invites ...
# 44999  Funding Budget 2016 increase charging refuelli...
# 45000  Government Canada approved Enbridge Line Repla...
# 45001  Government Canada approved Trans Mountain Expa...
# 45002  Trans Mountain Expansion project Line3 replace...
#
#                                         caption_original       category  \
# 0      RT @CanadianPM: 117,000 poppies, one for each ...        unknown
# 1      A big thank you 🎈 for an incredible #Canada150...  Environmental
# 2      Qausuittuq National Park is officially open! L...  Environmental
# 3      It’s the first day of #PolarBearWeek! ❄️ From ...        unknown
# 4      It’s #RemembranceDay 🇨🇦 Honour those who have ...  Environmental
# ...                                                  ...            ...
# 44998  Be part of the conversation of a generation! M...     Economical
# 44999  Funding from Budget will increase charging/ref...     Economical
# 45000  The Government of Canada approved the Enbridge...  Environmental
# 45001  The Government of Canada approved the Trans Mo...  Environmental
# 45002  What do the Trans Mountain Eansion project and...     Economical
#
#             date_published                                           hashtags  \
# 0      2017-11-10 22:37:12                               ['#CanadaRemembers']
# 1      2017-12-28 20:05:10                     ['#Canada150', '#ParksCanada']
# 2      2017-08-10 19:20:34                            ['#Arctic', '#Nunavut']
# 3      2017-11-06 00:25:05                                 ['#PolarBearWeek']
# 4      2017-11-11 13:15:17             ['#RemembranceDay', '#ParksChallenge']
# ...                    ...                                                ...
# 44998  2017-10-04T08:22:12                                      ["genenergy"]
# 44999  2016-12-08T08:45:08  ["electricvehicles","naturalgas","electricity"...
# 45000  2016-12-08T08:20:07  ["pipeline","canada","economy","replace","natu...
# 45001  2016-12-08T08:17:30  ["pipeline","canada","economy","expansion","tm...
# 45002  2016-12-08T08:15:13  ["line3","pipeline","transmountain","jobs","ca...
#
#                         ...                   num_hahas num_likes num_loves  \
# 0                       ...                         NaN         0       NaN
# 1                       ...                         NaN      1471       NaN
# 2                       ...                         NaN       433       NaN
# 3                       ...                         NaN       373       NaN
# 4                       ...                         NaN       333       NaN
# ...                     ...                         ...       ...       ...
# 44998                   ...                         NaN         3       NaN
# 44999                   ...                         NaN         3       NaN
# 45000                   ...                         NaN         2       NaN
# 45001                   ...                         NaN         1       NaN
# 45002                   ...                         NaN         1       NaN
#
#       num_reactions  num_sads num_shares  num_special num_wows  sentiment  \
# 0               NaN       NaN       2372          NaN      NaN    Neutral
# 1               NaN       NaN        499          NaN      NaN    Neutral
# 2               NaN       NaN        162          NaN      NaN    Neutral
# 3               NaN       NaN        137          NaN      NaN    Neutral
# 4               NaN       NaN        106          NaN      NaN    Neutral
# ...             ...       ...        ...          ...      ...        ...
# 44998           NaN       NaN        NaN          NaN      NaN    neutral
# 44999           NaN       NaN        NaN          NaN      NaN    neutral
# 45000           NaN       NaN        NaN          NaN      NaN    neutral
# 45001           NaN       NaN        NaN          NaN      NaN    neutral
# 45002           NaN       NaN        NaN          NaN      NaN    neutral
#
#                            words_matched_list
# 0                                         NaN
# 1                              ['park', 'or']
# 2                           ['lands', 'park']
# 3                                         NaN
# 4                                    ['park']
# ...                                       ...
# 44998                              ['energy']
# 44999           ['infrastructure', 'funding']
# 45000  ['natural', 'resources', 'government']
# 45001  ['natural', 'resources', 'government']
# 45002                                ['jobs']
#
# [45003 rows x 26 columns]

# %%
pd.options.display.max_rows = 50
try:
    data_df['lemmatized_text'] = data_df['caption_original'].astype(str).apply(lemmatize_text)
except:
    print('cannot process file...')
data_df['Action_matched_keywords'] = data_df['lemmatized_text'].apply(find_matched_keywords)
display(data_df)
# Out:
#              Action_matched_keywords Reactions_SUM  Unnamed: 0  \
# 0                                 []          2372         0.0
# 1                                 []          1970         1.0
# 2                            [learn]           595         2.0
# 3                       [cool, bear]           510         3.0
# 4                                 []           439         4.0
# 5                          [protect]           434         5.0
# 6                                 []           419         6.0
# 7                             [help]           397         7.0
# 8      [care, protecting, ecosystem]           337         8.0
# 9                                 []           330         9.0
# 10                                []           329        10.0
# 11                                []           328        11.0
# 12                                []           324        12.0
# 13                         [protect]           303        13.0
# 14                                []           300        14.0
# 15                                []           293        15.0
# 16                                []           272        16.0
# 17                         [protect]           262        17.0
# 18                                []           257        18.0
# 19                                []           251        19.0
# 20                                []           247        20.0
# 21                                []           246        21.0
# 22                   [help, protect]           242        22.0
# 23                                []           236        23.0
# 24                                []           234        24.0
# ...                              ...           ...         ...
# 44978                             []             7       212.0
# 44979           [energy, low-carbon]             7       213.0
# 44980                 [work, change]             7       214.0
# 44981                       [energy]             6       215.0
# 44982                 [help, reduce]             6       216.0
# 44983                       [energy]             6       217.0
# 44984                             []             6       218.0
# 44985              [address, energy]             6       219.0
# 44986                             []             5       220.0
# 44987                       [energy]             5       221.0
# 44988                             []             5       222.0
# 44989           [low-carbon, energy]             5       223.0
# 44990                       [energy]             5       224.0
# 44991                       [energy]             5       225.0
# 44992                       [energy]             5       226.0
# 44993                       [energy]             5       227.0
# 44994                             []             4       228.0
# 44995                             []             4       229.0
# 44996                       [energy]             4       230.0
# 44997                [energy, learn]             4       231.0
# 44998                             []             3       232.0
# 44999                     [increase]             3       233.0
# 45000                        [learn]             2       234.0
# 45001                        [learn]             1       235.0
# 45002                             []             1       236.0
#
#                            account_name  average_sentiment_score  \
# 0                   ParksCanada_tweeter                -0.155556
# 1                   ParksCanada_tweeter                 0.300000
# 2                   ParksCanada_tweeter                 0.220000
# 3                   ParksCanada_tweeter                 0.214583
# 4                   ParksCanada_tweeter                 0.000000
# 5                   ParksCanada_tweeter                 0.000000
# 6                   ParksCanada_tweeter                 0.258333
# 7                   ParksCanada_tweeter                 0.300000
# 8                   ParksCanada_tweeter                 0.500000
# 9                   ParksCanada_tweeter                 0.280000
# 10                  ParksCanada_tweeter                 1.000000
# 11                  ParksCanada_tweeter                 0.791667
# 12                  ParksCanada_tweeter                 0.375000
# 13                  ParksCanada_tweeter                 0.000000
# 14                  ParksCanada_tweeter                 0.479167
# 15                  ParksCanada_tweeter                 1.000000
# 16                  ParksCanada_tweeter                 0.250000
# 17                  ParksCanada_tweeter                 0.341667
# 18                  ParksCanada_tweeter                 0.252841
# 19                  ParksCanada_tweeter                 1.000000
# 20                  ParksCanada_tweeter                 0.000000
# 21                  ParksCanada_tweeter                 0.000000
# 22                  ParksCanada_tweeter                 1.000000
# 23                  ParksCanada_tweeter                 0.183333
# 24                  ParksCanada_tweeter                 0.000000
# ...                                 ...                      ...
# 44978  naturalresourcescanada_instagram                 0.000000
# 44979  naturalresourcescanada_instagram                 0.000000
# 44980  naturalresourcescanada_instagram                 0.000000
# 44981  naturalresourcescanada_instagram                 0.000000
# 44982  naturalresourcescanada_instagram                 0.000000
# 44983  naturalresourcescanada_instagram                 0.000000
# 44984  naturalresourcescanada_instagram                 0.000000
# 44985  naturalresourcescanada_instagram                 0.000000
# 44986  naturalresourcescanada_instagram                 0.100000
# 44987  naturalresourcescanada_instagram                 0.000000
# 44988  naturalresourcescanada_instagram                 0.000000
# 44989  naturalresourcescanada_instagram                 0.000000
# 44990  naturalresourcescanada_instagram                 0.000000
# 44991  naturalresourcescanada_instagram                 0.000000
# 44992  naturalresourcescanada_instagram                 0.000000
# 44993  naturalresourcescanada_instagram                 0.000000
# 44994  naturalresourcescanada_instagram                 0.000000
# 44995  naturalresourcescanada_instagram                 0.000000
# 44996  naturalresourcescanada_instagram                 0.000000
# 44997  naturalresourcescanada_instagram                 0.000000
# 44998  naturalresourcescanada_instagram                 0.000000
# 44999  naturalresourcescanada_instagram                 0.000000
# 45000  naturalresourcescanada_instagram                 0.000000
# 45001  naturalresourcescanada_instagram                 0.000000
# 45002  naturalresourcescanada_instagram                 0.000000
#
#                                          caption_cleaned  \
# 0      RT CanadianPM 117 000 poppies one Fallen casca...
# 1      big thank incredible Canada150 year behalf ent...
# 2      Qausuittuq National Park officially open Learn...
# 3      first day PolarBearWeek cool photos fun facts ...
# 4      RemembranceDay Honour served country share pho...
# 5      RT WatertonLakesNP Thank crews worked protect ...
# 6      Exciting news Starting 2018 admission ParksCan...
# 7      MentalHealthAwarenessWeek want hear places hel...
# 8      WorldKindnessDay important kind show care prot...
# 9      Baby bats called pups bats one year nursed big...
# 10     Happy NationalForestWeek week celebrating dive...
# 11     Happy LabourDay longweekend perfect time disco...
# 12     RT GCIndigenous UN Int Day IndigenousPeoples l...
# 13     Today WorldAnimalDay See protect speciesatrisk...
# 14     many amazing colours across Canada Thank shari...
# 15     Happy NationalTreeDay featuring Canadian fores...
# 16     sun setting summer sad know perfect time captu...
# 17     Tomorrow able see partial solar eclipse many l...
# 18     NEW starting January 1st admission places yout...
# 19     Happy InternationalMountainDay think Canadian ...
# 20     Today marks 88 years since women recognized pe...
# 21     coolest picture bird taken Share maybe feature...
# 22     Happy WorldHoneyBeeDay Help protect wildlife u...
# 23     October WomensHistoryMonth month long featurin...
# 24     war hero LauraSecord made history warned Briti...
# ...                                                  ...
# 44978  Calling photographers looking photos northern ...
# 44979  Honourable Jim Carr Minister Natural Resources...
# 44980  Joanne White scientist naturally curious want ...
# 44981  clean energy future impact Canadian workforce ...
# 44982  MP Breton announces 7M funding Green Municipal...
# 44983  say energy future Join Min Hehr GenEnergy conv...
# 44984  Funfest Tweet us NRCan picture event using OdySci
# 44985  Minister Natural Resources Honourable Jim Carr...
# 44986  Safety important aspect pipeline infrastructur...
# 44987  Min Duclos vision energy future Share ideas us...
# 44988  Geoscape posters geological information used c...
# 44989  Canada transition low carbon energy future Min...
# 44990  take everything consideration See else Kayla s...
# 44991  energy future matters conversation generation ...
# 44992  Minister McKenna lot say energy future Check G...
# 44993  Join Min Sohi part generation defines Canada e...
# 44994  week GenEnergy forum Min Carr encourages CDNs ...
# 44995  counting GenEnergy forum Min Hajdu invites wat...
# 44996  part conversation generation Join Min Duclos s...
# 44997  Join Min Duclos discuss way forward energy fut...
# 44998  part conversation generation Min Sohi invites ...
# 44999  Funding Budget 2016 increase charging refuelli...
# 45000  Government Canada approved Enbridge Line Repla...
# 45001  Government Canada approved Trans Mountain Expa...
# 45002  Trans Mountain Expansion project Line3 replace...
#
#                                         caption_original       category  \
# 0      RT @CanadianPM: 117,000 poppies, one for each ...        unknown
# 1      A big thank you 🎈 for an incredible #Canada150...  Environmental
# 2      Qausuittuq National Park is officially open! L...  Environmental
# 3      It’s the first day of #PolarBearWeek! ❄️ From ...        unknown
# 4      It’s #RemembranceDay 🇨🇦 Honour those who have ...  Environmental
# 5      RT @WatertonLakesNP: Thank you to all the crew...  Environmental
# 6      Exciting news! Starting in 2018, admission to ...  Environmental
# 7      It’s #MentalHealthAwarenessWeek, so we want to...         Social
# 8      It’s #WorldKindnessDay! It’s so important to b...  Environmental
# 9      Baby #bats are called "pups" and bats have onl...        unknown
# 10     Happy #NationalForestWeek! 🌲 All week, we’ll b...  Environmental
# 11     Happy #LabourDay! The #longweekend is the perf...        unknown
# 12     RT @GCIndigenous: For @UN Int'l Day of World’s...         Social
# 13     Today is #WorldAnimalDay! See what we’re doing...  Environmental
# 14     So many amazing colours across Canada! Thank y...  Environmental
# 15     Happy #NationalTreeDay! We've been featuring o...  Environmental
# 16     The sun is setting on summer. It’s sad  we kn...  Environmental
# 17     Tomorrow you'll be able to see partial solar e...  Environmental
# 18     NEW: starting January 1st, admission to our pl...        unknown
# 19     Happy #InternationalMountainDay! We think #Can...        unknown
# 20     Today marks 88 years since women were recogniz...         Social
# 21     What's the coolest picture of a bird you've ta...  Environmental
# 22     Happy #WorldHoneyBeeDay! 🐝 Help protect #wildl...  Environmental
# 23     October is #WomensHistoryMonth! All month long...         Social
# 24     A war hero, #LauraSecord made history when she...         Social
# ...                                                  ...            ...
# 44978  Calling all photographers! We’re looking for p...  Environmental
# 44979  The Honourable Jim Carr, Canada’s Minister of ...  Environmental
# 44980  Why is Joanne White a scientist? “I’m naturall...         Social
# 44981  How will a clean energy future impact the Cana...         Social
# 44982  MP Breton announces $5.7M in funding to the Gr...  Environmental
# 44983  Have your say in Canada’s energy future! Join ...         Social
# 44984  Are you at ? Tweet us at a picture of you at t...        unknown
# 44985  Canada’s Minister of Natural Resources, the Ho...     Economical
# 44986  Safety is an important aspect of Canada’s pipe...     Economical
# 44987  Min Duclos has a vision for Canada’s energy fu...         Social
# 44988  Geoscape posters with their geological informa...  Environmental
# 44989  How can Canada transition to a low-carbon ener...         Social
# 44990  “We have to take everything under consideratio...         Social
# 44991  Canada’s energy future matters! The conversati...         Social
# 44992  Minister McKenna had a lot to say about our en...         Social
# 44993  Join Min Sohi and be part of the generation th...         Social
# 44994  With only week until the forum, Min Carr encou...     Economical
# 44995  We're counting down until the forum! Min Hajdu...     Economical
# 44996  Be a part of the conversation of a generation....         Social
# 44997  Join Min Duclos as we discuss a way forward fo...         Social
# 44998  Be part of the conversation of a generation! M...     Economical
# 44999  Funding from Budget will increase charging/ref...     Economical
# 45000  The Government of Canada approved the Enbridge...  Environmental
# 45001  The Government of Canada approved the Trans Mo...  Environmental
# 45002  What do the Trans Mountain Eansion project and...     Economical
#
#             date_published                                           hashtags  \
# 0      2017-11-10 22:37:12                               ['#CanadaRemembers']
# 1      2017-12-28 20:05:10                     ['#Canada150', '#ParksCanada']
# 2      2017-08-10 19:20:34                            ['#Arctic', '#Nunavut']
# 3      2017-11-06 00:25:05                                 ['#PolarBearWeek']
# 4      2017-11-11 13:15:17             ['#RemembranceDay', '#ParksChallenge']
# 5      2017-09-16 01:03:37                                      ['#Waterton']
# 6      2017-11-30 19:15:27                          ['#ParksCanada', '#FREE']
# 7      2017-10-01 16:05:15          ['#MentalHealthAwarenessWeek', '#MIAW17']
# 8      2017-11-13 13:10:15                              ['#WorldKindnessDay']
# 9      2017-10-28 18:00:55                              ['#bats', '#BatWeek']
# 10     2017-09-24 12:05:09                ['#NationalForestWeek', '#forests']
# 11     2017-09-04 11:55:10  ['#LabourDay', '#longweekend', '#HiddenGem', '...
# 12     2017-08-09 17:26:32                             ['#IndigenousPeoples']
# 13     2017-10-04 11:55:11              ['#WorldAnimalDay', '#speciesatrisk']
# 14     2017-10-11 16:31:02                                ['#ParksChallenge']
# 15     2017-09-27 16:03:07        ['#NationalTreeDay', '#NationalForestWeek']
# 16     2017-08-17 20:00:53                                ['#ParksChallenge']
# 17     2017-08-20 15:15:12                                                 []
# 18     2017-11-30 22:55:33                                          ['#FREE']
# 19     2017-12-11 13:15:18         ['#InternationalMountainDay', '#Canadian']
# 20     2017-10-18 21:20:12  ['#Canada', '#PersonsDay', '#WomensHistoryMonth']
# 21     2017-08-25 20:01:17                    ['#ParksChallenge', '#Birding']
# 22     2017-08-19 13:20:16  ['#WorldHoneyBeeDay', '#wildlife', '#iNaturali...
# 23     2017-10-01 20:30:17                            ['#WomensHistoryMonth']
# 24     2017-10-14 23:15:08            ['#LauraSecord', '#WomensHistoryMonth']
# ...                    ...                                                ...
# 44978  2016-12-28T07:53:40  ["arcticscience","arctic","science","north","p...
# 44979  2017-02-23T09:49:16  ["nuclear","naturalresources","lowcarbon","eco...
# 44980  2017-03-08T09:45:00  ["womeninscience","stemgirls","girlslovescienc...
# 44981  2017-10-02T14:39:52                                      ["genenergy"]
# 44982  2017-12-01T08:52:07                               ["quebec","cdnmuni"]
# 44983  2017-10-03T09:09:52                                      ["genenergy"]
# 44984  2017-05-13T09:39:22                               ["funfest","odysci"]
# 44985  2017-02-08T05:57:42                                                 []
# 44986  2016-12-08T08:58:20  ["pipeline","safety","infrastructure","natural...
# 44987  2017-10-05T14:03:23                                                 []
# 44988  2017-12-06T08:09:12                                         ["gsc175"]
# 44989  2017-10-05T14:58:52                                      ["genenergy"]
# 44990  2017-08-14T11:16:26     ["genenergy","yourenergyfuture","cleanenergy"]
# 44991  2017-11-03T07:24:17                                      ["genenergy"]
# 44992  2017-09-28T14:09:28                                      ["genenergy"]
# 44993  2017-09-29T14:32:24                                      ["genenergy"]
# 44994  2017-10-03T13:59:23                                      ["genenergy"]
# 44995  2017-10-04T13:30:59                                      ["genenergy"]
# 44996  2017-10-05T12:41:44                                      ["genenergy"]
# 44997  2017-10-05T15:22:28                                      ["genenergy"]
# 44998  2017-10-04T08:22:12                                      ["genenergy"]
# 44999  2016-12-08T08:45:08  ["electricvehicles","naturalgas","electricity"...
# 45000  2016-12-08T08:20:07  ["pipeline","canada","economy","replace","natu...
# 45001  2016-12-08T08:17:30  ["pipeline","canada","economy","expansion","tm...
# 45002  2016-12-08T08:15:13  ["line3","pipeline","transmountain","jobs","ca...
#
#                              ...                         num_likes num_loves  \
# 0                            ...                                 0       NaN
# 1                            ...                              1471       NaN
# 2                            ...                               433       NaN
# 3                            ...                               373       NaN
# 4                            ...                               333       NaN
# 5                            ...                                 0       NaN
# 6                            ...                               245       NaN
# 7                            ...                               281       NaN
# 8                            ...                               230       NaN
# 9                            ...                               244       NaN
# 10                           ...                               219       NaN
# 11                           ...                               231       NaN
# 12                           ...                                 0       NaN
# 13                           ...                               213       NaN
# 14                           ...                               223       NaN
# 15                           ...                               211       NaN
# 16                           ...                               221       NaN
# 17                           ...                               164       NaN
# 18                           ...                               162       NaN
# 19                           ...                               182       NaN
# 20                           ...                               159       NaN
# 21                           ...                               195       NaN
# 22                           ...                               163       NaN
# 23                           ...                               137       NaN
# 24                           ...                               162       NaN
# ...                          ...                               ...       ...
# 44978                        ...                                 7       NaN
# 44979                        ...                                 7       NaN
# 44980                        ...                                 7       NaN
# 44981                        ...                                 6       NaN
# 44982                        ...                                 6       NaN
# 44983                        ...                                 6       NaN
# 44984                        ...                                 6       NaN
# 44985                        ...                                 6       NaN
# 44986                        ...                                 4       NaN
# 44987                        ...                                 5       NaN
# 44988                        ...                                 5       NaN
# 44989                        ...                                 5       NaN
# 44990                        ...                                 5       NaN
# 44991                        ...                                 5       NaN
# 44992                        ...                                 5       NaN
# 44993                        ...                                 5       NaN
# 44994                        ...                                 4       NaN
# 44995                        ...                                 4       NaN
# 44996                        ...                                 4       NaN
# 44997                        ...                                 4       NaN
# 44998                        ...                                 3       NaN
# 44999                        ...                                 3       NaN
# 45000                        ...                                 2       NaN
# 45001                        ...                                 1       NaN
# 45002                        ...                                 1       NaN
#
#       num_reactions num_sads  num_shares num_special  num_wows sentiment  \
# 0               NaN      NaN        2372         NaN       NaN   Neutral
# 1               NaN      NaN         499         NaN       NaN   Neutral
# 2               NaN      NaN         162         NaN       NaN   Neutral
# 3               NaN      NaN         137         NaN       NaN   Neutral
# 4               NaN      NaN         106         NaN       NaN   Neutral
# 5               NaN      NaN         434         NaN       NaN   Neutral
# 6               NaN      NaN         174         NaN       NaN   Neutral
# 7               NaN      NaN         116         NaN       NaN   Neutral
# 8               NaN      NaN         107         NaN       NaN  Positive
# 9               NaN      NaN          86         NaN       NaN   Neutral
# 10              NaN      NaN         110         NaN       NaN  Positive
# 11              NaN      NaN          97         NaN       NaN  Positive
# 12              NaN      NaN         324         NaN       NaN  Positive
# 13              NaN      NaN          90         NaN       NaN   Neutral
# 14              NaN      NaN          77         NaN       NaN  Positive
# 15              NaN      NaN          82         NaN       NaN  Positive
# 16              NaN      NaN          51         NaN       NaN   Neutral
# 17              NaN      NaN          98         NaN       NaN  Positive
# 18              NaN      NaN          95         NaN       NaN   Neutral
# 19              NaN      NaN          69         NaN       NaN  Positive
# 20              NaN      NaN          88         NaN       NaN   Neutral
# 21              NaN      NaN          51         NaN       NaN   Neutral
# 22              NaN      NaN          79         NaN       NaN  Positive
# 23              NaN      NaN          99         NaN       NaN   Neutral
# 24              NaN      NaN          72         NaN       NaN   Neutral
# ...             ...      ...         ...         ...       ...       ...
# 44978           NaN      NaN         NaN         NaN       NaN   neutral
# 44979           NaN      NaN         NaN         NaN       NaN   neutral
# 44980           NaN      NaN         NaN         NaN       NaN   neutral
# 44981           NaN      NaN         NaN         NaN       NaN   neutral
# 44982           NaN      NaN         NaN         NaN       NaN   neutral
# 44983           NaN      NaN         NaN         NaN       NaN   neutral
# 44984           NaN      NaN         NaN         NaN       NaN   neutral
# 44985           NaN      NaN         NaN         NaN       NaN   neutral
# 44986           NaN      NaN         NaN         NaN       NaN  positive
# 44987           NaN      NaN         NaN         NaN       NaN   neutral
# 44988           NaN      NaN         NaN         NaN       NaN   neutral
# 44989           NaN      NaN         NaN         NaN       NaN   neutral
# 44990           NaN      NaN         NaN         NaN       NaN   neutral
# 44991           NaN      NaN         NaN         NaN       NaN   neutral
# 44992           NaN      NaN         NaN         NaN       NaN   neutral
# 44993           NaN      NaN         NaN         NaN       NaN   neutral
# 44994           NaN      NaN         NaN         NaN       NaN   neutral
# 44995           NaN      NaN         NaN         NaN       NaN   neutral
# 44996           NaN      NaN         NaN         NaN       NaN   neutral
# 44997           NaN      NaN         NaN         NaN       NaN   neutral
# 44998           NaN      NaN         NaN         NaN       NaN   neutral
# 44999           NaN      NaN         NaN         NaN       NaN   neutral
# 45000           NaN      NaN         NaN         NaN       NaN   neutral
# 45001           NaN      NaN         NaN         NaN       NaN   neutral
# 45002           NaN      NaN         NaN         NaN       NaN   neutral
#
#                                      words_matched_list  \
# 0                                                   NaN
# 1                                        ['park', 'or']
# 2                                     ['lands', 'park']
# 3                                                   NaN
# 4                                              ['park']
# 5                      ['water', 'park', 'lakes', 'or']
# 6                                        ['park', 'or']
# 7                                            ['health']
# 8                   ['ecosystem', 'biodiversity', 'or']
# 9                                                   NaN
# 10                                       ['park', 'or']
# 11                                                  NaN
# 12               ['culture', 'diversity', 'indigenous']
# 13                                    ['species', 'or']
# 14                                             ['park']
# 15                                       ['tree', 'or']
# 16                                      ['park', 'mer']
# 17                                      ['or', 'solar']
# 18                                                  NaN
# 19                                                  NaN
# 20                                            ['women']
# 21                                     ['park', 'bird']
# 22              ['wildlife', 'natural', 'or', 'nature']
# 23                                            ['women']
# 24                                            ['women']
# ...                                                 ...
# 44978      ['lands', 'lake ', 'ice', 'landscape', 'or']
# 44979  ['carbon', 'natural', 'resources', 'low carbon']
# 44980              ['ami', 'health', 'change', 'women']
# 44981                               ['future', 'futur']
# 44982                        ['water', 'green ', 'air']
# 44983                               ['future', 'futur']
# 44984                                               NaN
# 44985                            ['energy', 'minister']
# 44986                      ['import', 'infrastructure']
# 44987                               ['future', 'futur']
# 44988                                            ['or']
# 44989                               ['future', 'futur']
# 44990                               ['future', 'futur']
# 44991                               ['future', 'futur']
# 44992                               ['future', 'futur']
# 44993                               ['future', 'futur']
# 44994                                        ['energy']
# 44995                                        ['energy']
# 44996                               ['future', 'futur']
# 44997                               ['future', 'futur']
# 44998                                        ['energy']
# 44999                     ['infrastructure', 'funding']
# 45000            ['natural', 'resources', 'government']
# 45001            ['natural', 'resources', 'government']
# 45002                                          ['jobs']
#
#                                          lemmatized_text
# 0      [rt, canadianpm, 117000, poppy, one, canada's,...
# 1      [big, thank, incredible, canada150, year, beha...
# 2      [qausuittuq, national, park, officially, open,...
# 3      [the, first, day, polarbearweek, ❄️, cool, pho...
# 4      [remembranceday, 🇨🇦, honour, served, country, ...
# 5      [rt, watertonlakesnp, thank, the, crew, worked...
# 6      [exciting, news, starting, 2018, admission, pa...
# 7      [mentalhealthawarenessweek, want, hear, you, p...
# 8      [worldkindnessday, important, kind, the, show,...
# 9      [baby, bat, called, pup, bat, one, year, nurse...
# 10     [happy, nationalforestweek, week, we'll, celeb...
# 11     [happy, labourday, the, longweekend, the, perf...
# 12     [rt, gcindigenous, un, int'l, day, world's, in...
# 13     [today, worldanimalday, see, protect, speciesa...
# 14     [many, amazing, colour, across, canada, thank,...
# 15     [happy, nationaltreeday, featuring, canadian, ...
# 16     [the, sun, setting, summer, sad, know, the, pe...
# 17     [tomorrow, able, see, partial, solar, eclipse,...
# 18     [new, starting, january, 1st, admission, place...
# 19     [happy, internationalmountainday, think, canad...
# 20     [today, mark, 88, year, since, woman, recogniz...
# 21     [what's, the, coolest, picture, bird, taken, s...
# 22     [happy, worldhoneybeeday, help, protect, wildl...
# 23     [october, womenshistorymonth, month, long, we'...
# 24     [war, hero, laurasecord, made, history, warned...
# ...                                                  ...
# 44978  [calling, photographer, looking, photo, canada...
# 44979  [the, honourable, jim, carr, canada's, ministe...
# 44980  [joanne, white, scientist, “i'm, naturally, cu...
# 44981  [clean, energy, future, impact, the, canadian,...
# 44982  [mp, breton, announces, 57m, funding, the, gre...
# 44983  [say, canada's, energy, future, join, min, heh...
# 44984                [tweet, picture, the, event, using]
# 44985  [canada's, minister, natural, resources, the, ...
# 44986  [safety, important, aspect, canada's, pipeline...
# 44987  [min, duclos, vision, canada's, energy, future...
# 44988  [geoscape, poster, geological, information, us...
# 44989  [canada, transition, low-carbon, energy, futur...
# 44990  [“we, take, everything, consideration”, see, e...
# 44991  [canada's, energy, future, matter, the, conver...
# 44992  [minister, mckenna, lot, say, energy, future, ...
# 44993  [join, min, sohi, part, the, generation, defin...
# 44994  [week, the, forum, min, carr, encourages, cdns...
# 44995  [counting, down, the, forum, min, hajdu, invit...
# 44996  [part, the, conversation, generation, join, mi...
# 44997  [join, min, duclos, discus, way, forward, cana...
# 44998  [part, the, conversation, generation, min, soh...
# 44999  [funding, budget, increase, chargingrefuelling...
# 45000  [the, government, canada, approved, the, enbri...
# 45001  [the, government, canada, approved, the, trans...
# 45002  [the, trans, mountain, eansion, project, repla...
#
# [45003 rows x 27 columns]

# %%
pd.options.display.max_rows = 100
output_df = data_df[data_df['Action_matched_keywords'].astype(str) != '[]']
output_df = output_df[OUTPUT_COLS]
output_df.to_csv(outputDir + 'q5q6_merged_ouput_EN.csv', index=None, encoding='utf-8')
output_df
# Out:
#                         id       date_published  \
# 2       895726583729856513  2017-08-10 19:20:34
# 3       927330962379366402  2017-11-06 00:25:05
# 5       908858879999713280  2017-09-16 01:03:37
# 7       914521600485191680  2017-10-01 16:05:15
# 8       930060241269673984  2017-11-13 13:10:15
# 13      915545833017413632  2017-10-04 11:55:11
# 17      899288715738132481  2017-08-20 15:15:12
# 22      898897405738930176  2017-08-19 13:20:16
# 26      915992557456207872  2017-10-05 17:30:18
# 30      944005857536282624  2017-12-22 00:45:09
# 38      915014827923341313  2017-10-03 00:45:09
# 39      922923213276905472  2017-10-24 20:30:15
# 40      928750340308160513  2017-11-09 22:25:11
# 47      934496930356518912  2017-11-25 19:00:04
# 51      937827636948152320  2017-12-04 23:35:07
# 54      925407362290208774  2017-10-31 17:01:23
# 55      924712689238233089  2017-10-29 19:01:00
# 59      913557739753918465  2017-09-29 00:15:12
# 62      897452885402763264  2017-08-15 13:40:16
# 63      920318924201349121  2017-10-17 16:01:44
# 71      917847267578662914  2017-10-10 20:20:16
# 72      900877993878458368  2017-08-25 00:30:25
# 74      921088974516518914  2017-10-19 19:01:39
# 76      894541190795800577  2017-08-07 12:50:14
# 79      922436260878278659  2017-10-23 12:15:17
# 80      923187886656315401  2017-10-25 14:01:58
# 82      929733174749515776  2017-11-12 15:30:37
# 84      907404690568237056  2017-09-12 00:45:11
# 85      931524919686516736  2017-11-17 14:10:22
# 86      916332663107149824  2017-10-06 16:01:46
# 87      907175763375529984  2017-09-11 09:35:31
# 88      933409955016736770  2017-11-22 19:00:49
# 92      941796295978741760  2017-12-15 22:25:09
# 95      930949831647989762  2017-11-16 00:05:10
# 96      913101124470808587  2017-09-27 18:00:47
# 101     911578446203097088  2017-09-23 13:10:12
# 105     902298535646855168  2017-08-28 22:35:09
# 106     912333434420416512  2017-09-25 15:10:15
# 107     943562001422471168  2017-12-20 19:21:26
# 108     937033785949945856  2017-12-02 19:00:38
# 110     919534611729920000  2017-10-15 12:05:10
# 113     912775078261219328  2017-09-26 20:25:11
# 115     896691589917155328  2017-08-13 11:15:09
# 120     937699327887241216  2017-12-04 15:05:16
# 121     893213161788198912  2017-08-03 20:53:07
# 124     921043623327817728  2017-10-19 16:01:26
# 127     917125213283934210  2017-10-08 20:31:04
# 133     915245481818824704  2017-10-03 16:01:41
# 134     933676559369756673  2017-11-23 12:40:13
# 135     921805888855388160  2017-10-21 18:30:24
# ...                    ...                  ...
# 44912  2017-01-25_11-33-09  2017-01-25T11:33:09
# 44913  2017-02-28_06-36-25  2017-02-28T06:36:25
# 44914  2017-10-19_11-23-30  2017-10-19T11:23:30
# 44917  2017-08-02_12-16-27  2017-08-02T12:16:27
# 44918  2017-09-14_13-45-18  2017-09-14T13:45:18
# 44919  2016-12-20_10-49-25  2016-12-20T10:49:25
# 44920  2017-08-09_08-29-30  2017-08-09T08:29:30
# 44922  2017-02-20_11-28-50  2017-02-20T11:28:50
# 44923  2017-07-18_08-09-26  2017-07-18T08:09:26
# 44925  2017-06-21_13-18-09  2017-06-21T13:18:09
# 44927  2017-06-23_08-21-36  2017-06-23T08:21:36
# 44928  2017-11-15_08-32-26  2017-11-15T08:32:26
# 44929  2017-10-27_12-23-10  2017-10-27T12:23:10
# 44931  2017-06-07_12-10-59  2017-06-07T12:10:59
# 44933  2017-10-02_10-26-35  2017-10-02T10:26:35
# 44934  2017-02-24_10-31-03  2017-02-24T10:31:03
# 44936  2017-12-07_07-37-43  2017-12-07T07:37:43
# 44937  2017-11-14_11-51-33  2017-11-14T11:51:33
# 44938  2017-12-04_11-37-04  2017-12-04T11:37:04
# 44939  2017-10-24_07-19-41  2017-10-24T07:19:41
# 44940  2017-10-12_15-33-30  2017-10-12T15:33:30
# 44942  2017-06-07_12-12-10  2017-06-07T12:12:10
# 44944  2017-02-23_12-52-03  2017-02-23T12:52:03
# 44945  2017-02-24_14-01-56  2017-02-24T14:01:56
# 44948  2017-09-27_13-31-36  2017-09-27T13:31:36
# 44949  2017-08-15_05-45-18  2017-08-15T05:45:18
# 44951  2017-08-22_10-30-37  2017-08-22T10:30:37
# 44952  2017-10-06_05-50-49  2017-10-06T05:50:49
# 44962  2017-02-16_11-05-26  2017-02-16T11:05:26
# 44966  2017-02-02_11-20-52  2017-02-02T11:20:52
# 44967  2017-09-29_11-14-47  2017-09-29T11:14:47
# 44973  2017-10-24_08-03-04  2017-10-24T08:03:04
# 44976  2017-07-13_07-58-04  2017-07-13T07:58:04
# 44979  2017-02-23_09-49-16  2017-02-23T09:49:16
# 44980  2017-03-08_09-45-00  2017-03-08T09:45:00
# 44981  2017-10-02_14-39-52  2017-10-02T14:39:52
# 44982  2017-12-01_08-52-07  2017-12-01T08:52:07
# 44983  2017-10-03_09-09-52  2017-10-03T09:09:52
# 44985  2017-02-08_05-57-42  2017-02-08T05:57:42
# 44987  2017-10-05_14-03-23  2017-10-05T14:03:23
# 44989  2017-10-05_14-58-52  2017-10-05T14:58:52
# 44990  2017-08-14_11-16-26  2017-08-14T11:16:26
# 44991  2017-11-03_07-24-17  2017-11-03T07:24:17
# 44992  2017-09-28_14-09-28  2017-09-28T14:09:28
# 44993  2017-09-29_14-32-24  2017-09-29T14:32:24
# 44996  2017-10-05_12-41-44  2017-10-05T12:41:44
# 44997  2017-10-05_15-22-28  2017-10-05T15:22:28
# 44999  2016-12-08_08-45-08  2016-12-08T08:45:08
# 45000  2016-12-08_08-20-07  2016-12-08T08:20:07
# 45001  2016-12-08_08-17-30  2016-12-08T08:17:30
#
#                                                     link  \
# 2      ['https://t.co/3kCgJN4RYV', 'https://t.co/8d6M...
# 3                            ['https://t.co/3SraumhUxm']
# 5                            ['https://t.co/TzqLZx9U0L']
# 7                            ['https://t.co/RtNVJ0U5ZO']
# 8                            ['https://t.co/A0Rz84ahSv']
# 13     ['https://t.co/nlPZZ6s2fj', 'https://t.co/pczk...
# 17     ['https://t.co/QMM6AKVd0w', 'https://t.co/71Kw...
# 22     ['https://t.co/m16HnF1pjH', 'https://t.co/SH1r...
# 26                           ['https://t.co/L4MXjRMi8S']
# 30     ['https://t.co/GyXd6fMmx', 'https://t.co/ZdgQY...
# 38     ['https://t.co/DYCeWtNo', 'https://t.co/GntoHL...
# 39     ['https://t.co/hLy7plaOYO', 'https://t.co/VSZP...
# 40                           ['https://t.co/uSjOdFphFr']
# 47                           ['https://t.co/Xa5o4oIJAk']
# 51     ['https://t.co/iiirhsNPU4', 'https://t.co/tsCX...
# 54                           ['https://t.co/ki9xgEgeVo']
# 55                           ['https://t.co/RZUu26WYqx']
# 59                            ['https://t.co/4KNvYyw3B']
# 62                           ['https://t.co/enDD8fhFXJ']
# 63                           ['https://t.co/Pkp8z836so']
# 71                           ['https://t.co/75Syip31bx']
# 72     ['https://t.co/d3iAjTQkHF', 'https://t.co/DtDw...
# 74                           ['https://t.co/fQsgrqI7kn']
# 76                            ['https://t.co/hb3maF4Qs']
# 79     ['https://t.co/jwFTL0xIuh', 'https://t.co/b3ih...
# 80                           ['https://t.co/Ya4i5f9lsl']
# 82     ['https://t.co/VbYXGS5hYE', 'https://t.co/Sc9J...
# 84                           ['https://t.co/j2xtgOz2I6']
# 85     ['https://t.co/VbYXGS5hYE', 'https://t.co/U1Cv...
# 86                           ['https://t.co/OyIWE3pjLQ']
# 87                                                    []
# 88                           ['https://t.co/MZasuL9cx5']
# 92     ['https://t.co/wFoySQCS13', 'https://t.co/a72C...
# 95     ['https://t.co/Mof0i0KiB5', 'https://t.co/bKJY...
# 96                           ['https://t.co/x3d6dLLosZ']
# 101                          ['https://t.co/GcLku1fOEq']
# 105                           ['https://t.co/bfigIZoqX']
# 106                          ['https://t.co/lccG4vwW4M']
# 107    ['https://t.co/WfLoF8xjSX', 'https://t.co/Pj97...
# 108                          ['https://t.co/fAykAavu0t']
# 110    ['https://t.co/BZVgZZ4JGo', 'https://t.co/A2BQ...
# 113                          ['https://t.co/NBKiGJZWo3']
# 115    ['https://t.co/UB5DBoyaWr', 'https://t.co/Z05E...
# 120    ['https://t.co/qMKddBGJ5B', 'https://t.co/rFKk...
# 121    ['https://t.co/5C8bIz3JDe', 'https://t.co/wYNP...
# 124                          ['https://t.co/ukprsWeE0n']
# 127                           ['https://t.co/CXNAQ12iv']
# 133                          ['https://t.co/vmV4mq7SC5']
# 134                          ['https://t.co/R9NL38JzNi']
# 135                           ['https://t.co/Q7zZLF1ua']
# ...                                                  ...
# 44912  https://instagram.fyvr3-1.fna.fbcdn.net/vp/37e...
# 44913  https://instagram.fyvr3-1.fna.fbcdn.net/vp/87a...
# 44914  https://instagram.fyvr3-1.fna.fbcdn.net/vp/136...
# 44917  https://instagram.fyvr3-1.fna.fbcdn.net/vp/3db...
# 44918  https://instagram.fyvr3-1.fna.fbcdn.net/vp/c01...
# 44919  https://instagram.fyvr3-1.fna.fbcdn.net/vp/39e...
# 44920  https://instagram.fyvr3-1.fna.fbcdn.net/vp/3bc...
# 44922  https://instagram.fyvr3-1.fna.fbcdn.net/vp/0e3...
# 44923  https://instagram.fyvr3-1.fna.fbcdn.net/vp/357...
# 44925  https://instagram.fyvr3-1.fna.fbcdn.net/vp/0b6...
# 44927  https://instagram.fyvr3-1.fna.fbcdn.net/vp/d73...
# 44928  https://instagram.fyvr3-1.fna.fbcdn.net/vp/648...
# 44929  https://instagram.fyvr3-1.fna.fbcdn.net/vp/2c2...
# 44931  https://instagram.fyvr3-1.fna.fbcdn.net/vp/17d...
# 44933  https://instagram.fyvr3-1.fna.fbcdn.net/vp/c14...
# 44934  https://instagram.fyvr3-1.fna.fbcdn.net/vp/b4e...
# 44936  https://instagram.fyvr3-1.fna.fbcdn.net/vp/b73...
# 44937  https://instagram.fyvr3-1.fna.fbcdn.net/vp/372...
# 44938  https://instagram.fyvr3-1.fna.fbcdn.net/vp/932...
# 44939  https://instagram.fyvr3-1.fna.fbcdn.net/vp/2ac...
# 44940  https://instagram.fyvr3-1.fna.fbcdn.net/vp/fa5...
# 44942  https://instagram.fyvr3-1.fna.fbcdn.net/vp/22a...
# 44944  https://instagram.fyvr3-1.fna.fbcdn.net/vp/e99...
# 44945  https://instagram.fyvr3-1.fna.fbcdn.net/vp/994...
# 44948  https://instagram.fyvr3-1.fna.fbcdn.net/vp/eef...
# 44949  https://instagram.fyvr3-1.fna.fbcdn.net/vp/47f...
# 44951  https://instagram.fyvr3-1.fna.fbcdn.net/vp/0d6...
# 44952  https://instagram.fyvr3-1.fna.fbcdn.net/vp/37e...
# 44962  https://instagram.fyvr3-1.fna.fbcdn.net/vp/eea...
# 44966  https://instagram.fyvr3-1.fna.fbcdn.net/vp/b2f...
# 44967  https://instagram.fyvr3-1.fna.fbcdn.net/vp/056...
# 44973  https://instagram.fyvr3-1.fna.fbcdn.net/vp/a81...
# 44976  https://instagram.fyvr3-1.fna.fbcdn.net/vp/305...
# 44979  https://instagram.fyvr3-1.fna.fbcdn.net/vp/338...
# 44980  https://instagram.fyvr3-1.fna.fbcdn.net/vp/b1b...
# 44981  https://instagram.fyvr3-1.fna.fbcdn.net/vp/f63...
# 44982  https://instagram.fyvr3-1.fna.fbcdn.net/vp/9c0...
# 44983  https://instagram.fyvr3-1.fna.fbcdn.net/vp/507...
# 44985  https://instagram.fyvr3-1.fna.fbcdn.net/vp/80e...
# 44987  https://instagram.fyvr3-1.fna.fbcdn.net/vp/280...
# 44989  https://instagram.fyvr3-1.fna.fbcdn.net/vp/244...
# 44990  https://instagram.fyvr3-1.fna.fbcdn.net/vp/4b9...
# 44991  https://instagram.fyvr3-1.fna.fbcdn.net/vp/ad2...
# 44992  https://instagram.fyvr3-1.fna.fbcdn.net/vp/c1f...
# 44993  https://instagram.fyvr3-1.fna.fbcdn.net/vp/2a5...
# 44996  https://instagram.fyvr3-1.fna.fbcdn.net/vp/967...
# 44997  https://instagram.fyvr3-1.fna.fbcdn.net/vp/9e3...
# 44999  https://instagram.fyvr3-1.fna.fbcdn.net/vp/e87...
# 45000  https://instagram.fyvr3-1.fna.fbcdn.net/vp/12b...
# 45001  https://instagram.fyvr3-1.fna.fbcdn.net/vp/c0d...
#
#                                         caption_original  \
# 2      Qausuittuq National Park is officially open! L...
# 3      It’s the first day of #PolarBearWeek! ❄️ From ...
# 5      RT @WatertonLakesNP: Thank you to all the crew...
# 7      It’s #MentalHealthAwarenessWeek, so we want to...
# 8      It’s #WorldKindnessDay! It’s so important to b...
# 13     Today is #WorldAnimalDay! See what we’re doing...
# 17     Tomorrow you'll be able to see partial solar e...
# 22     Happy #WorldHoneyBeeDay! 🐝 Help protect #wildl...
# 26     Get out &amp; experience the colours of fall! ...
# 30     It’s officially the shortest day of the year… ...
# 38     A day of #hiking will take you to #TwinFalls. ...
# 39     October 24-31 is #BatWeek! We're proud to prot...
# 40     Too cute! ☺️ At birth, polar bear cubs like th...
# 47     Take a walk on the wild side! See how #science...
# 51     Happy #WorldWildlifeConservationDay! 🦋🐻🐢 Parks...
# 54     Little brown #bats are very efficient hunters ...
# 55     #DYK #bats native to Canada are insect-eaters ...
# 59     Home sweet home! 🏡 Bears, wolves, and deer all...
# 62     It’s #NationalAcadianDay! 🎉 Celebrate with a v...
# 63     We love keeping our national parks free of was...
# 71     This #WorldMentalHealthDay let us know where y...
# 72     Make your end of #summer count! From eating s’...
# 74     We know you love the fall colours, now we want...
# 76     Happy #LighthouseDay! #DYK the oldest survivin...
# 79     It's polar bear season in Wapusk NP! Can’t mak...
# 80     #Funfact: Peregrine falcons can stoop dive to ...
# 82     It’s not too late for a Fall adventure! Avoid ...
# 84     This #MotivationMonday escape the hustle + bus...
# 85     The trails are calling, it’s  #TakeAHikeDay! G...
# 86     #ParksChallenge: Share your #fall photos! #DYK...
# 87     RT @WatertonLakesNP: The Kenow Fire is demonst...
# 88     Incoming Bison delivery! See how Bison are tra...
# 92     How exciting! On Dec. 27, the @TenorsMusic wil...
# 95     Plan the perfect visit for viewing wildlife: h...
# 96     From the giant trees in BC to saplings in #PEI...
# 101    It's #InternationalRabbitDay! Rabbits and hare...
# 105    Summer is coming to an end, and what an amazin...
# 106    #DYK the #borealforest is one of the largest #...
# 107    From coast to coast to coast, these are the 8 ...
# 108    You’ve heard of the chicken crossing the road,...
# 110    This #WomensHistoryMonth learn more about one ...
# 113    The #Acadianforest is absolutely stunning in t...
# 115    The tall ships are heading to both #PortRoyalN...
# 120    WOW! 😮 #DYK Canada has the longest coastline i...
# 121    Planning a trip to the mountain parks? Make su...
# 124    91% of plastic produced since the 50s isn’t re...
# 127    #DYK that we've been working with partners for...
# 133    Beresford Bay, a turquoise fishing spot on the...
# 134    From sea to sea to sea, national marine conser...
# 135    Think picnics and outdoor adventures are done ...
# ...                                                  ...
# 44912  Your future matters! Protecting the and growin...
# 44913  Entomologist Johanne Delisle says science is a...
# 44914  – Canadian innovation was showcased during the...
# 44917  What will it take to fight ? A team of the bes...
# 44918  Participants are asked, “What impactful change...
# 44919  Want a chance to be featured in a GoC Polar Co...
# 44920  “The potential of tapping into the resources t...
# 44922  Research scientist Suzanne Paradis is the mode...
# 44923  DYK Canada is a world leader in carbon capture...
# 44925  Imani has some innovative ideas about ’s energ...
# 44927  Emorose wants his energy future to be nothing ...
# 44928  to the City of Medicine Hat! Proud to support ...
# 44929  “There is a transition underway within the ene...
# 44931  Min Carr met with Minister Jiang Daming to pro...
# 44933  How can we support the growing sector in Canad...
# 44934  Meet Lynn Johnston, Wildland Fire Researcher. ...
# 44936  Stewart River, : Steamers like the Alaska were...
# 44937  Did you know that methane accounts for roughly...
# 44938  We’re preparing young Canadians for the econom...
# 44939  Here’s what Fatih Birol said about the Global ...
# 44940  Elains the carbon capture and storage (CCS) pr...
# 44942  Min Carr underlined the support for CNNC Joint...
# 44944  Minister Carr and Parliamentary Secretary Rudd...
# 44945  Do you love forests? Grab your smartphone and ...
# 44948  says the youth of 🇨🇦 are going to change the w...
# 44949  Minister Carr hears from representatives on an...
# 44951  Energy systems that are resilient to climate c...
# 44952  Min O’Regan of wants you to let us know what o...
# 44962  Canada’s Minister of Natural Resources, the Ho...
# 44966  The Honourable Jim Carr, Canada’s Minister of ...
# 44967  Min Sohi envisions a future where we diversify...
# 44973  “…tomorrow's energy future may be more sustain...
# 44976  We're making high energy intensity a situation...
# 44979  The Honourable Jim Carr, Canada’s Minister of ...
# 44980  Why is Joanne White a scientist? “I’m naturall...
# 44981  How will a clean energy future impact the Cana...
# 44982  MP Breton announces $5.7M in funding to the Gr...
# 44983  Have your say in Canada’s energy future! Join ...
# 44985  Canada’s Minister of Natural Resources, the Ho...
# 44987  Min Duclos has a vision for Canada’s energy fu...
# 44989  How can Canada transition to a low-carbon ener...
# 44990  “We have to take everything under consideratio...
# 44991  Canada’s energy future matters! The conversati...
# 44992  Minister McKenna had a lot to say about our en...
# 44993  Join Min Sohi and be part of the generation th...
# 44996  Be a part of the conversation of a generation....
# 44997  Join Min Duclos as we discuss a way forward fo...
# 44999  Funding from Budget will increase charging/ref...
# 45000  The Government of Canada approved the Enbridge...
# 45001  The Government of Canada approved the Trans Mo...
#
#                                          caption_cleaned  \
# 2      Qausuittuq National Park officially open Learn...
# 3      first day PolarBearWeek cool photos fun facts ...
# 5      RT WatertonLakesNP Thank crews worked protect ...
# 7      MentalHealthAwarenessWeek want hear places hel...
# 8      WorldKindnessDay important kind show care prot...
# 13     Today WorldAnimalDay See protect speciesatrisk...
# 17     Tomorrow able see partial solar eclipse many l...
# 22     Happy WorldHoneyBeeDay Help protect wildlife u...
# 26     Get amp experience colours fall Grab scarf hea...
# 30     officially shortest day WinterSolstice Take ad...
# 38     day hiking take TwinFalls Share photo historic...
# 39     October 24 31 BatWeek proud protect bats criti...
# 40     cute birth polar bear cubs like size mothers p...
# 47     Take walk wild side See science helps bears ad...
# 51     Happy WorldWildlifeConservationDay Parks Canad...
# 54     Little brown bats efficient hunters capable ca...
# 55     DYK bats native Canada insect eaters typically...
# 59     Home sweet home Bears wolves deer live Montane...
# 62     NationalAcadianDay Celebrate visit NHS learn A...
# 63     love keeping national parks free waste Conside...
# 71     WorldMentalHealthDay let us know spend daily m...
# 72     Make end summer count eating mores stargazing ...
# 74     know love fall colours want see enjoying Show ...
# 76     Happy LighthouseDay DYK oldest surviving light...
# 79     polar bear season Wapusk NP make visit Check p...
# 80     Funfact Peregrine falcons stoop dive speeds 30...
# 82     late Fall adventure Avoid Premature Hibernatio...
# 84     MotivationMonday escape hustle bustle plan wee...
# 85     trails calling TakeAHikeDay Get outside avoid ...
# 86     ParksChallenge Share fall photos DYK autumn pl...
# 87     RT WatertonLakesNP Kenow Fire demonstrating in...
# 88     Incoming Bison delivery See Bison trans locate...
# 92     exciting Dec 27 TenorsMusic release NEW Auld L...
# 95     Plan perfect visit viewing wildlife https co M...
# 96     giant trees BC saplings PEI Canadian forests e...
# 101    InternationalRabbitDay Rabbits hares expert ca...
# 105    Summer coming end amazing summer start plannin...
# 106    DYK borealforest one largest ecosystems Bears ...
# 107    coast coast coast special spotsadded tentative...
# 108    heard chicken crossing road fish Watch fish mi...
# 110    WomensHistoryMonth learn one fiercest advocate...
# 113    Acadianforest absolutely stunning Fall Plan vi...
# 115    tall ships heading PortRoyalNHS FortAnneNHS Ce...
# 120    WOW DYK Canada longest coastline world 243 000...
# 121    Planning trip mountain parks Make sure check h...
# 124    91 plastic produced since 50s recycled Minimiz...
# 127    DYK working partners 50 yrs protect whooping c...
# 133    Beresford Bay turquoise fishing spot remote we...
# 134    sea sea sea national marine conservation areas...
# 135    Think picnics outdoor adventures done year Par...
# ...                                                  ...
# 44912  PMYouthCouncil future matters Protecting Envir...
# 44913  Entomologist Johanne Delisle says science priv...
# 44914  ICYMI Canadian CleanTech innovation showcased ...
# 44917  take fight ClimateChange nA team best clean en...
# 44918  Participants asked impactful changes occurred ...
# 44919  Want chance featured GoC Polar Continental She...
# 44920  potential tapping resources North gives us opp...
# 44922  Research scientist Suzanne Paradis modern day ...
# 44923  DYK Canada world leader carbon capture storage...
# 44925  Imani innovative ideas energy future Find say ...
# 44927  Emorose wants energy future nothing short beau...
# 44928  Congratulations City Medicine Hat Proud suppor...
# 44929  transition underway within energy sector Debor...
# 44931  Min Carr met Minister Jiang Daming promote bil...
# 44933  support growing CleanTech sector Canada Join M...
# 44934  Meet Lynn Johnston Wildland Fire Researcher re...
# 44936  TBT Stewart River 1939 Steamers like Alaska ke...
# 44937  know methane accounts roughly 15 total GHG emi...
# 44938  preparing young Canadians economy future inves...
# 44939  Fatih Birol said Global Energy Outlook GenEner...
# 44940  Explains carbon capture storage CCS process ca...
# 44942  Min Carr underlined GoC support CNNC Joint Ven...
# 44944  Minister Carr Parliamentary Secretary Rudd dis...
# 44945  love forests Grab smartphone get local forest ...
# 44948  sciencemin says youth going change way power l...
# 44949  Minister Carr hears youth representatives Clea...
# 44951  Energy systems resilient climate change import...
# 44952  Min Regan veteransaffairscanada wants let us k...
# 44962  Minister Natural Resources Honourable Jim Carr...
# 44966  Honourable Jim Carr Minister Natural Resources...
# 44967  Min Sohi envisions future diversify energy sou...
# 44973   tomorrow energy future may sustainable GenEnergy
# 44976  making high energy intensity TBT situation See...
# 44979  Honourable Jim Carr Minister Natural Resources...
# 44980  Joanne White scientist naturally curious want ...
# 44981  clean energy future impact Canadian workforce ...
# 44982  MP Breton announces 7M funding Green Municipal...
# 44983  say energy future Join Min Hehr GenEnergy conv...
# 44985  Minister Natural Resources Honourable Jim Carr...
# 44987  Min Duclos vision energy future Share ideas us...
# 44989  Canada transition low carbon energy future Min...
# 44990  take everything consideration See else Kayla s...
# 44991  energy future matters conversation generation ...
# 44992  Minister McKenna lot say energy future Check G...
# 44993  Join Min Sohi part generation defines Canada e...
# 44996  part conversation generation Join Min Duclos s...
# 44997  Join Min Duclos discuss way forward energy fut...
# 44999  Funding Budget 2016 increase charging refuelli...
# 45000  Government Canada approved Enbridge Line Repla...
# 45001  Government Canada approved Trans Mountain Expa...
#
#                                                 hashtags num_comments  \
# 2                                ['#Arctic', '#Nunavut']          NaN
# 3                                     ['#PolarBearWeek']          NaN
# 5                                          ['#Waterton']          NaN
# 7              ['#MentalHealthAwarenessWeek', '#MIAW17']          NaN
# 8                                  ['#WorldKindnessDay']          NaN
# 13                 ['#WorldAnimalDay', '#speciesatrisk']          NaN
# 17                                                    []          NaN
# 22     ['#WorldHoneyBeeDay', '#wildlife', '#iNaturali...          NaN
# 26                                   ['#ParksChallenge']          NaN
# 30                                   ['#WinterSolstice']          NaN
# 38               ['#hiking', '#TwinFalls', '#Canada150']          NaN
# 39                                 ['#BatWeek', '#bats']          NaN
# 40                                    ['#PolarBearWeek']          NaN
# 47                     ['#science', '#ScienceWithAView']          NaN
# 51         ['#WorldWildlifeConservationDay', '#Science']          NaN
# 54                                 ['#bats', '#BatWeek']          NaN
# 55                         ['#DYK', '#bats', '#BatWeek']          NaN
# 59            ['#MontaneForests', '#NationalForestWeek']          NaN
# 62       ['#NationalAcadianDay', '#GrandPr', '#Acadian']          NaN
# 63                               ['#WasteReductionWeek']          NaN
# 71     ['#WorldMentalHealthDay', '#mindful', '#GreatO...          NaN
# 72                                           ['#summer']          NaN
# 74                                   ['#ParksChallenge']          NaN
# 76     ['#LighthouseDay', '#DYK', '#lighthouse', '#Ca...          NaN
# 79                                     ['#polarbearcam']          NaN
# 80                    ['#Funfact', '#WildlifeWednesday']          NaN
# 82                                                    []          NaN
# 84               ['#MotivationMonday', '#greatoutdoors']          NaN
# 85                                     ['#TakeAHikeDay']          NaN
# 86                  ['#ParksChallenge', '#fall', '#DYK']          NaN
# 87                                                    []          NaN
# 88                                          ['#science']          NaN
# 92                     ['#CapeSpearNHS', '#GrosMorneNP']          NaN
# 95                                ['#WildlifeWednesday']          NaN
# 96                           ['#PEI', '#ParksChallenge']          NaN
# 101    ['#InternationalRabbitDay', '#GrosMorneNP', '#...          NaN
# 105                                ['#MotivationMonday']          NaN
# 106    ['#DYK', '#borealforest', '#ecosystems', '#Nat...          NaN
# 107                                   ['#WorldHeritage']          NaN
# 108                    ['#science', '#ScienceWithAView']          NaN
# 110            ['#WomensHistoryMonth', '#NellieMcClung']          NaN
# 113    ['#Acadianforest', '#Fall', '#KejimkujikNP', '...          NaN
# 115                    ['#PortRoyalNHS', '#FortAnneNHS']          NaN
# 120                ['#DYK', '#MarineMonday', '#Science']          NaN
# 121                       ['#BCwildfires', '#PlanAhead']          NaN
# 124                              ['#WasteReductionWeek']          NaN
# 127    ['#DYK', '#WoodBuffaloNP', '#PlacesWorthProtec...          NaN
# 133               ['#GwaiiHaanas', '#ColourtheOutdoors']          NaN
# 134                                    ['#NMCANovember']          NaN
# 135                                  ['#ParksChallenge']          NaN
# ...                                                  ...          ...
# 44912         ["pmyouthcouncil","environment","economy"]            0
# 44913  ["sprucebudworm","womeninscience","stemgirls",...            0
# 44914                  ["icymi","cleantech","genenergy"]            0
# 44917          ["climatechange","genenergy","genenergy"]            0
# 44918                                      ["genenergy"]            0
# 44919  ["arcticscience","north","science","canada","i...            0
# 44920     ["genenergy","yourenergyfuture","cleanenergy"]            0
# 44922  ["mineral","womeninscience","nrcansci","stemgi...            0
# 44923                                      ["genenergy"]            0
# 44925          ["canada","genenergy","yourenergyfuture"]            0
# 44927          ["canada","genenergy","yourenergyfuture"]            0
# 44928                  ["congratulations","lowercarbon"]            0
# 44929                                      ["genenergy"]            1
# 44931                                    ["canadachina"]            0
# 44933                          ["cleantech","genenergy"]            1
# 44934  ["womeninscience","nrcansci","stemgirls","girl...            0
# 44936                                            ["tbt"]            0
# 44937                                                 []            0
# 44938                                                 []            0
# 44939                                      ["genenergy"]            0
# 44940                                      ["genenergy"]            0
# 44942                              ["goc","canadachina"]            0
# 44944  ["cna2017","lowcarbon","nuclear","innovation",...            0
# 44945                     ["intlforestday","loveforest"]            0
# 44948                                      ["genenergy"]            0
# 44949                 ["youth","cleangrowth","emmc2017"]            0
# 44951                                      ["genenergy"]            0
# 44952                                      ["genenergy"]            1
# 44962  ["naturalresources","modernization","forest","...            1
# 44966                                                 []            0
# 44967                                      ["genenergy"]            0
# 44973                                      ["genenergy"]            0
# 44976                                ["tbt","genenergy"]            0
# 44979  ["nuclear","naturalresources","lowcarbon","eco...            0
# 44980  ["womeninscience","stemgirls","girlslovescienc...            0
# 44981                                      ["genenergy"]            0
# 44982                               ["quebec","cdnmuni"]            0
# 44983                                      ["genenergy"]            0
# 44985                                                 []            0
# 44987                                                 []            0
# 44989                                      ["genenergy"]            0
# 44990     ["genenergy","yourenergyfuture","cleanenergy"]            0
# 44991                                      ["genenergy"]            0
# 44992                                      ["genenergy"]            0
# 44993                                      ["genenergy"]            0
# 44996                                      ["genenergy"]            0
# 44997                                      ["genenergy"]            0
# 44999  ["electricvehicles","naturalgas","electricity"...            0
# 45000  ["pipeline","canada","economy","replace","natu...            0
# 45001  ["pipeline","canada","economy","expansion","tm...            0
#
#       num_shares num_likes Reactions_SUM       category matched_keywords  \
# 2            162       433           595  Environmental              NaN
# 3            137       373           510        unknown              NaN
# 5            434         0           434  Environmental              NaN
# 7            116       281           397         Social              NaN
# 8            107       230           337  Environmental              NaN
# 13            90       213           303  Environmental              NaN
# 17            98       164           262  Environmental              NaN
# 22            79       163           242  Environmental              NaN
# 26            57       176           233  Environmental              NaN
# 30            55       153           208  Environmental              NaN
# 38            33       158           191  Environmental              NaN
# 39            54       132           186        unknown              NaN
# 40            24       161           185        unknown              NaN
# 47            48       125           173        unknown              NaN
# 51            49       118           167  Environmental              NaN
# 54            45       112           157        unknown              NaN
# 55            51       103           154        unknown              NaN
# 59            32       117           149  Environmental              NaN
# 62            51        94           145         Social              NaN
# 63            36       109           145  Environmental              NaN
# 71            35       102           137         Social              NaN
# 72            45        90           135  Environmental              NaN
# 74            28       105           133  Environmental              NaN
# 76            36        95           131  Environmental              NaN
# 79            31        97           128        unknown              NaN
# 80            37        91           128  Environmental              NaN
# 82            29        96           125        unknown              NaN
# 84            25        98           123  Environmental              NaN
# 85            38        85           123        unknown              NaN
# 86            21       102           123  Environmental              NaN
# 87           123         0           123  Environmental              NaN
# 88            36        85           121        unknown              NaN
# 92            30        84           114  Environmental              NaN
# 95            23        90           113  Environmental              NaN
# 96            31        81           112  Environmental              NaN
# 101           30        78           108     Economical              NaN
# 105           27        80           107  Environmental              NaN
# 106           30        77           107  Environmental              NaN
# 107           39        67           106  Environmental              NaN
# 108           35        70           105        unknown              NaN
# 110           40        64           104         Social              NaN
# 113           21        81           102  Environmental              NaN
# 115           24        78           102  Environmental              NaN
# 120           29        71           100  Environmental              NaN
# 121           39        61           100  Environmental              NaN
# 124           44        53            97  Environmental              NaN
# 127           26        70            96  Environmental              NaN
# 133           16        78            94  Environmental              NaN
# 134           25        68            93  Environmental              NaN
# 135           18        75            93  Environmental              NaN
# ...          ...       ...           ...            ...              ...
# 44912        NaN        12            12         Social              NaN
# 44913        NaN        12            12         Social              NaN
# 44914        NaN        12            12     Economical              NaN
# 44917        NaN        12            12  Environmental              NaN
# 44918        NaN        12            12         Social              NaN
# 44919        NaN        12            12  Environmental              NaN
# 44920        NaN        12            12  Environmental              NaN
# 44922        NaN        12            12         Social              NaN
# 44923        NaN        12            12  Environmental              NaN
# 44925        NaN        11            11         Social              NaN
# 44927        NaN        11            11         Social              NaN
# 44928        NaN        11            11         Social              NaN
# 44929        NaN        10            11     Economical              NaN
# 44931        NaN        11            11     Economical              NaN
# 44933        NaN        10            11  Environmental              NaN
# 44934        NaN        11            11     Economical              NaN
# 44936        NaN        11            11  Environmental              NaN
# 44937        NaN        11            11     Economical              NaN
# 44938        NaN        11            11     Economical              NaN
# 44939        NaN        10            10     Economical              NaN
# 44940        NaN        10            10  Environmental              NaN
# 44942        NaN        10            10  Environmental              NaN
# 44944        NaN        10            10     Economical              NaN
# 44945        NaN        10            10         Social              NaN
# 44948        NaN        10            10         Social              NaN
# 44949        NaN        10            10     Economical              NaN
# 44951        NaN         9             9  Environmental              NaN
# 44952        NaN         8             9  Environmental              NaN
# 44962        NaN         8             9     Economical              NaN
# 44966        NaN         9             9  Environmental              NaN
# 44967        NaN         8             8         Social              NaN
# 44973        NaN         8             8         Social              NaN
# 44976        NaN         7             7     Economical              NaN
# 44979        NaN         7             7  Environmental              NaN
# 44980        NaN         7             7         Social              NaN
# 44981        NaN         6             6         Social              NaN
# 44982        NaN         6             6  Environmental              NaN
# 44983        NaN         6             6         Social              NaN
# 44985        NaN         6             6     Economical              NaN
# 44987        NaN         5             5         Social              NaN
# 44989        NaN         5             5         Social              NaN
# 44990        NaN         5             5         Social              NaN
# 44991        NaN         5             5         Social              NaN
# 44992        NaN         5             5         Social              NaN
# 44993        NaN         5             5         Social              NaN
# 44996        NaN         4             4         Social              NaN
# 44997        NaN         4             4         Social              NaN
# 44999        NaN         3             3     Economical              NaN
# 45000        NaN         2             2  Environmental              NaN
# 45001        NaN         1             1  Environmental              NaN
#
#       language  average_sentiment_score sentiment  \
# 2           en                 0.220000   Neutral
# 3           en                 0.214583   Neutral
# 5           en                 0.000000   Neutral
# 7           en                 0.300000   Neutral
# 8           en                 0.500000  Positive
# 13          en                 0.000000   Neutral
# 17          en                 0.341667  Positive
# 22          en                 1.000000  Positive
# 26          en                 0.250000   Neutral
# 30          en                -0.150000   Neutral
# 38          en                 0.000000   Neutral
# 39          en                 0.400000  Positive
# 40          en                 0.111111   Neutral
# 47          en                 0.130682   Neutral
# 51          en                 0.750000  Positive
# 54          en                 0.287500   Neutral
# 55          en                -0.134921   Neutral
# 59          en                 0.303977   Neutral
# 62          en                 0.625000  Positive
# 63          en                 0.162500   Neutral
# 71          en                 0.000000   Neutral
# 72          en                 0.000000   Neutral
# 74          en                 0.640625  Positive
# 76          en                 0.500000  Positive
# 79          en                -0.130208   Neutral
# 80          en                 0.000000   Neutral
# 82          en                -0.375000  Negative
# 84          en                 0.000000   Neutral
# 85          en                 0.000000   Neutral
# 86          en                -0.250000   Neutral
# 87          en                 0.200000   Neutral
# 88          en                 0.000000   Neutral
# 92          en                 0.430455  Positive
# 95          en                 1.000000  Positive
# 96          en                 0.200000   Neutral
# 101         en                 0.000000   Neutral
# 105         en                 0.750000  Positive
# 106         en                 0.000000   Neutral
# 107         en                 0.473214  Positive
# 108         en                -0.393750  Negative
# 110         en                 0.500000  Positive
# 113         en                 0.625000  Positive
# 115         en                 0.000000   Neutral
# 120         en                 0.462500  Positive
# 121         en                 0.500000  Positive
# 124         en                 0.000000   Neutral
# 127         en                 0.000000   Neutral
# 133         en                -0.100000   Neutral
# 134         en                 0.250000   Neutral
# 135         en                 0.637500  Positive
# ...        ...                      ...       ...
# 44912       en                 0.000000   neutral
# 44913       en                 0.000000   neutral
# 44914       en                 0.000000   neutral
# 44917       en                 0.000000   neutral
# 44918       en                 0.000000   neutral
# 44919       en                 0.000000   neutral
# 44920       en                 0.000000   neutral
# 44922       en                 0.000000   neutral
# 44923       en                 0.000000   neutral
# 44925       en                 0.000000   neutral
# 44927       en                 0.000000   neutral
# 44928       en                 0.000000   neutral
# 44929       en                 0.000000   neutral
# 44931       en                 0.000000   neutral
# 44933       en                -0.062500  negative
# 44934       en                 0.000000   neutral
# 44936       en                 0.000000   neutral
# 44937       en                 0.000000   neutral
# 44938       en                 0.000000   neutral
# 44939       en                 0.000000   neutral
# 44940       en                 0.000000   neutral
# 44942       en                 0.000000   neutral
# 44944       en                 0.000000   neutral
# 44945       en                 0.000000   neutral
# 44948       en                 0.000000   neutral
# 44949       en                 0.000000   neutral
# 44951       en                 0.000000   neutral
# 44952       en                 0.000000   neutral
# 44962       en                 0.000000   neutral
# 44966       en                 0.000000   neutral
# 44967       en                 0.000000   neutral
# 44973       en                 0.000000   neutral
# 44976       en                 0.000000   neutral
# 44979       en                 0.000000   neutral
# 44980       en                 0.000000   neutral
# 44981       en                 0.000000   neutral
# 44982       en                 0.000000   neutral
# 44983       en                 0.000000   neutral
# 44985       en                 0.000000   neutral
# 44987       en                 0.000000   neutral
# 44989       en                 0.000000   neutral
# 44990       en                 0.000000   neutral
# 44991       en                 0.000000   neutral
# 44992       en                 0.000000   neutral
# 44993       en                 0.000000   neutral
# 44996       en                 0.000000   neutral
# 44997       en                 0.000000   neutral
# 44999       en                 0.000000   neutral
# 45000       en                 0.000000   neutral
# 45001       en                 0.000000   neutral
#
#                                  Action_matched_keywords
# 2                                                [learn]
# 3                                           [cool, bear]
# 5                                              [protect]
# 7                                                 [help]
# 8                          [care, protecting, ecosystem]
# 13                                             [protect]
# 17                                             [protect]
# 22                                       [help, protect]
# 26                                          [experience]
# 30                                            [preserve]
# 38                                              [hiking]
# 39                                             [protect]
# 40                                                [bear]
# 47                             [walk, help, bear, adapt]
# 51                 [working, help, protect, learn, help]
# 54                                                [talk]
# 55                                             [hunting]
# 59                                                [live]
# 62                                               [learn]
# 63     [waste, consider, recycling, composting, campi...
# 71                                            [spending]
# 72                                        [make, eating]
# 74                                  [hike, walk, picnic]
# 76                                           [surviving]
# 79                                          [bear, make]
# 80                                         [dive, speed]
# 82                                               [avoid]
# 84                                                [plan]
# 85                                               [avoid]
# 86                                         [plant, make]
# 87                                       [demonstrating]
# 88                                                [help]
# 92                                             [release]
# 95                                                [plan]
# 96                                             [protect]
# 101                                               [turn]
# 105                                           [planning]
# 106                                          [ecosystem]
# 107                                              [learn]
# 108                                   [fish, fish, help]
# 110                                              [learn]
# 113                                               [plan]
# 115                                               [make]
# 120                        [working, protect, ecosystem]
# 121                                     [planning, make]
# 124               [plastic, camping, wastereductionweek]
# 127                                   [working, protect]
# 133                                            [fishing]
# 134                        [protect, ecosystem, promote]
# 135                                             [picnic]
# ...                                                  ...
# 44912                              [protecting, growing]
# 44913                                [make, work, cycle]
# 44914                       [engineering, design, build]
# 44917  [fight, energy, work, energy, reducing, change...
# 44918                                           [change]
# 44919                                             [camp]
# 44920                         [resource, create, energy]
# 44922                                             [help]
# 44923            [energy, store, combat, change, energy]
# 44925                                     [energy, cool]
# 44927                               [energy, learn, add]
# 44928                                          [support]
# 44929                                           [energy]
# 44931                                          [promote]
# 44933                                 [support, growing]
# 44934                                     [help, manage]
# 44936                                            [train]
# 44937                                [investing, reduce]
# 44938                                [investing, create]
# 44939                                           [energy]
# 44940                                            [waste]
# 44942                                          [support]
# 44944                               [energy, low-carbon]
# 44945                                      [local, help]
# 44948                                           [change]
# 44949                                   [energy, mining]
# 44951                           [energy, change, energy]
# 44952                                           [energy]
# 44962                                         [bringing]
# 44966                              [sustainable, mining]
# 44967                                           [energy]
# 44973                              [energy, sustainable]
# 44976                                           [energy]
# 44979                               [energy, low-carbon]
# 44980                                     [work, change]
# 44981                                           [energy]
# 44982                                     [help, reduce]
# 44983                                           [energy]
# 44985                                  [address, energy]
# 44987                                           [energy]
# 44989                               [low-carbon, energy]
# 44990                                           [energy]
# 44991                                           [energy]
# 44992                                           [energy]
# 44993                                           [energy]
# 44996                                           [energy]
# 44997                                    [energy, learn]
# 44999                                         [increase]
# 45000                                            [learn]
# 45001                                            [learn]
#
# [21670 rows x 16 columns]

# %% [markdown]
# ## Only one line of code is needed to train word embedding model

# %%
model = Word2Vec(data_df['lemmatized_text'], size=600, window=50, min_count=20)
# save model
model.save('word2vec_model.bin')
## uncomment the following line of code to load an existing model instead of training a new one.
#model = Word2Vec.load('word2vec_model.bin')
#list(model.wv.vocab)

# %% [markdown]
# ## find new action words using existing actions

# %%
output_dict = {}
top_n = 30
counter = 1
for keyword in keywords_list:
    try:
        tuple_list = model.wv.most_similar(positive=[keyword], topn=top_n)
    except KeyError:
        print(str(counter) + ': keyword \"' + keyword + '\" is not found...')
        counter += 1
        continue
    new_actions = set(ele[0] for ele in tuple_list if ele not in keywords_list)
    output_dict[keyword] = new_actions
pprint(output_dict)
print(str(counter-1) + ' given keywords not found in the embedding model..')
# Out:
# 1: keyword "online_shopping" is not found...
# 2: keyword "solve" is not found...
# 3: keyword "cure" is not found...
# 4: keyword "freezer" is not found...
# 5: keyword "recycle" is not found...
# 6: keyword "wasting_food" is not found...
# 7: keyword "cut_down_gas_emission" is not found...
# 8: keyword "pursuing" is not found...
# 9: keyword "drink" is not found...
# 10: keyword "decision-making" is not found...
# 11: keyword "medication" is not found...
# 12: keyword "wood_product" is not found...
# 13: keyword "le_packaging" is not found...
# 14: keyword "cooling" is not found...
# 15: keyword "expired" is not found...
# 16: keyword "locally_grown_food" is not found...
# 17: keyword "tempting" is not found...
# 18: keyword "unpacking_grocery" is not found...
# 19: keyword "surviving" is not found...
# 20: keyword "expiration_date" is not found...
# 21: keyword "overhauling" is not found...
# 22: keyword "light_off" is not found...
# 23: keyword "driving_le" is not found...
# 24: keyword "strenghtening" is not found...
# 25: keyword "preservation" is not found...
# 26: keyword "damaging" is not found...
# 27: keyword "wrapper" is not found...
# 28: keyword "trashing" is not found...
# 29: keyword "fixing" is not found...
# 30: keyword "co-working_space" is not found...
# 31: keyword "food_bank" is not found...
# 32: keyword "compost_indoors" is not found...
# 33: keyword "washing" is not found...
# 34: keyword "reuse" is not found...
# 35: keyword "eco-friendly_agent" is not found...
# 36: keyword "re-tool" is not found...
# 37: keyword "pursue" is not found...
# 38: keyword "buying_online" is not found...
# 39: keyword "used_product" is not found...
# 40: keyword "farm-fresh" is not found...
# 41: keyword "tea_infuser" is not found...
# 42: keyword "veggie" is not found...
# 43: keyword "taking_home_food" is not found...
# 44: keyword "eating_habit" is not found...
# 45: keyword "green_purchasing" is not found...
# 46: keyword "le_energy_use" is not found...
# 47: keyword "online_shop" is not found...
# 48: keyword "smaller_plate" is not found...
# 49: keyword "clogging_landfill" is not found...
# 50: keyword "permitting" is not found...
# 51: keyword "packaging_peanut" is not found...
# 52: keyword "preserving" is not found...
# 53: keyword "reusable_bag" is not found...
# 54: keyword "unpack" is not found...
# 55: keyword "local_dining" is not found...
# 56: keyword "walking" is not found...
# 57: keyword "carry_cup" is not found...
# 58: keyword "errand" is not found...
# 59: keyword "nutrient" is not found...
# 60: keyword "ceramic_baking_pan" is not found...
# 61: keyword "grow_own_food" is not found...
# 62: keyword "bus_ride" is not found...
# 63: keyword "meal_plan" is not found...
# 64: keyword "throwing" is not found...
# 65: keyword "biosphere_reserve" is not found...
# 66: keyword "recycling_nutrient" is not found...
# 67: keyword "takeaway" is not found...
# 68: keyword "food_product" is not found...
# 69: keyword "reusable_container" is not found...
# 70: keyword "local_farm" is not found...
# 71: keyword "food_kitchen" is not found...
# 72: keyword "carpooling" is not found...
# 73: keyword "compost" is not found...
# 74: keyword "bulk_quantity" is not found...
# 75: keyword "low-flow" is not found...
# 76: keyword "re-tooling" is not found...
# 77: keyword "demonstrate" is not found...
# 78: keyword "saving_environment" is not found...
# 79: keyword "unused" is not found...
# 80: keyword "growing_herb" is not found...
# 81: keyword "borrowing" is not found...
# 82: keyword "energy_efficient" is not found...
# 83: keyword "carpool" is not found...
# 84: keyword "le_food_packaging" is not found...
# 85: keyword "shut_down" is not found...
# 86: keyword "reusable_straw" is not found...
# 87: keyword "fuel_use" is not found...
# 88: keyword "solving" is not found...
# 89: keyword "eco-savvy" is not found...
# 90: keyword "avoid_temptation" is not found...
# 91: keyword "drip" is not found...
# 92: keyword "accelerating" is not found...
# 93: keyword "cultivating" is not found...
# 94: keyword "food_shopping" is not found...
# 95: keyword "function" is not found...
# 96: keyword "promot" is not found...
# 97: keyword "recycled_item" is not found...
# 98: keyword "recycled_material" is not found...
# 99: keyword "eliminating" is not found...
# 100: keyword "eating_local" is not found...
# 101: keyword "old_stuff" is not found...
# 102: keyword "own_mug" is not found...
# 103: keyword "backyard_garden" is not found...
# 104: keyword "supporting_farmer" is not found...
# 105: keyword "donating" is not found...
# 106: keyword "checking_label" is not found...
# 107: keyword "edible_wrapper" is not found...
# 108: keyword "speeding" is not found...
# 109: keyword "public_transportation" is not found...
# 110: keyword "savour_the_season" is not found...
# 111: keyword "positive_impact" is not found...
# 112: keyword "abide" is not found...
# 113: keyword "co-work" is not found...
# 114: keyword "bpa-free" is not found...
# 115: keyword "eliminate" is not found...
# 116: keyword "freezing" is not found...
# 117: keyword "icrease" is not found...
# 118: keyword "energy_efficient_appliance" is not found...
# 119: keyword "turning_off" is not found...
# 120: keyword "shopping_online" is not found...
# 121: keyword "beautifying" is not found...
# 122: keyword "throw" is not found...
# 123: keyword "food_donation" is not found...
# 124: keyword "global_warming" is not found...
# 125: keyword "composting" is not found...
# 126: keyword "conserving_energy" is not found...
# 127: keyword "dish_soap" is not found...
# 128: keyword "survive" is not found...
# 129: keyword "local_market" is not found...
# 130: keyword "pristine_lakes" is not found...
# 131: keyword "cut_down" is not found...
# 132: keyword "enriching_soil" is not found...
# 133: keyword "windowsill" is not found...
# 134: keyword "farmer's_market" is not found...
# 135: keyword "gas_emission" is not found...
# 136: keyword "cultivate_fresh" is not found...
# 137: keyword "non-toxic_cleaning_product" is not found...
# 138: keyword "water_bottle" is not found...
# 139: keyword "cultivate" is not found...
# 140: keyword "re-use" is not found...
# 141: keyword "trash" is not found...
# 142: keyword "gardening" is not found...
# 143: keyword "bearing" is not found...
# 144: keyword "reduce_food_waste" is not found...
# 145: keyword "educating" is not found...
# 146: keyword "cycling" is not found...
# 147: keyword "telecommute" is not found...
# 148: keyword "reducing_water_consumption" is not found...
# 149: keyword "making_decision" is not found...
# 150: keyword "track_the_trash" is not found...
# 151: keyword "procuring" is not found...
# 152: keyword "demonstrating" is not found...
# 153: keyword "water_consumption" is not found...
# 154: keyword "shop_online" is not found...
# 155: keyword "crafting" is not found...
# 156: keyword "accelerate" is not found...
# 157: keyword "educate" is not found...
# 158: keyword "combining_errand" is not found...
# 159: keyword "combine" is not found...
# 160: keyword "own_bag" is not found...
# 161: keyword "procure" is not found...
# 162: keyword "freeze" is not found...
# 163: keyword "planting" is not found...
# 164: keyword "avoiding" is not found...
# 165: keyword "functioning" is not found...
# 166: keyword "le_methane" is not found...
# 167: keyword "shopping_habit" is not found...
# 168: keyword "bake" is not found...
# 169: keyword "brushing" is not found...
# 170: keyword "curing" is not found...
# 171: keyword "cleaning_product" is not found...
# 172: keyword "concocting" is not found...
# 173: keyword "slowing" is not found...
# 174: keyword "designing" is not found...
# 175: keyword "grocery_bag" is not found...
# {'achieve': {'2030',
#              'addressed',
#              'bilateral',
#              'boost',
#              "cdnag's",
#              'cecweb',
#              'competitiveness',
#              'comprehensive',
#              'contribute',
#              'developing',
#              'effective',
#              'expand',
#              'gap',
#              "goc's",
#              'greater',
#              'greeninggovernment',
#              'implementing',
#              'improving',
#              'innovate',
#              'invest',
#              'invested',
#              'investments',
#              'livestock',
#              'long-term',
#              'lowcarbon',
#              'modernizing',
#              'objective',
#              'pan-canadian',
#              'sustainability',
#              "🇨🇦's"},
#  'achieving': {'2030',
#                'adapt',
#                'ag',
#                'boost',
#                'canclimateaction',
#                'canola',
#                "cdnag's",
#                "china's",
#                'connected',
#                'contribute',
#                'expertise',
#                'germany',
#                'greeninggovernment',
#                'healthier',
#                'huge',
#                'influence',
#                'innovate',
#                'insight',
#                'lowcarbon',
#                'missioninnovation',
#                'modernizing',
#                'momentum',
#                'naturalresources',
#                'pork',
#                'renewableenergy',
#                'smes',
#                'succeed',
#                'transition',
#                'vision',
#                "🇨🇦's"},
#  'adapt': {'achieve',
#            'achieving',
#            'adaptation',
#            'adapting',
#            'barley',
#            'boost',
#            'cattle',
#            "cdnag's",
#            'cdnenv',
#            'chemical',
#            'collaborating',
#            'contribute',
#            'cow',
#            'develop',
#            'developed',
#            'dna',
#            'explains',
#            'fsds',
#            'gap',
#            'grower',
#            'healthier',
#            'huge',
#            'influence',
#            'invested',
#            'livestock',
#            'long-term',
#            'poultry',
#            'renewableenergy',
#            'understanding',
#            'valuable'},
#  'adapting': {'adapt',
#               'adaptation',
#               'addressing',
#               'barley',
#               'cdnsci',
#               'chemical',
#               'chris',
#               'collaborating',
#               'collaborative',
#               'combat',
#               'contribute',
#               'developed',
#               'dna',
#               'explains',
#               'grower',
#               'healthier',
#               'influence',
#               'invested',
#               'knowledge',
#               'lakewinnipeg',
#               'method',
#               'objective',
#               'processing',
#               'stronger',
#               'studied',
#               'success',
#               'tackle',
#               'understanding',
#               'wood',
#               'worldscienceday'},
#  'add': {'app',
#          'appliance',
#          'backtoschool',
#          'blackfriday',
#          'clothes',
#          'costume',
#          'download',
#          'easy',
#          'energyefficient',
#          'energysaving',
#          'game',
#          'gift',
#          'giving',
#          'got',
#          'kid',
#          "kids'",
#          'let',
#          'loved',
#          'movie',
#          'own',
#          'pcapp',
#          'recipe',
#          'shopping',
#          'something',
#          'soon',
#          'spending',
#          "there's",
#          'thermostat',
#          'turn',
#          'up'},
#  'address': {'agreement',
#              'budget2017',
#              'canadachina',
#              'china',
#              'cleantech',
#              'collaboration',
#              'commitment',
#              'committed',
#              'cooperation',
#              'developing',
#              'discussed',
#              'economic',
#              'economy',
#              'gc',
#              'greater',
#              'growth',
#              'implementing',
#              'industry',
#              'initiative',
#              'leadership',
#              'mexico',
#              'mining',
#              'mou',
#              'nuclear',
#              'paris',
#              'priority',
#              'representative',
#              'rudd',
#              'strengthen',
#              'strong'},
#  'addressing': {'aandcanada',
#                 'achieve',
#                 'achieving',
#                 'adapting',
#                 'bilateral',
#                 'canada-us',
#                 'collaborate',
#                 'combat',
#                 'competitiveness',
#                 'concrete',
#                 'deliver',
#                 'delivers',
#                 'fsds',
#                 "goc's",
#                 'implement',
#                 'implementing',
#                 'kim',
#                 'lakewinnipeg',
#                 'momentum',
#                 'objective',
#                 'productive',
#                 'resilience',
#                 'shared',
#                 'success',
#                 'sustainability',
#                 'table',
#                 'tackle',
#                 'target',
#                 'towards',
#                 "🇨🇦's"},
#  'agri-food': {'acoacanada',
#                'ag',
#                'beef',
#                'canclimateaction',
#                "cdnag's",
#                'cdninnovation',
#                'cleanenergy',
#                'cleangrowth',
#                'creating',
#                'europe',
#                'exportdevcanada',
#                'framework',
#                'germany',
#                'greeninggovernment',
#                'growing',
#                'ingredient',
#                'innovate',
#                'innovative',
#                'low-carbon',
#                'low_carbon',
#                'lowcarbon',
#                'pan-canadian',
#                'production',
#                'promote',
#                'rampd',
#                'resilience',
#                'sector',
#                'transition',
#                'union',
#                "🇨🇦's"},
#  'appliance': {'backtoschool',
#                'bad',
#                'blackfriday',
#                'calculator',
#                'carseat',
#                'cert',
#                'checklist',
#                'choose',
#                'clothes',
#                'clothing',
#                'covered',
#                'decide',
#                'electronics',
#                'energyefficient',
#                'fix',
#                'grocery',
#                'instead',
#                'leds',
#                'longer',
#                'print',
#                'retailer',
#                'save5',
#                'shopping',
#                'simple',
#                'smaller',
#                'store',
#                'thermostat',
#                'thursdaythoughts',
#                'turn',
#                'washer'},
#  'approach': {'achieve',
#               'adapt',
#               'adaptation',
#               'chemical',
#               'competitiveness',
#               'detection',
#               'develop',
#               'developing',
#               'effective',
#               'faster',
#               'footprint',
#               'gap',
#               'greater',
#               'improved',
#               'industrial',
#               'inform',
#               'innovate',
#               'long-term',
#               'lowcarbon',
#               'methane',
#               'pollutant',
#               'potential',
#               'processing',
#               'reduction',
#               'seek',
#               'stronger',
#               'sustainability',
#               'table',
#               'treatment',
#               'wastewater'},
#  'avoid': {'able',
#            'baggage',
#            'buy',
#            'buying',
#            'card',
#            'deal',
#            'device',
#            'easy',
#            'even',
#            'fast',
#            'heat',
#            'item',
#            'limit',
#            'mobile',
#            'monthly',
#            'own',
#            'phone',
#            'purchase',
#            'put',
#            'rule',
#            'saveenergy',
#            'shopping',
#            'tip',
#            'tips',
#            'tire',
#            'traveltips',
#            'trick',
#            'usually',
#            'wintertips',
#            'without'},
#  'bear': {'ancient',
#           'archaeology',
#           'bird',
#           'bison',
#           'boreal',
#           'breeding',
#           'canyon',
#           'caribou',
#           'colony',
#           'deep',
#           'fundy',
#           'glass',
#           'greenland',
#           'hecate',
#           'known',
#           'landscape',
#           'lush',
#           'migratory',
#           'narwhal',
#           'polar',
#           'prairie',
#           'rare',
#           'reef',
#           'rock',
#           'seabird',
#           'sound',
#           'tundra',
#           'underwater',
#           'unique',
#           'wildlifewednesday'},
#  'bicycle': {'alongside',
#              'apollo',
#              'block',
#              'bon',
#              'cap',
#              'capt',
#              'ccgshipbuilding',
#              'corporal',
#              'deck',
#              'des',
#              'desgroseilliers',
#              'died',
#              'ending',
#              'escort',
#              'evening',
#              'groseilliers',
#              'mooring',
#              'parrysound',
#              'pearkes',
#              'preparing',
#              'rcaf_arc',
#              'regina',
#              'samuelrisley',
#              'sirwilfridlaurier',
#              'terryfox',
#              'the…',
#              'thunder',
#              'voyage',
#              'welcomed',
#              'windsor'},
#  'bike': {'2018camping',
#           'admire',
#           'biking',
#           'breathtaking',
#           'circle',
#           'cree',
#           'definitely',
#           'didyouknow',
#           'episode',
#           'explorecanada',
#           'featured',
#           'forillon',
#           'jasper',
#           'lifetime',
#           'marking',
#           'mauricie',
#           'memory',
#           'motivationmonday',
#           'mount',
#           'no',
#           'ottawacity',
#           'paddling',
#           'paradise',
#           'peak',
#           'photograph',
#           'project_naming',
#           'race',
#           'revelstoke',
#           'tradition',
#           'truly'},
#  'biking': {'2018camping',
#             'admire',
#             'bike',
#             'breathtaking',
#             'crowd',
#             'definitely',
#             'dream',
#             "environmentca's",
#             'escape',
#             'explorecanada',
#             'feel',
#             'finally',
#             'getoutside',
#             'golden',
#             'gorgeous',
#             'grab',
#             'hiddengems',
#             'mauricie',
#             'motivationmonday',
#             'pair',
#             'peak',
#             'picnic',
#             'piece',
#             'revelstoke',
#             'riding',
#             'sight',
#             'sleep',
#             'truly',
#             'wow',
#             '❤️'},
#  'boat': {'aid',
#           'assistance',
#           'boating',
#           'boatingsafety',
#           'ccg',
#           'craft',
#           'distress',
#           'emergency',
#           'jrcc',
#           'mariner',
#           'mariners',
#           'navigation',
#           'owner',
#           'personnel',
#           'pilot',
#           'pleasure',
#           'police',
#           'removed',
#           'replacement',
#           'rescue',
#           'rescued',
#           'safely',
#           'sar',
#           'search',
#           'seasonal',
#           'stationed',
#           'staysafe',
#           'training',
#           'twentyfourseven',
#           'vicjrcc_cccos'},
#  'boating': {'always',
#              'aware',
#              'bcwildfires',
#              'boat',
#              'boater',
#              'boatingsafety',
#              'dangerous',
#              'expect',
#              'handy',
#              'hypothermia',
#              'keeping',
#              'lifejacket',
#              'mariners',
#              'nearby',
#              'pfd',
#              'pilot',
#              'pleasure',
#              'prepared',
#              'safe',
#              'safeboating',
#              'safely',
#              'season',
#              'sport',
#              'staysafe',
#              'tsbcanada',
#              'twentyfourseven',
#              'vicjrcc_cccos',
#              'warning',
#              'wear',
#              'wearing'},
#  'breaking': {'arrival',
#               'bon',
#               'brought',
#               'conducted',
#               'deepsea_sponges',
#               'depth',
#               'edge',
#               'ellen',
#               'ending',
#               'explorer',
#               'floor',
#               "he's",
#               'hole',
#               'kenchington',
#               'leaf',
#               'lots',
#               'man',
#               'naiss',
#               'nrc_cnrc',
#               'peek',
#               'pfc_cfs',
#               'returned',
#               'rise',
#               'rosette',
#               'smith',
#               'sprucebudworm',
#               'surveying',
#               'tracking',
#               'walrus',
#               'whoi'},
#  'bring': {'again',
#            'already',
#            'app',
#            'backtoschool',
#            'blackfriday',
#            'choose',
#            'clothes',
#            'clothing',
#            'commit',
#            'dish',
#            'download',
#            'easy',
#            'habit',
#            'healthycdns',
#            'indoors',
#            'loved',
#            'quiz',
#            'save5',
#            'setting',
#            'simple',
#            'so',
#            'spending',
#            'staying',
#            'stress',
#            'surprise',
#            'teach',
#            'turn',
#            'unwanted',
#            'weatherwise',
#            'yourself'},
#  'bringing': {'agree',
#               'all',
#               'asia',
#               'cranberry',
#               'define',
#               'double',
#               'everyday',
#               'exactly',
#               'ff',
#               'fighting',
#               'followfriday',
#               'healthier',
#               'httpstcoy6fsmbppgy',
#               'huge',
#               'insight',
#               'itk_canadainuit',
#               'northern_norton',
#               'parent',
#               'pledge',
#               'pollinator',
#               'ray',
#               'reality',
#               'reduces',
#               'reflect',
#               'said',
#               'stand',
#               'teachers',
#               'telling',
#               'version',
#               'vision'},
#  'build': {'2030',
#            'affordable',
#            'budget2016',
#            'budget2017',
#            'cdnmuni',
#            'ceta',
#            'cleanenergy',
#            'cleaner',
#            'competitive',
#            'create',
#            'creating',
#            'developing',
#            'emerging',
#            'eu',
#            'expanding',
#            'fcm_online',
#            'framework',
#            'goal',
#            'growing',
#            'growth',
#            'housing',
#            'improving',
#            'innovate',
#            'invest',
#            'lowcarbon',
#            'middle',
#            'pan-canadian',
#            'promote',
#            'sector',
#            'solution'},
#  'building': {'address',
#               'agreement',
#               'canadachina',
#               'cdn',
#               'china',
#               'collaboration',
#               'committed',
#               'cooperation',
#               'developing',
#               'economic',
#               'gc',
#               'growth',
#               'industry',
#               'initiative',
#               'investing',
#               'investment',
#               'leadership',
#               'mexico',
#               'mineral',
#               'mining',
#               'mou',
#               'municipality',
#               'partnership',
#               'relationship',
#               'renewed',
#               'representative',
#               'rudd',
#               'signed',
#               'strengthen',
#               'strong'},
#  'bulb': {'appliance',
#           'buy',
#           'cert',
#           'certified',
#           'clothes',
#           'computer',
#           'consumption',
#           'cooking',
#           'electronics',
#           'energyefficient',
#           'instead',
#           'laundry',
#           'leds',
#           'longer',
#           'properly',
#           'saveenergy',
#           'score',
#           'shopping',
#           'simple',
#           'sold',
#           'star',
#           'store',
#           'switch',
#           'thermostat',
#           'tiptuesday',
#           'usually',
#           'washer',
#           'wednesdaywisdom',
#           'window',
#           'wintertips'},
#  'bus': {'advance',
#          'alternative',
#          'cell',
#          'complaint',
#          'contract',
#          'dispute',
#          'electric',
#          'electronic',
#          'expected',
#          'file',
#          'inspection',
#          'internet',
#          'landfill',
#          'legislation',
#          'obligation',
#          'per',
#          'pet',
#          'pleading',
#          'provider',
#          'regulated',
#          'requirement',
#          'resolve',
#          'rights',
#          'stability',
#          'standard',
#          'tariff',
#          'truck',
#          'upgrade',
#          'vehicle',
#          'vibration'},
#  'buy': {'ask',
#          'avoid',
#          'bulb',
#          'buying',
#          'card',
#          'cash',
#          'certified',
#          'cost',
#          'covered',
#          'credit',
#          'deal',
#          'easy',
#          'energystarcanada',
#          'item',
#          'mean',
#          'mobile',
#          'money',
#          'monthly',
#          'own',
#          'phone',
#          'purchase',
#          'save',
#          'saveenergy',
#          'saving',
#          'score',
#          'sell',
#          'shopping',
#          'store',
#          'usually',
#          'wallet'},
#  'buying': {'ask',
#             'baggage',
#             'buy',
#             'card',
#             'cash',
#             'charge',
#             'convenient',
#             'covered',
#             'credit',
#             'deal',
#             'debt',
#             'expense',
#             'fee',
#             'insurance',
#             'item',
#             'loan',
#             'mean',
#             'money',
#             'monthly',
#             'mortgage',
#             'option',
#             'personal',
#             'price',
#             'purchase',
#             'rebate',
#             'sell',
#             'someone',
#             'store',
#             'usually',
#             'warranty'},
#  'camp': {'1997',
#           'behind',
#           'edward',
#           'eerience',
#           'eureka',
#           'fishmas',
#           'gave',
#           'grey',
#           'gros',
#           'highlands',
#           'leg',
#           'magical',
#           'magnificent',
#           'morne',
#           'nice',
#           'paddle',
#           'photography',
#           'pic',
#           'prince',
#           'quite',
#           'scenery',
#           'sent',
#           'shot',
#           'spectacular',
#           'stop',
#           'sun',
#           'sunrise',
#           'sunset',
#           'true',
#           'went'},
#  'camping': {'accommodation',
#              'back',
#              'bit',
#              'dreaming',
#              'early',
#              'enjoy',
#              'enjoying',
#              'fall',
#              'for',
#              'friend',
#              'getaway',
#              'got',
#              'grab',
#              'halloween',
#              'holiday',
#              'outdoor',
#              'outdoors',
#              'outside',
#              'perfect',
#              'relax',
#              'remember',
#              'spend',
#              'still',
#              "there's",
#              'trip',
#              'try',
#              'wait',
#              'waiting',
#              'whether',
#              'yet'},
#  'care': {'advantage',
#           'advice',
#           'again',
#           'already',
#           'bought',
#           'calculator',
#           'charity',
#           'cherry',
#           'chicken',
#           'choose',
#           'choosing',
#           'commit',
#           'decide',
#           'directly',
#           'easier',
#           'everyday',
#           'household',
#           'kind',
#           'mail',
#           'marketing',
#           'paying',
#           'quiz',
#           'reason',
#           'recycling',
#           'reply',
#           'setting',
#           'sweet',
#           'that',
#           'traveltuesdays',
#           'value'},
#  'causing': {'airbag',
#              'bmw',
#              'brake',
#              'cable',
#              'crash',
#              'damaged',
#              'deploy',
#              'electrical',
#              'fail',
#              'ford',
#              'front',
#              'hood',
#              'hyundai',
#              'instrument',
#              'leak',
#              'motorcycle',
#              'potentially',
#              'pump',
#              'rear',
#              'replace',
#              'seat',
#              'seatbelt',
#              'separate',
#              'shift',
#              'software',
#              'steering',
#              'suvs',
#              'toyota',
#              'transmission',
#              'truck'},
#  'change': {'aafc',
#             'changing',
#             'climate',
#             'climatechange',
#             'combined',
#             'crop',
#             'developed',
#             'disease',
#             'environment',
#             'feed',
#             'feeding',
#             'fight',
#             'food',
#             'greenhouse',
#             'impact',
#             'inform',
#             'planet',
#             'play',
#             'potato',
#             'potential',
#             'pulse',
#             'researcher',
#             'soil',
#             'solution',
#             'storage',
#             'studying',
#             'table',
#             'waste',
#             'yield',
#             '🇨🇦'},
#  'changing': {'aafc',
#               'apple',
#               'bee',
#               'citizen',
#               'combined',
#               'crop',
#               'developed',
#               'disease',
#               'eating',
#               'feed',
#               'feeding',
#               'fertilizer',
#               'fruit',
#               'genetic',
#               'impact',
#               'insect',
#               'iyp2016',
#               'lentil',
#               'manage',
#               'organism',
#               'pest',
#               'potato',
#               'pulse',
#               'researcher',
#               'researching',
#               'soil',
#               'studying',
#               'understand',
#               'vegetable',
#               'yield'},
#  'choose': {'already',
#             'appliance',
#             'bought',
#             'calculator',
#             'carseat',
#             'cash',
#             'choosing',
#             'clothes',
#             'clothing',
#             'covered',
#             'cut',
#             'decide',
#             'grocery',
#             'habit',
#             'helpful',
#             'longer',
#             'payday',
#             'paying',
#             'print',
#             'purchase',
#             'purchasing',
#             'save5',
#             'setting',
#             'shopping',
#             'simple',
#             'store',
#             'thermostat',
#             'unwanted',
#             'wallet',
#             'warranty'},
#  'choosing': {'airtravel',
#               'bought',
#               'calculator',
#               'carseat',
#               'charged',
#               'charity',
#               'choose',
#               'decide',
#               'eco-friendly',
#               'fridge',
#               'grocery',
#               'household',
#               'label',
#               'longer',
#               'payday',
#               'paying',
#               'print',
#               'purchasing',
#               'reason',
#               'recycling',
#               'retailer',
#               'roadsafety',
#               'save5',
#               'savemoney',
#               'scammer',
#               'switch',
#               'trustee',
#               'unwanted',
#               'utility',
#               'wednesdaywisdom'},
#  'cleaner': {'2030',
#              'build',
#              'carbon',
#              'cdnmuni',
#              'clean',
#              'competitive',
#              'decision',
#              'develop',
#              'effective',
#              'efficiency',
#              'electricity',
#              'emerging',
#              'emission',
#              'expanding',
#              'footprint',
#              'ghg',
#              'goal',
#              'greater',
#              'growing',
#              'growth',
#              'innovate',
#              'invest',
#              'lowcarbon',
#              'methane',
#              'pan-canadian',
#              'pricing',
#              'reduced',
#              'reduction',
#              'renewable',
#              'solution'},
#  'cleangrowth': {'ag',
#                  'agri-food',
#                  'alliance',
#                  'announcing',
#                  'canadachina',
#                  'cleanenergy',
#                  'developing',
#                  'expertise',
#                  'exportdevcanada',
#                  'framework',
#                  'germany',
#                  'greeninggovernment',
#                  'innovation',
#                  'innovative',
#                  'leader',
#                  'low-carbon',
#                  'low_carbon',
#                  'mining',
#                  'momentum',
#                  'nuclear',
#                  'organization',
#                  'pdac2017',
#                  'poweringpastcoal',
#                  'promote',
#                  'rampd',
#                  'relationship',
#                  'resilience',
#                  'sector',
#                  'transition',
#                  "🇨🇦's"},
#  'climateaction': {'address',
#                    'alliance',
#                    'canadachina',
#                    'canadainchina',
#                    'carbon',
#                    'carr',
#                    'china',
#                    'cleantech',
#                    'coal',
#                    'cop23',
#                    'discussed',
#                    'electricity',
#                    'greenhouse',
#                    'keynote',
#                    'leading',
#                    'low_carbon',
#                    'macaulay',
#                    'ministerial',
#                    'nuclear',
#                    'paris',
#                    'pricing',
#                    'ps',
#                    'renewable',
#                    'rudd',
#                    'scott',
#                    'specializing',
#                    'treatment',
#                    'uk',
#                    '“we',
#                    '🇨🇦'},
#  'collaborate': {'aandcanada',
#                  'achieve',
#                  'addressing',
#                  'brings',
#                  'campaign',
#                  'combat',
#                  'continuing',
#                  'convention',
#                  'diversity',
#                  'fbf',
#                  "goc's",
#                  'highlighting',
#                  'integrated',
#                  'investments',
#                  'lakewinnipeg',
#                  'objective',
#                  'participation',
#                  'productive',
#                  'progress',
#                  'recognizes',
#                  'resilience',
#                  'shared',
#                  'success',
#                  'tackle',
#                  'target',
#                  'thenfb',
#                  'world-class',
#                  'worldwide',
#                  'wwfcanada',
#                  "🇨🇦's"},
#  'combat': {'aandcanada',
#             'addition',
#             'asset',
#             'bilateral',
#             'canola',
#             'canus',
#             'continuing',
#             'contributes',
#             'crucial',
#             'deliver',
#             'disaster',
#             'engage',
#             'enhance',
#             'expand',
#             'fbf',
#             'funded',
#             'httpstcofj217zwska',
#             'implementing',
#             'integrated',
#             'investments',
#             'in…',
#             'lakewinnipeg',
#             'objective',
#             'participation',
#             'recognizes',
#             'recognizing',
#             'success',
#             'task',
#             'towards',
#             'world-leading'},
#  'conducting': {'2010',
#                 'alaska',
#                 'arrival',
#                 'arrived',
#                 'ashore',
#                 'bruce',
#                 'conducted',
#                 'coordinated',
#                 'deployed',
#                 'drill',
#                 'floating',
#                 'followed',
#                 'given',
#                 'heavy',
#                 'mci',
#                 'mt',
#                 'nfld',
#                 'pearkes',
#                 'prepares',
#                 'range',
#                 'recovered',
#                 'resume',
#                 'sailor',
#                 'saint',
#                 'sinking',
#                 'stlawrence',
#                 'swift',
#                 'tall',
#                 'the…',
#                 'transported'},
#  'conserve': {'animal',
#               'biodiversity',
#               'breed',
#               'conserving',
#               'ecological',
#               'ecosystem',
#               'endangered',
#               'freshwater',
#               'habitat',
#               'harm',
#               'human',
#               'important',
#               'listed',
#               'mammal',
#               'parkscanadascience',
#               'plant',
#               'play',
#               'population',
#               'protect',
#               'protecting',
#               'protects',
#               'restore',
#               'shelter',
#               'specie',
#               'species',
#               'speciesatrisk',
#               'vulnerable',
#               'wetland',
#               'wild',
#               'worldfisheriesday'},
#  'conserving': {'atlanticsalmon',
#                 'biodiversity',
#                 'breed',
#                 'conserve',
#                 'coral',
#                 'ecological',
#                 'ecosystem',
#                 'endangered',
#                 'estuary',
#                 'forest',
#                 'freshwater',
#                 'habitat',
#                 'human',
#                 'hydrothermal',
#                 'important',
#                 'marineconservation',
#                 'play',
#                 'population',
#                 'protecting',
#                 'recovery',
#                 'refuge',
#                 'restoration',
#                 'restore',
#                 'speciesatrisk',
#                 'tallurutiup',
#                 'target',
#                 'understanding',
#                 'vulnerable',
#                 'wetland',
#                 'wwfcanada'},
#  'consider': {'airtravel',
#               'already',
#               'bumped',
#               'buying',
#               'calculator',
#               'card',
#               'cash',
#               'charge',
#               'choose',
#               'covered',
#               'deal',
#               'debt',
#               'expense',
#               'fee',
#               'helpful',
#               'insurance',
#               'money',
#               'mortgage',
#               'option',
#               'pay',
#               'paying',
#               'purchase',
#               'rate',
#               'rebate',
#               'shop',
#               'someone',
#               'thinking',
#               'usually',
#               'warranty',
#               'wondering'},
#  'contribute': {'2020',
#                 'achieve',
#                 'achieving',
#                 'adapt',
#                 'beef',
#                 'canola',
#                 "cdnag's",
#                 'cdnenv',
#                 'cow',
#                 'developed',
#                 'dna',
#                 'educational',
#                 'european',
#                 'fsds',
#                 'gap',
#                 'grower',
#                 'healthier',
#                 'improved',
#                 'influence',
#                 'invest',
#                 'invested',
#                 'livestock',
#                 'lowcarbon',
#                 'pan-canadian',
#                 'production',
#                 'sustainability',
#                 'understanding',
#                 'union',
#                 'wood',
#                 "🇨🇦's"},
#  'cool': {'back',
#           'bit',
#           'camping',
#           'coffee',
#           'dark',
#           'enjoying',
#           'finally',
#           'for',
#           'grab',
#           'halloween',
#           'holiday',
#           'outdoor',
#           'outdoors',
#           'outside',
#           'parkschallenge',
#           'perfect',
#           'playing',
#           'really',
#           'relax',
#           'show',
#           'snap',
#           'spend',
#           'summer',
#           'tail',
#           'there',
#           'thing',
#           'try',
#           'wait',
#           'waiting',
#           'whether'},
#  'create': {'achieve',
#             'budget2016',
#             'build',
#             'cleaner',
#             'committed',
#             'creating',
#             'developing',
#             'economic',
#             'economy',
#             'expand',
#             'expanding',
#             'framework',
#             'government',
#             'growing',
#             'growth',
#             'improving',
#             'infra',
#             'innovate',
#             'invest',
#             'investing',
#             'investment',
#             'organization',
#             'pan-canadian',
#             'promote',
#             'reliable',
#             'resource',
#             'sector',
#             'strong',
#             'stronger',
#             'territory'},
#  'creating': {'achieve',
#               'acoacanada',
#               'agricultural',
#               'budget2016',
#               'build',
#               "cdnag's",
#               'cecweb',
#               'cleanenergy',
#               'cleangrowth',
#               'create',
#               'developing',
#               'europe',
#               'expand',
#               'fcm_online',
#               'framework',
#               'greeninggovernment',
#               'growing',
#               'improving',
#               'infc_eng',
#               'innovate',
#               'invest',
#               'investing',
#               'lowcarbon',
#               'middle',
#               'mining',
#               'organization',
#               'pan-canadian',
#               'promote',
#               'sector',
#               "🇨🇦's"},
#  'cultural': {'150th',
#               'archaeological',
#               'birthday',
#               'celebrate',
#               'celebrating',
#               'century',
#               'confederation',
#               "country's",
#               'culture',
#               'designated',
#               'discovery',
#               'explore',
#               'guided',
#               'heritage',
#               'historic',
#               'history',
#               'incredible',
#               'national',
#               'parkscanada',
#               'place',
#               'plaque',
#               'played',
#               'rich',
#               'shaped',
#               'significance',
#               'sites',
#               'tourism',
#               'unesco',
#               'vibrant',
#               'worldheritage'},
#  'cycle': {'algae',
#            'beetle',
#            'decade',
#            'dna',
#            'explains',
#            'extremely',
#            'gene',
#            'genetic',
#            'globally',
#            'hatchery',
#            'hydrothermal',
#            'identified',
#            'maritimes',
#            'measured',
#            'observation',
#            'pollinator',
#            'recover',
#            'researching',
#            'sara',
#            'scallop',
#            'scilit16',
#            'seed',
#            'stream',
#            'studied',
#            'tremblay',
#            'vent',
#            'vulnerable',
#            'watershed',
#            'worldscienceday',
#            'worldwide'},
#  'damage': {'alert',
#             'allow',
#             'bcwildfire',
#             'box',
#             'cause',
#             'condition',
#             'depends',
#             'determine',
#             'essential',
#             'fine',
#             'fisher',
#             'gear',
#             'however',
#             'identify',
#             'illegal',
#             'injury',
#             'inspection',
#             'level',
#             'loss',
#             'needed',
#             'possible',
#             'prevent',
#             'quickly',
#             'remove',
#             'reporting',
#             'risk',
#             'serious',
#             'similar',
#             'small',
#             'smoke'},
#  'design': {'accepting',
#             'advisor',
#             'affairs',
#             'analyst',
#             'category',
#             'ccgcentralandarcticregion',
#             'chairperson',
#             'champion',
#             'commission',
#             'congrats',
#             'edmonton',
#             'employed',
#             'excellence',
#             'february',
#             'fn',
#             'gathered',
#             'gc2020',
#             'grad',
#             'grew',
#             'httpstcoo…',
#             'manager',
#             'minerals',
#             'persons',
#             'phase',
#             'recipient',
#             'seeking',
#             'senior',
#             'tribunal',
#             'whitehorse',
#             'yellowknife'},
#  'develop': {'2030',
#              'achieve',
#              'adapt',
#              'approach',
#              "cdnag's",
#              'cleaner',
#              'competitiveness',
#              'cow',
#              'developing',
#              'effective',
#              'emerging',
#              'faster',
#              'footprint',
#              'gap',
#              'greater',
#              'growth',
#              'industrial',
#              'innovate',
#              'invest',
#              'long-term',
#              'lowcarbon',
#              'methane',
#              'mexico',
#              'pan-canadian',
#              'processing',
#              'reduction',
#              'seek',
#              'stronger',
#              'sustainability',
#              'wastewater'},
#  'developing': {'2030',
#                 'achieve',
#                 'cecweb',
#                 'cleanenergy',
#                 'cleangrowth',
#                 'competitiveness',
#                 'develop',
#                 'expand',
#                 'expertise',
#                 'greater',
#                 'growth',
#                 'implementing',
#                 'innovate',
#                 'innovative',
#                 'invest',
#                 'leadership',
#                 'lowcarbon',
#                 'mexico',
#                 'mineral',
#                 'mining',
#                 'missioninnovation',
#                 'momentum',
#                 'nuclear',
#                 'pan-canadian',
#                 'promote',
#                 'resilience',
#                 'softwoodlumber',
#                 'stronger',
#                 'transition',
#                 "🇨🇦's"},
#  'dive': {'adult',
#           'anywhere',
#           'believe',
#           'black',
#           'blue',
#           'camera',
#           'clam',
#           'creature',
#           'dolphin',
#           'flower',
#           'grassland',
#           'guess',
#           'guy',
#           'humpback',
#           'hundred',
#           'lucky',
#           'male',
#           'mass',
#           'rare',
#           'rolling',
#           'sharkweek',
#           'shell',
#           'swim',
#           'swimming',
#           'tagging',
#           'watching',
#           'white',
#           'wonder',
#           'worldwhaleday',
#           'yellow'},
#  'diving': {'andrew',
#             'beaufort',
#             'chatham',
#             'conducted',
#             'decade',
#             'discovered',
#             'earthquake',
#             'fossil',
#             'fr',
#             'funfact',
#             'geologist',
#             'geology',
#             'geoweek',
#             'glassspongereefs',
#             'gsc',
#             'gully',
#             'kenchington',
#             'measured',
#             'newly',
#             'parkscanadapei',
#             'pfc_cfs',
#             'scotian',
#             'seafloor',
#             'seamount',
#             'southwest',
#             'supported',
#             'travelled',
#             't…',
#             'vanaqua',
#             'worldscienceday'},
#  'donate': {'aboriginalhistorymonth',
#             'according',
#             'all',
#             'asia',
#             'balance',
#             'barrier',
#             'beer',
#             'code',
#             'contains',
#             'edition',
#             'encourage',
#             'everyday',
#             'facing',
#             'favorite',
#             'ff',
#             'getprepared',
#             'intel',
#             'kids',
#             'lay',
#             'offering',
#             'pledge',
#             'plenty',
# ...
#             'fridge',
#             'furnace',
#             'grocery',
#             'instead',
#             'leds',
#             'longer',
#             'payday',
#             'properly',
#             'quick',
#             'replacing',
#             'savemoney',
#             'sold',
#             'standby',
#             'switching',
#             'thursdaythoughts',
#             'tiptuesday',
#             'utility',
#             'washer',
#             'wednesdaywisdom'},
#  'switching': {'appliance',
#                'bad',
#                'ceiling',
#                'cert',
#                'choosing',
#                'dinner',
#                'dish',
#                'electronics',
#                'fix',
#                'fridge',
#                'furnace',
#                'grocery',
#                'label',
#                'leds',
#                'lighting',
#                'longer',
#                'mondaymotivation',
#                'quick',
#                'save5',
#                'savemoney',
#                'standby',
#                'streaming',
#                'string',
#                'switch',
#                'thermostat',
#                'thursdaythoughts',
#                'tiptuesday',
#                'tv',
#                'washer',
#                'wednesdaywisdom'},
#  'tackle': {'achieve',
#             'achieving',
#             'acoacanada',
#             'adapt',
#             'adapting',
#             'addressing',
#             'ag',
#             'agri-food',
#             'campaign',
#             "cdnag's",
#             'cleanenergy',
#             'contribute',
#             'fighting',
#             'fsds',
#             'germany',
#             'greeninggovernment',
#             'healthier',
#             'influence',
#             'invested',
#             'low-carbon',
#             'lowcarbon',
#             'momentum',
#             'pan-canadian',
#             'paris',
#             'promote',
#             'resilience',
#             'success',
#             'sustainability',
#             'transition',
#             "🇨🇦's"},
#  'talk': {'aafc_canada',
#           'agnpf',
#           'catherine',
#           'conversation',
#           'dialogue',
#           'discussion',
#           'ec_minister',
#           'expert',
#           'foodpolicy4canada',
#           'forward',
#           'future',
#           'genenergy',
#           'generation',
#           'hear',
#           'httpstcopqx0lgg5hb',
#           'httpstc…',
#           'importance',
#           'letstalkwhales',
#           'live',
#           'morescience',
#           'roundtable',
#           'say',
#           'shape',
#           'shared',
#           'summit',
#           "today's",
#           'tune',
#           'unfccc',
#           'virtual',
#           'workshop'},
#  'talking': {'ambassador',
#              'brian',
#              'champion',
#              'elder',
#              'encourages',
#              'engaging',
#              'fbf',
#              'gathered',
#              'globalleadership',
#              'insight',
#              "int'l",
#              'ipcc_ch',
#              'kigaliamendment',
#              'kim',
#              'min_cirna',
#              'montrealprotocol',
#              "nrcan's",
#              'perspective',
#              'present',
#              'presentation',
#              'productive',
#              'promoting',
#              'reception',
#              'showcase',
#              'speaking',
#              'the_pdac',
#              'thenfb',
#              'thrilled',
#              'unga',
#              "yesterday's"},
#  'track': {'always',
#            'away',
#            'blind',
#            'clear',
#            'cold',
#            'drone',
#            'especially',
#            'fly',
#            'flying',
#            'heading',
#            'hit',
#            'hot',
#            'hour',
#            'laser',
#            'leave',
#            'leavethephonealone',
#            'leaving',
#            'light',
#            'little',
#            'never',
#            'nodronezone',
#            'notabrightidea',
#            'or',
#            'pack',
#            'pointing',
#            'temperature',
#            'tire',
#            'warm',
#            'winter',
#            'without'},
#  'tracking': {'3000',
#               'beaufort',
#               'bottom',
#               'breaking',
#               'brought',
#               'conducted',
#               'deep-sea',
#               'deepsea_sponges',
#               'depth',
#               'edge',
#               'ellen',
#               'funfact',
#               'geoweek',
#               "he's",
#               'hole',
#               'kenchington',
#               'lots',
#               'memorialu',
#               'naiss',
#               'nrc_cnrc',
#               'observation',
#               'pfc_cfs',
#               'recover',
#               'scilit16',
#               'sprucebudworm',
#               'surveying',
#               'trawl',
#               'tremblay',
#               'walrus',
#               'whoi'},
#  'train': {'24',
#            'accident',
#            'aircraft',
#            'airport',
#            'attention',
#            'collision',
#            'crossing',
#            'derailment',
#            'ferry',
#            'flight',
#            'flying',
#            'following',
#            'gate',
#            'installed',
#            'laser',
#            'maintenance',
#            'motorcycle',
#            'nodronezone',
#            'notabrightidea',
#            'note',
#            'pack',
#            'permit',
#            'pleasure',
#            'pointing',
#            'police',
#            'remind',
#            'running',
#            'santa',
#            'stuck',
#            'terrain'},
#  'turn': {'add',
#           'appliance',
#           'backtoschool',
#           'blackfriday',
#           'choose',
#           'clothes',
#           'decide',
#           'dollar',
#           'easy',
#           'electronics',
#           'energyefficient',
#           'game',
#           'gift',
#           'giving',
#           'grocery',
#           'habit',
#           'instead',
#           'laundry',
#           'leds',
#           'longer',
#           'own',
#           'saveenergy',
#           'shopping',
#           'simple',
#           'smaller',
#           'spending',
#           'store',
#           'thermostat',
#           'usually',
#           'washer'},
#  'turn_off': {'attention',
#               'brake',
#               'cancellation',
#               'causing',
#               'cert',
#               'cooking',
#               'crash',
#               'damaged',
#               'delayed',
#               'door',
#               'driver',
#               'fast',
#               'hood',
#               'httpowlyuy2l3061cit',
#               'lighting',
#               'party',
#               'permission',
#               'properly',
#               'replace',
#               'run',
#               'seat',
#               'software',
#               'stuck',
#               'tiptuesday',
#               'tv',
#               'upgrade',
#               "vehicle's",
#               'washer',
#               'window',
#               'wintertips'},
#  'understanding': {'2020',
#                    'adapt',
#                    'adaptation',
#                    'adapting',
#                    'algae',
#                    'bee',
#                    'cdnenv',
#                    'chemical',
#                    'collaborating',
#                    'combined',
#                    'contribute',
#                    'developed',
#                    'disease',
#                    'dna',
#                    'explains',
#                    'gap',
#                    'genetic',
#                    'globally',
#                    'grower',
#                    'healthier',
#                    'improved',
#                    'invested',
#                    'livestock',
#                    'maintain',
#                    'manage',
#                    'method',
#                    'predict',
#                    'studied',
#                    'vulnerable',
#                    'wood'},
#  'unplug': {'bad',
#             'blackfriday',
#             'cert',
#             'checklist',
#             'clothes',
#             'clothing',
#             'electronics',
#             'energysaving',
#             'extra',
#             'fan',
#             'gift',
#             'giving',
#             'hit',
#             'instead',
#             'laundry',
#             'leavethephonealone',
#             'leds',
#             'not',
#             'saveenergy',
#             'seeandbeseen',
#             'shop',
#             'shopping',
#             'spending',
#             'summertips',
#             'text',
#             'tiptuesday',
#             'treat',
#             'wash',
#             'washer',
#             'wintertips'},
#  'vegetable': {'adapt',
#                'berry',
#                'blueberry',
#                'bread',
#                'cattle',
#                "cdnag's",
#                'cereal',
#                'contribute',
#                'cow',
#                'cranberry',
#                'developed',
#                'european',
#                'fruit',
#                'grower',
#                'grown',
#                'harvest',
#                'import',
#                'influence',
#                'ingredient',
#                'iyp2016',
#                'lentil',
#                'oat',
#                'potato',
#                'poultry',
#                'pulse',
#                'trend',
#                'union',
#                'valuable',
#                'value',
#                'wheat'},
#  'walk': {'anything',
#           'backcountry',
#           'bucket',
#           'colour',
#           'destination',
#           'enjoy',
#           'finally',
#           'getaway',
#           'gorgeous',
#           'grab',
#           'gros',
#           'hidden',
#           'hike',
#           'hiking',
#           'magical',
#           'morne',
#           'outdoor',
#           'outside',
#           'paddle',
#           'peak',
#           'perfect',
#           'popular',
#           'quite',
#           'relax',
#           'skate',
#           'sky',
#           'spectacular',
#           'sunset',
#           'wait',
#           'waiting'},
#  'warm': {'always',
#           'coffee',
#           'cold',
#           'comfort',
#           'cup',
#           'dark',
#           'destination',
#           'down',
#           'flying',
#           'grab',
#           'heading',
#           'hit',
#           'hitting',
#           'holiday',
#           'hot',
#           'mindful',
#           'night',
#           'nodronezone',
#           'notabrightidea',
#           'perfect',
#           'relax',
#           'remind',
#           'ride',
#           'running',
#           'sight',
#           'sky',
#           'spring',
#           'sun',
#           'visible',
#           'whether'},
#  'warming': {'90',
#              'according',
#              'all',
#              'contain',
#              'demonstration',
#              'equal',
#              'exactly',
#              'familiar',
#              'friendly',
#              'get_prepared',
#              'gone',
#              'httpstcomze4mpw6ak',
#              'machine',
#              'migratorybirds',
#              'mikewulder',
#              'mix',
#              'mondaymotivation',
#              'outing',
#              'pair',
#              'plus',
#              'preventing',
#              'ray',
#              'stage',
#              'string',
#              'teen',
#              'thx',
#              'trial',
#              'version',
#              'web',
#              'wheel'},
#  'waste': {'breathe',
#            'cell',
#            'cleaning',
#            'compare',
#            'consumption',
#            'easily',
#            'eco-friendly',
#            'electricity',
#            'face',
#            'fertilizer',
#            'footprint',
#            'fruit',
#            'generate',
#            'ghg',
#            'green',
#            'harmful',
#            'landfill',
#            'material',
#            'problem',
#            'reduced',
#            'reducing',
#            'reduction',
#            'result',
#            'single',
#            'solar',
#            'source',
#            'storage',
#            'to',
#            'trend',
#            'yield'},
#  'wastereductionweek': {'again',
#                         'all',
#                         'biggest',
#                         'bringing',
#                         'content',
#                         'cyber',
#                         'dish',
#                         'disturbance',
#                         'double',
#                         'everyday',
#                         'fighting',
#                         'fsds',
#                         'graphic',
#                         'grocery',
#                         'httpstcoy6fsmbppgy',
#                         'likely',
#                         'matter',
#                         'mikewulder',
#                         'pledge',
#                         'pollinator',
#                         'quiz',
#                         'reading',
#                         'recycling',
#                         'reduces',
#                         'rid',
#                         'tap',
#                         'touch',
#                         'trial',
#                         'version',
#                         'yes'},
#  'wastewater': {'achieve',
#                 'bilateral',
#                 'capacity',
#                 'competitiveness',
#                 'comprehensive',
#                 'develop',
#                 'developing',
#                 'effective',
#                 'enhance',
#                 'expand',
#                 'gap',
#                 'gc',
#                 'greater',
#                 'implementing',
#                 'improved',
#                 'improving',
#                 'integrated',
#                 'invest',
#                 'investing',
#                 'investments',
#                 'invests',
#                 'lakewinnipeg',
#                 'mexico',
#                 'municipality',
#                 'prosperity',
#                 'provides',
#                 'reliable',
#                 'strong',
#                 'stronger',
#                 'treatment'},
#  'waterway': {'247',
#               'abandoned',
#               'bc',
#               'capability',
#               'chart',
#               'coastal',
#               'communications',
#               'dedicated',
#               'distress',
#               'emergency',
#               'enhanced',
#               'ensuring',
#               'greatlakes',
#               'incident',
#               'mariner',
#               'marinesafety',
#               'maritime',
#               'mcts',
#               'navigation',
#               'oceansprotectionplan',
#               'officers',
#               'ourcoasts',
#               'radar',
#               'respond',
#               'response',
#               'secure',
#               'services',
#               'towing',
#               'traffic',
#               'wrecked'},
#  'work': {'arctic',
#           'chs',
#           'collecting',
#           'conduct',
#           'continental',
#           'dedicated',
#           'field',
#           'hard',
#           'hydrographer',
#           'hydrographic',
#           'hydrography',
#           'jobs_gc',
#           'knowledge',
#           'lab',
#           'mapping',
#           'monitoring',
#           'science',
#           'scientific',
#           'scientist',
#           "scientists'",
#           'seabed',
#           'shelf',
#           'shorebird',
#           'survey',
#           'teamwork',
#           'technician',
#           'volunteer',
#           'womeninscience',
#           'worked',
#           'working'},
#  'working': {'capacity',
#              'coastal',
#              'collaborative',
#              'continue',
#              'critical',
#              'effort',
#              'enhancing',
#              'ensure',
#              'ensuring',
#              'environmental',
#              'health',
#              'infrastructure',
#              'key',
#              'knowledge',
#              'management',
#              'marinesafety',
#              'moratorium',
#              'oceansprotectionplan',
#              'ourcoasts',
#              'partner',
#              'protection',
#              'restoration',
#              'restore',
#              'restoring',
#              'role',
#              'spill',
#              'support',
#              'supporting',
#              'together',
#              'wrecked'}}
# 175 given keywords not found in the embedding model..
