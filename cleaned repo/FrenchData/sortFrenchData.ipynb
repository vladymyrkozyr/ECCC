# %%
import glob
import os
import sys
import pandas as pd
import nltk
#nltk.download()   # comment after first download
from nltk.tokenize import MWETokenizer
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
import gensim
from gensim import corpora
import string
from numbers import Number
from pprint import pprint
import logging
import operator
from FrenchLefffLemmatizer.FrenchLefffLemmatizer import FrenchLefffLemmatizer

pd.options.display.max_rows = 30

# %%
keywords_chosen = 'Keywords_ECCC_FR.csv'

data_folder = './Accounts/*.csv'

# %%
# create output directory
outputDir = os.path.dirname(data_folder) + '/q1_output/'
if not os.path.exists(outputDir):
    os.makedirs(outputDir)

# %%
# set of punctuations to remove from text
exclude = set(string.punctuation)

# %%
stopWords = set(stopwords.words('french'))

lemma = FrenchLefffLemmatizer()    # French lemmatizer

# lemmatize_keywords also clears 'nan' from input keyword list file
# lemmatization is conducted based on context, some words may not get lemmatized, 
# e.g. "local eating" does not get lemmatized to "local eat"
def lemmatize_keywords(col):
    if str(col).lower() == 'nan':
        return ''
    return '_'.join(lemma.lemmatize(word).lower() for word in col.split())

# %%
# load keywords list
pd.options.display.max_rows = 100
keywords_df = pd.read_csv(keywords_chosen, encoding='latin-1')   # "ISO-8859-1"
KEYWORDS_COLS = keywords_df.columns
lemma_keywords_df = pd.DataFrame(columns=KEYWORDS_COLS)
category_dict = {}
keywords_list = set()
for col in KEYWORDS_COLS:
    lemma_keywords_df[col] = keywords_df[col].astype(str).apply(lemmatize_keywords)
    category_dict[col] = set(lemma_keywords_df[col].tolist())
    try:
        category_dict[col].remove('')
    except:
        pass
    keywords_list = keywords_list.union(category_dict[col])
display(lemma_keywords_df)

# if there are punctuations in the keywords list, these punctuation will be kept regardless of puncturation removal step
for word in keywords_list:
    for char in word:
        if char in exclude:
            exclude.remove(char)
            
# Add all words in the given keyword list to pre-defined token dictionary
multi_word = [w.split('_') for w in keywords_list ]   #if '_' in w 
tokenizer = MWETokenizer(multi_word)
# Out:
#                              Social               Economical  \
# 0                           famille                  énergie
# 1                               ami                  secteur
# 2                            copain              importation
# 3                            copine                   import
# 4                            épouse                   import
# 5                             époux                industrie
# 6                            enfant    commerce_électronique
# 7                        changement      tendance_des_marché
# 8                        communauté               croissance
# 9                           culture                 mondiale
# 10                            femme                  mondial
# 11                            futur               écosystème
# 12                          égalité           mondialisation
# 13                        diversité                  finance
# 14                     biodiversité                 ministre
# 15                 opinion_publique              partenariat
# 16                   intérêt_public                politique
# 17       salubrité_de_leau_potable                empreinte
# 18             alimentation_durable               innovation
# 19                   naturepourtous                 novateur
# 20                     collectivité                   invest
# 21                    collaboration  entreprisesalimentaires
# 22            collectivité_en_santé                   droits
# 23                         étudiant              force_armée
# 24                            civil                équilibre
# 25                           locale           infrastructure
# 26                         minorité          coûts-avantages
# 27                       population                 matériau
# 28           égalité_entre_les_sexe              gouvernance
# 29                             race                   revenu
# 30                  groupe_ethnique              agriculture
# 31                       résilience                 bénéfice
# 32                          justice                 pauvreté
# 33                   discrimination                  chômage
# 34               interdisciplinaire                prospérer
# 35                         intégrée     terre_de_la_couronne
# 36            droits_de_la_personne                rentables
# 37                   droits_humains          produit_du_bois
# 38                       engagement          entrepreneuriat
# 39                       autochtone             entrepreneur
# 40                multiculturalisme            employabilité
# 41                  multiculturelle      chambre_de_commerce
# 42                    multiculturel                 tourisme
# 43                            métis                    fefec
# 44                            inuit              technologie
# 45                  première_nation                  produit
# 46          bibliothèque_et_archive            libre-echange
# 47                         cyclisme        commercialisation
# 48                       compostage                 commerce
# 49                          compost                   marché
# ..                              ...                      ...
# 62                     manger_local
# 63                    aliment_local
# 64                   alimentslocaux
# 65                     alimentation
# 66                           jardin
# 67                        jardinage
# 68                           jardin
# 69             sécurité_alimentaire
# 70                      eau_potable
# 71                   responsabilité
# 72               dépense_des_ménage
# 73                           ménage
# 74   santé_environnementale_urbaine
# 75                    santé_urbaine
# 76                        espérance
# 77                       provincial
# 78                          fédéral
# 79                             vote
# 80                             nord
# 81                         étudiant
# 82
# 83
# 84
# 85
# 86
# 87
# 88
# 89
# 90
# 91
# 92
# 93
# 94
# 95
# 96
# 97
# 98
# 99
# 100
# 101
# 102
# 103
# 104
# 105
# 106
# 107
# 108
# 109
# 110
# 111
#
#                             Environmental
# 0                             agriculture
# 1    les_émission_de_gaz_à_effet_de_serre
# 2                    gaz_à_effet_de_serre
# 3                            conservation
# 4                           environnement
# 5                                 durable
# 6                              soutenable
# 7                   changement_climatique
# 8                               recyclage
# 9                                     gaz
# 10            musée_canadien_de_la_nature
# 11                                 oiseau
# 12                                 oiseau
# 13                               recycler
# 14                                recycle
# 15                                   côte
# 16                             durabilité
# 17                                    air
# 18                               cyclisme
# 19                             compostage
# 20                                compost
# 21                                   côte
# 22                                   vélo
# 23                             climatique
# 24                             résilience
# 25                                  cop23
# 26                            hydrogenics
# 27                               woodland
# 28                               biofuels
# 29                     hi-velocity_system
# 30                      one_planet_summit
# 31                       oneplanet_summit
# 32                       cleantech_global
# 33                          réutilisables
# 34                                   parc
# 35                                    eau
# 36                         énergie_éolien
# 37                                solaire
# 38                          garde_côtière
# 39                   station_de_recherche
# 40                         pêche_et_océan
# 41                                     or
# 42                tarification_du_carbone
# 43       crédit_de_carbone_compensatoires
# 44                 carbone_compensatoires
# 45                             bioénergie
# 46                          biocarburants
# 47        fédération_canadien_de_la_faune
# 48                              forestier
# 49                                  forêt
# ..                                    ...
# 62                              pollution
# 63                           hydrocarbure
# 64                        énergie_fossile
# 65                             écosystème
# 66                               émission
# 67                        espèce_en_péril
# 68                                  terre
# 69                                 plante
# 70                                  arbre
# 71                                  arbre
# 72                          géothermiques
# 73                            déboisement
# 74        lélévation_du_niveau_de_la_mer
# 75                             inondation
# 76                                 côtier
# 77                                  flore
# 78                                  faune
# 79                                 marine
# 80                                oléoduc
# 81                        pollueur-payeur
# 82                       laccord_de_pari
# 83                                   vert
# 84                               polluant
# 85                 matériau_réutilisables
# 86                            atténuation
# 87                                 propre
# 88                      sommet_one_planet
# 89                          milieu_humide
# 90                     pratique_forestier
# 91                      substance_nocives
# 92                       qualité_de_l'air
# 93                    taxe_sur_le_carbone
# 94       consommation_résidentielle_deau
# 95                                 espèce
# 96                             contaminés
# 97                          contamination
# 98                               biomasse
# 99                                 fleuve
# 100                               rivière
# 101                                   lac
# 102                                 océan
# 103                                   mer
# 104                               gazoduc
# 105                                biogaz
# 106                     ressource_naturel
# 107                               pétrole
# 108                          pétrole_brut
# 109                                  mine
# 110                        espèce_sauvage
# 111                                nature
#
# [112 rows x 3 columns]

# %%
for word in keywords_list:
    if len(word) < 3:
        print(word)
# Out:
# or

# %%
def lemmatize_text(row): 
    # we are using the original text in the caption_original column because
    # the script we originally used to clean the data didn't handle the French
    # text correctly and so the results in the caption_cleaned and hashtags
    # columns are corrupted and should not be used
    # however all the cleaning (tokenizing, removal of unnecessary punctuation,
    # and lemmatization is now done right here in this script and it's done
    # correctly for French
    text = str(row['caption_original']).replace('nan', '')
    #print(text)
    text = text.replace('’', '\'')
    tokens = tokenizer.tokenize(text.split())   
    # remove stop words
    stop_free = ' '.join(w for w in tokens if w.lower() not in stopWords and len(w) > 1)
    # remove punctuation
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    # lemmatize
    lemmas = ' '.join(lemma.lemmatize(word).lower() for word in punc_free.split() if len(lemma.lemmatize(word)) > 1)
    # remove stop words that appear after lemmatization
    stop_free_2 = ' '.join(w for w in lemmas.split() if w not in stopWords and len(w) > 1)
    #print(stop_free_2)
    return stop_free_2.split()

# assign a category if a keyword from that category is matched
def find_category(row):
    text = row['lemmatized_text']
    keywords_found = []
    category = set()
    for word in text:
        for col in KEYWORDS_COLS:
            if word in category_dict[col]:
                #print(word)
                #print(category_dict[col])
                keywords_found.append(word)
                category.add(col)
    if len(keywords_found) == 0:
        category.add('other')   
    return keywords_found, sorted(list(category))

# %%
pd.options.display.max_rows = 100
# read csv files and save targt columns to dataframe
filePaths = glob.glob(data_folder)  
for filename in filePaths:
    print(filename)
    basename = os.path.basename(filename)
    outputFileName = outputDir + basename
    data_df = pd.read_csv(filename, encoding = 'utf-8')
    if data_df.shape[0] < 1:
        print('this file is empty: ' + basename)
        data_df.to_csv(outputFileName, index=None) 
        continue
    #data_df['lang'] = data_df['caption_cleaned'].astype(str).apply(detect_lang)
    #data_df = data_df.drop(['words_matched_list'], axis=1)
    data_df = data_df.fillna('')
    #wrong_lang = data_df[data_df['lang'] != 'en'].shape[0]
    data_df['lemmatized_text'] = 'unknown'
    try:
        data_df['lemmatized_text'] = data_df.apply(lemmatize_text, axis=1)
    except:
        print('Cannot process file: ' + basename)
        print("Due to ValueError:", sys.exc_info()[1])
        continue
    data_df['matched_keywords'], data_df['category'] = zip(*data_df.apply(find_category, axis=1))
    
    #display(data_df[['words_matched_list', 'lemmatized_text','matched_keywords', 'category']])
    output_list = data_df.columns.tolist()
    output_list.remove('category')
    output_list.remove('words_matched_list')
    output_list.remove('lemmatized_text')
    output_list.append('category')
    output_df = data_df[output_list]
    output_df.to_csv(outputFileName, encoding='utf-8', index=None)
# Out:
# ./Accounts/QuestionsdargentCanada_facebook_statuses.csv
# ./Accounts/MPO_Centre_tweets.csv
# ./Accounts/PechesOceansCanada_facebook_statuses.csv
# ./Accounts/GCC_CCG_tweets.csv
# ./Accounts/GCAutochtones_tweets.csv
# ./Accounts/MPO_Science_tweets.csv
# ./Accounts/ressourcenaturellescanada_posts.csv
# ./Accounts/MPO_DFO_tweets.csv
# ./Accounts/TransportsetInfrastructureauCanada_facebook_statuses.csv
# ./Accounts/AAC_Canada_tweets.csv
# ./Accounts/EnvironnementetressourcesnaturellesauCanada_facebook_statuses.csv
# ./Accounts/GardeCotiereCanadienne_facebook_statuses.csv
# ./Accounts/ministre_ec_tweets.csv
# 3102  Elkanah Billings ces disques fossiles Aspidell...
# 3103  Apprenez en plus sur notre programme de ocarto...
# 3104  nergie aire comble environ 16 des besoins tota...
# 3105  Le livre Geology Canada en 1863 consignait tou...
# 3106  trucs pour conomieCarburant ds le Guide en lig...
# 3107  DG Julie Sunday signe mandat Groupe travail Ca...
# 3108  Ce morceau de calcaire cristallin couvert en 1...
# 3109  Gardez vos PneusEnForme et lisez le Guide avan...
# 3110  LSV SP Kim Rudd conclu la TalkNuclear sur la C...
# 3111  tro ATTENTION Ceci est une enceinte de confine...
# 3112  Bonne 24mai Amusez vous mais pensez et rifiez ...
# 3113  Vous campez ce weekend Ne revenez pas avec des...
# 3114  les feuxdartifice grand public cessitent des c...
# 3115  Les feux artifice sont amusants mais suivez no...
# 3116  innovation dans les pneus en fait du chemin Co...
# 3117  Ferez vous un feu artifice pour la Quelques co...
# 3118  Partagez nos astuces sur les ces pyrotechnique...
# 3119  Allumez les ces pyrotechniques avec prudence a...
# 3120  Charles Willimott ce cristal de mica phlogopit...
# 3121  Ces restes de poissons sont les fossiles de la...
# 3122  Heure Quiz Quel nom cet insecte https co sHhdo...
#
#                                               hashtags  num_shares  num_likes  \
# 0                                        ['#Lecanada']        2169          0
# 1                                               ['#G']          56         68
# 2                                               ['#G']          41         69
# 3                                         ['#FeteDuC']         101          0
# 4                                             ['#Jou']          86          0
# 5                                               ['#G']          35         50
# 6                                                   []          77          0
# 7                         ['#Autochtones', '#JNACana']          66          0
# 8        ['#NationalForestWeek', '#DYK', '#Canada150']          64          0
# 9                                       ['#F', '#Can']          58          0
# 10                                                  []          57          0
# 11                                        ['#JIF2017']          56          0
# 12                                                  []          55          0
# 13                                                  []          54          0
# 14                                 ['#EnRappel', '#p']          54          0
# 15                                            ['#GG2']          54          0
# 16                                ['#F', '#Canada150']          53          0
# 17                                           ['#GG29']          52          0
# 18                                                  []          52          0
# 19                                         ['#polcan']          50          0
# 20                                                  []          48          0
# 21                                                  []          48          0
# 22                                           ['#Jour']          46          0
# 23                                                  []          46          0
# 24                                                  []          45          0
# 25                                              ['#p']          45          0
# 26         ['#Histoiredesfemmes', '#PrendreSaPlaceow']          45          0
# 27                              ['#ConseilJeunessePM']          45          0
# 28                                                  []          42          0
# 29                                              ['#G']          17         24
# 30                                           ['#CERC']          41          0
# 31                              ['#ConseilJeunessePM']          39          0
# 32                                   ['#Charbon', '#']          39          0
# 33                                                  []          39          0
# 34                                                  []          22         16
# 35                                     ['#Budget2017']          33          0
# 36                               ['#ModernisationONE']          14         18
# 37                            ['#Conseill', '#Canada']          32          0
# 38                                                  []          30          0
# 39                                    ['#CanadaChine']           9         20
# 40                                                  []          29          0
# 41                              ['#ConseilJeunessePM']          27          0
# 42                                                  []          27          0
# 43                                                  []          25          0
# 44                                     ['#Budget2017']          25          0
# 45                                                  []          25          0
# 46                                     ['#Budget2017']          25          0
# 47                                             ['#US']          15          9
# 48                                ['#GG29', '#polcan']          24          0
# 49                                        ['#fcc2016']          23          0
# ...                                                ...         ...        ...
# 3073                                   ['#TechPropre']           0          0
# 3074  ['#Scientif', '#OdySci', '#SR2017', '#GoSensGo']           0          0
# 3075                                   ['#geoscience']           0          0
# 3076         ['#innovation', '#Demandez', '#SciRNCan']           0          0
# 3077                               ['#HiltonLacLeamy']           0          0
# 3078                                    ['#Pipelines']           0          0
# 3079                                       ['#', '#G']           0          0
# 3080                     ['#entomologie', '#Insectes']           0          0
# 3081                             ['#BasCarbone', '#G']           0          0
# 3082                       ['#Canada150', '#insectes']           0          0
# 3083                                ['#Ottawa', '#VE']           0          0
# 3084                                            ['#G']           0          0
# 3085                                                []           0          0
# 3086                                 ['#g', '#CGC175']           0          0
# 3087                      ['#AgrileDuFr', '#insectes']           0          0
# 3088                                           ['#Oc']           0          0
# 3089                                 ['#p', '#CGC175']           0          0
# 3090                                       ['#CGC175']           0          0
# 3091                          ['#bio', '#BoisdOeuvre']           0          0
# 3092  ['#grande', '#hauteur', '#bois', '#CanadaChine']           0          0
# 3093              ['#', '#foresterie', '#technologie']           0          0
# 3094                                                []           0          0
# 3095              ['#TrouvezLaDiff', '#circumpolaire']           0          0
# 3096                                            ['#R']           0          0
# 3097    ['#CanadaChine', '#TechPropre', '#CanadaVert']           0          0
# 3098                            ['#cartes', '#CGC175']           0          0
# 3099                      ['#explorations', '#CGC175']           0          0
# 3100                         ['#JeudiR', '#Canada150']           0          0
# 3101                             ['#R', '#Foresterie']           0          0
# 3102                                                []           0          0
# 3103                       ['#Min', '#G', '#geocon17']           0          0
# 3104                             ['#nucl', '#CNA2017']           0          0
# 3105                                 ['#g', '#CGC175']           0          0
# 3106                            ['#', '#PneusEnForme']           0          0
# 3107                                                []           0          0
# 3108                                                []           0          0
# 3109                           ['#PneusEnForme', '#S']           0          0
# 3110                             ['#nucl', '#CNA2017']           0          0
# 3111                         ['#JeudiR', '#Canada150']           0          0
# 3112                        ['#24mai', '#S', '#pneus']           0          0
# 3113                             ['#AgrileDuFr', '#F']           0          0
# 3114                          ['#feuxdartifice', '#F']           0          0
# 3115                                                []           0          0
# 3116              ['#innovation', '#', '#BeTireSmart']           0          0
# 3117                                            ['#F']           0          0
# 3118                               ['#pyrotechniques']           0          0
# 3119                         ['#pyrotechniques', '#F']           0          0
# 3120                           ['#cristal', '#CGC175']           0          0
# 3121                            ['#Ottawa', '#CGC175']           0          0
# 3122                                         ['#Quiz']           0          0
#
#       Reactions_SUM language  average_sentiment_score sentiment  \
# 0              2169       fr                 0.000000   Neutral
# 1               124       fr                 0.000000   Neutral
# 2               110       fr                 0.000000   Neutral
# 3               101       fr                 0.000000   Neutral
# 4                86       fr                 0.000000   Neutral
# 5                85       fr                 0.000000   Neutral
# 6                77       fr                 0.000000   Neutral
# 7                66       fr                 0.000000   Neutral
# 8                64       en                 0.000000   Neutral
# 9                58       fr                 0.000000   Neutral
# 10               57       fr                 0.100000   Neutral
# 11               56       fr                 0.000000   Neutral
# 12               55       fr                 0.000000   Neutral
# 13               54       fr                 0.000000   Neutral
# 14               54       fr                 0.000000   Neutral
# 15               54       en                 0.093182   Neutral
# 16               53       es                 0.000000   Neutral
# 17               52       fr                 0.000000   Neutral
# 18               52       fr                 0.100000   Neutral
# 19               50       fr                 0.100000   Neutral
# 20               48       es                 0.000000   Neutral
# 3120              0       fr                 0.000000   Neutral
# 3121              0       fr                 0.000000   Neutral
# 3122              0       fr                 0.000000   Neutral
#
#        account_name                         matched_keywords  \
# 0     RNCan_tweeter                                       []
# 1     RNCan_tweeter          [changement_climatique, avenir]
# 2     RNCan_tweeter          [changement_climatique, avenir]
# 3     RNCan_tweeter                                       []
# 4     RNCan_tweeter                                       []
# 5     RNCan_tweeter                                       []
# 6     RNCan_tweeter                               [ministre]
# 7     RNCan_tweeter                    [autochtone, culture]
# 8     RNCan_tweeter                                       []
# 9     RNCan_tweeter                                  [océan]
# 10    RNCan_tweeter                               [ministre]
# 11    RNCan_tweeter                                  [femme]
# 12    RNCan_tweeter                                       []
# 13    RNCan_tweeter                               [ministre]
# 14    RNCan_tweeter                                       []
# 15    RNCan_tweeter                                       []
# 16    RNCan_tweeter                                       []
# 17    RNCan_tweeter                                       []
# 18    RNCan_tweeter                                       []
# 19    RNCan_tweeter                                       []
# 20    RNCan_tweeter                                       []
# 21    RNCan_tweeter                                       []
# 22    RNCan_tweeter                                       []
# 23    RNCan_tweeter                                       []
# 24    RNCan_tweeter                                       []
# 25    RNCan_tweeter         [ministre, changement, ministre]
# 26    RNCan_tweeter                                  [femme]
# 27    RNCan_tweeter                             [communauté]
# 28    RNCan_tweeter                                       []
# 29    RNCan_tweeter          [changement_climatique, avenir]
# 30    RNCan_tweeter                              [diversité]
# 31    RNCan_tweeter                                       []
# 32    RNCan_tweeter                                       []
# 33    RNCan_tweeter                                       []
# 34    RNCan_tweeter                                [produit]
# 35    RNCan_tweeter                                       []
# 36    RNCan_tweeter                                       []
# 37    RNCan_tweeter                                       []
# 38    RNCan_tweeter                                       []
# 39    RNCan_tweeter                          [collaboration]
# 40    RNCan_tweeter                               [ministre]
# 41    RNCan_tweeter                                       []
# 42    RNCan_tweeter                                  [forêt]
# 43    RNCan_tweeter                                  [océan]
# 44    RNCan_tweeter                               [ministre]
# 45    RNCan_tweeter                                    [eau]
# 46    RNCan_tweeter                                       []
# 47    RNCan_tweeter                                       []
# 48    RNCan_tweeter                                       []
# 49    RNCan_tweeter                      [forêt, changement]
# ...             ...                                      ...
# 3073  RNCan_tweeter        [ministre, secteur, pétrole, gaz]
# 3074  RNCan_tweeter                                       []
# 3075  RNCan_tweeter                                       []
# 3076  RNCan_tweeter                                       []
# 3077  RNCan_tweeter                               [ministre]
# 3078  RNCan_tweeter                                       []
# 3079  RNCan_tweeter                               [commerce]
# 3080  RNCan_tweeter                                       []
# 3081  RNCan_tweeter                                       []
# 3082  RNCan_tweeter                                       []
# 3083  RNCan_tweeter                                       []
# 3084  RNCan_tweeter                                 [avenir]
# 3085  RNCan_tweeter                                       []
# 3086  RNCan_tweeter                                       []
# 3087  RNCan_tweeter                                       []
# 3088  RNCan_tweeter                            [marine, ami]
# 3089  RNCan_tweeter                                [pétrole]
# 3090  RNCan_tweeter                                       []
# 3091  RNCan_tweeter                     [secteur, forestier]
# 3092  RNCan_tweeter                               [bâtiment]
# 3093  RNCan_tweeter  [secteur, énergie, technologie, propre]
# 3094  RNCan_tweeter                                 [propre]
# 3095  RNCan_tweeter                                       []
# 3096  RNCan_tweeter                                       []
# 3097  RNCan_tweeter                                    [air]
# 3098  RNCan_tweeter                                       []
# 3099  RNCan_tweeter                                   [nord]
# 3100  RNCan_tweeter                                       []
# 3101  RNCan_tweeter                                       []
# 3102  RNCan_tweeter                                       []
# 3103  RNCan_tweeter                                       []
# 3104  RNCan_tweeter                                       []
# 3105  RNCan_tweeter                                       []
# 3106  RNCan_tweeter                                       []
# 3107  RNCan_tweeter                                       []
# 3108  RNCan_tweeter                                       []
# 3109  RNCan_tweeter                                       []
# 3110  RNCan_tweeter                                       []
# 3111  RNCan_tweeter                                       []
# 3112  RNCan_tweeter                                       []
# 3113  RNCan_tweeter                                       []
# 3114  RNCan_tweeter                                       []
# 3115  RNCan_tweeter                                       []
# 3116  RNCan_tweeter                                       []
# 3117  RNCan_tweeter                                       []
# 3118  RNCan_tweeter                                       []
# 3119  RNCan_tweeter                                       []
# 3120  RNCan_tweeter                                       []
# 3121  RNCan_tweeter                                    [mer]
# 3122  RNCan_tweeter                                       []
#
#                          category
# 0                         [other]
# 1         [Environmental, Social]
# 2         [Environmental, Social]
# 3                         [other]
# 4                         [other]
# 5                         [other]
# 6                    [Economical]
# 7                        [Social]
# 8                         [other]
# 9                 [Environmental]
# 10                   [Economical]
# 11                       [Social]
# 12                        [other]
# 13                   [Economical]
# 14                        [other]
# 15                        [other]
# 16                        [other]
# 17                        [other]
# 18                        [other]
# 19                        [other]
# 20                        [other]
# 21                        [other]
# 22                        [other]
# 23                        [other]
# 24                        [other]
# 25           [Economical, Social]
# 26                       [Social]
# 27                       [Social]
# 28                        [other]
# 29        [Environmental, Social]
# 30                       [Social]
# 31                        [other]
# 32                        [other]
# 33                        [other]
# 34                   [Economical]
# 35                        [other]
# 36                        [other]
# 37                        [other]
# 38                        [other]
# 39                       [Social]
# 40                   [Economical]
# 41                        [other]
# 42                [Environmental]
# 43                [Environmental]
# 44                   [Economical]
# 45                [Environmental]
# 46                        [other]
# 47                        [other]
# 48                        [other]
# 49        [Environmental, Social]
# ...                           ...
# 3073  [Economical, Environmental]
# 3074                      [other]
# 3075                      [other]
# 3076                      [other]
# 3077                 [Economical]
# 3078                      [other]
# 3079                 [Economical]
# 3080                      [other]
# 3081                      [other]
# 3082                      [other]
# 3083                      [other]
# 3084                     [Social]
# 3085                      [other]
# 3086                      [other]
# 3087                      [other]
# 3088      [Environmental, Social]
# 3089              [Environmental]
# 3090                      [other]
# 3091  [Economical, Environmental]
# 3092                 [Economical]
# 3093  [Economical, Environmental]
# 3094              [Environmental]
# 3095                      [other]
# 3096                      [other]
# 3097              [Environmental]
# 3098                      [other]
# 3099                     [Social]
# 3100                      [other]
# 3101                      [other]
# 3102                      [other]
# 3103                      [other]
# 3104                      [other]
# 3105                      [other]
# 3106                      [other]
# 3107                      [other]
# 3108                      [other]
# 3109                      [other]
# 3110                      [other]
# 3111                      [other]
# 3112                      [other]
# 3113                      [other]
# 3114                      [other]
# 3115                      [other]
# 3116                      [other]
# 3117                      [other]
# 3118                      [other]
# 3119                      [other]
# 3120                      [other]
# 3121              [Environmental]
# 3122                      [other]
#
# [3123 rows x 16 columns]
